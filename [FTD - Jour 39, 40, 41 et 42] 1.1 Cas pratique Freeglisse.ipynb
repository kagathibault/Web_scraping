# %% [markdown]
# # Jour 11 - Olist x Freeglisse scraping case

# %% [markdown]
# <br>
# <center>
# <img src="https://res-2.cloudinary.com/crunchbase-production/image/upload/c_lpad,f_auto,q_auto:eco/h8ccwg5vhjcoqu1qfuwv" style="display:inline-block;" width=190>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img alt="Logo Freeglisse" src="https://freeglisse.com/img/ski-destock-logo-1569515072.jpg" width=250 style="display:inline-block;" >

# %% [markdown]
# ## Case study: étude de l'offre et du positionnement de Freeglisse

# %% [markdown]
# **_Contexte_**
#
# Olist aimerait désormais **augmenter son offre sur le segment du sport**, en incitant des marketplaces d'articles de sport à rejoindre la plateforme. Pour affiner sa stratégie vis-à-vis de ce type de vendeurs, Olist a besoin **d'analyser leur offre et leur positionnement**, pour mieux connaitre le marché sur lequel ils évoluent.
#
# En particulier, les Sales d'Olist s'intéressent à **FreeGlisse**, une plateforme de vente en ligne de matériel de ski d'occasion. Leur ojectif est d'emmagasiner le plus d’informations possibles à partir de ce que FreeGlisse affiche sur son site web.
# <br><br>
#
# **_Instructions_**
#
# Olist voudrait se concentrer dans un premier temps sur le segment des **skis**. Les informations à étudier incluent : **le nombre d'annonces sur les skis**, les **prix** pratiqués, la **répartition de l’offre entre les différentes sous-catégories**, eventuellement la **profondeur des stocks** (= le nombre de produits disponibles, ou le nombre de tailles disponibles par produit), et tout ce que vous pensez qui serait **intéressant pour analyser le positionnement marché de FreeGlisse**.
#
# Ces informations seraient d’autant plus intéressantes si elles étaient étudiées **par type de ski** (indiqué dans la Fiche Technique de chaque ski). N'hésitez pas à effectuer les regroupements qui vous semblent pertinents, à faire des analyses quantitatives et qualitatives, en utilisant **pandas** et en faisant de beaux **graphiques**. Pour les graphiques, vous utiliserez **Google Data Studio**.
#
# Côté technique, 2 compétences pourront être mises en oeuvre: le **crawling** entre les différentes pages du site, pour observer l’ensemble des offres de skis d’occasion (ici, pas besoin de selenium - des techniques plus simples seront possibles), et le **scraping des pages individuelles**, avec différentes infos à aller chercher.
#
# Pour finir, l'objectif de ce cas est aussi de tirer de ces analyses des **insights business**, en particulier des **conclusions sur le positionnement commercial de FreeGlisse et les spécificités qu'il pourrait apporter à Olist**.
# <br><br>
#
# **_Présentation_**
#
# En groupe, vous devrez **analyser les informations issues du scraping**, puis en fin de projet **présenter en environ 5 minutes** votre analyse à des Product Managers d'Olist (jurys de Databirdies), sous forme de **dashboard Data Studio**. L'essentiel est que la présentation soit **visuelle et intelligible par des stakeholders non-tech**.

# %% [markdown]
# ## liste de nos idées

# %%
## - catégorie(performant, loisir, junior(mixte - fille), type(polyvalent, all mountain, piste...), )
# - taille de ski 
# - Etat matériel ( A B C) 
# - prix 
# - marque (moyen vente, moyen prix ...)

# %% [markdown]
# ## importation des package

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from ydata_profiling import ProfileReport
import missingno as msno #msno.matrix(df)
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
from tqdm.notebook import tqdm

# %% [markdown]
# ## Obtention des URL de chaque page

# %%
def get_all_pages():
    urls_page = []
    page_number = 1
 
    for i in range(7):
        i = f"https://freeglisse.com/fr/12-ski-occasion?page={page_number}"
        page_number += 1
        urls_page.append(i)
    print(urls_page)
get_all_pages()
# Out:
# ['https://freeglisse.com/fr/12-ski-occasion?page=1', 'https://freeglisse.com/fr/12-ski-occasion?page=2', 'https://freeglisse.com/fr/12-ski-occasion?page=3', 'https://freeglisse.com/fr/12-ski-occasion?page=4', 'https://freeglisse.com/fr/12-ski-occasion?page=5', 'https://freeglisse.com/fr/12-ski-occasion?page=6', 'https://freeglisse.com/fr/12-ski-occasion?page=7']

# %% [markdown]
# ## Recuperation du code HTML de la page 1

# %%
test = requests.get("https://freeglisse.com/fr/12-ski-occasion?page=1")
test.content
# Out:
# b'<!doctype html>\n<html lang="fr-FR">\n\n  <head>\n    \n      \n  <meta charset="utf-8">\n\n\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\n\n  <title>Ski occasion - Ski d&#039;occasion - Skis occasions (1)</title>\n  \n    \n  \n  <meta name="description" content="Ski occasion">\n  <meta name="keywords" content="ski occasion">\n        <link rel="canonical" href="https://freeglisse.com/fr/12-ski-occasion">\n    \n          <link rel="alternate" href="https://freeglisse.com/fr/12-ski-occasion?page=1" hreflang="fr-fr">\n          <link rel="alternate" href="https://freeglisse.com/de/12-gebrauchte-ski?page=1" hreflang="de-de">\n          <link rel="alternate" href="https://freeglisse.com/en/12-used-ski?page=1" hreflang="en-en">\n          <link rel="alternate" href="https://freeglisse.com/es/12-esqui-usado?page=1" hreflang="es-es">\n          <link rel="alternate" href="https://freeglisse.com/it/12-sci-usato?page=1" hreflang="it-it">\n      \n  \n  \n    <script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "Organization",\n    "name" : "Freeglisse.com",\n    "url" : "https://freeglisse.com/fr/",\n    "logo": {\n      "@type": "ImageObject",\n      "url":"https://freeglisse.com/img/logo-1668007595.jpg"\n    }\n  }\n</script>\n\n<script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "WebPage",\n    "isPartOf": {\n      "@type": "WebSite",\n      "url":  "https://freeglisse.com/fr/",\n      "name": "Freeglisse.com"\n    },\n    "name": "Ski occasion - Ski d&#039;occasion - Skis occasions (1)",\n    "url":  "https://freeglisse.com/fr/12-ski-occasion?page=1"\n  }\n</script>\n\n\n  <script type="application/ld+json">\n    {\n      "@context": "https://schema.org",\n      "@type": "BreadcrumbList",\n      "itemListElement": [\n                      {\n              "@type": "ListItem",\n              "position": 1,\n              "name": "Accueil",\n              "item": "https://freeglisse.com/fr/"\n              },                        {\n              "@type": "ListItem",\n              "position": 2,\n              "name": "Occasion",\n              "item": "https://freeglisse.com/fr/106-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 3,\n              "name": "Ski occasion",\n              "item": "https://freeglisse.com/fr/12-ski-occasion"\n              }            ]\n          }\n  </script>\n  \n  \n  \n  <script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "ItemList",\n    "itemListElement": [\n                  {\n            "@type": "ListItem",\n            "position": 0,\n            "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n            "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm"\n            },                    {\n            "@type": "ListItem",\n            "position": 1,\n            "name": "Ski occasion Rossignol Sender 94 Ti 2023  + Fixations",\n            "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-431270-ski-occasion-rossignol-sender-94-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/898-taille_skis-156_cm"\n            },                    {\n            "@type": "ListItem",\n            "position": 2,\n            "name": "Ski de fond occasion Rossignol LTS Junior + fixation SNS Profil",\n            "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-434106-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c"\n            },                    {\n            "@type": "ListItem",\n            "position": 3,\n            "name": "Ski occasion Rossignol React 6 Compact + fixations",\n  ...

# %% [markdown]
# test.content est un objet bytes (un objet binaire)

# %%
type(test.content)
# Out:
# bytes

# %% [markdown]
# ## Mise en soup (meilleure lecture) du "test.content"

# %%
soup = BeautifulSoup(test.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Ski occasion - Ski d'occasion - Skis occasions (1)</title>
# <meta content="Ski occasion" name="description"/>
# <meta content="ski occasion" name="keywords"/>
# <link href="https://freeglisse.com/fr/12-ski-occasion" rel="canonical"/>
# <link href="https://freeglisse.com/fr/12-ski-occasion?page=1" hreflang="fr-fr" rel="alternate"/>
# <link href="https://freeglisse.com/de/12-gebrauchte-ski?page=1" hreflang="de-de" rel="alternate"/>
# <link href="https://freeglisse.com/en/12-used-ski?page=1" hreflang="en-en" rel="alternate"/>
# <link href="https://freeglisse.com/es/12-esqui-usado?page=1" hreflang="es-es" rel="alternate"/>
# <link href="https://freeglisse.com/it/12-sci-usato?page=1" hreflang="it-it" rel="alternate"/>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "name" : "Freeglisse.com",
#     "url" : "https://freeglisse.com/fr/",
#     "logo": {
#       "@type": "ImageObject",
#       "url":"https://freeglisse.com/img/logo-1668007595.jpg"
#     }
#   }
# </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "WebPage",
#     "isPartOf": {
#       "@type": "WebSite",
#       "url":  "https://freeglisse.com/fr/",
#       "name": "Freeglisse.com"
#     },
#     "name": "Ski occasion - Ski d&#039;occasion - Skis occasions (1)",
#     "url":  "https://freeglisse.com/fr/12-ski-occasion?page=1"
#   }
# </script>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement": [
#                       {
#               "@type": "ListItem",
#               "position": 1,
#               "name": "Accueil",
#               "item": "https://freeglisse.com/fr/"
#               },                        {
#               "@type": "ListItem",
#               "position": 2,
#               "name": "Occasion",
#               "item": "https://freeglisse.com/fr/106-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 3,
#               "name": "Ski occasion",
#               "item": "https://freeglisse.com/fr/12-ski-occasion"
#               }            ]
#           }
#   </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "ItemList",
#     "itemListElement": [
#                   {
#             "@type": "ListItem",
#             "position": 0,
#             "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Ski occasion Rossignol Sender 94 Ti 2023  + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-431270-ski-occasion-rossignol-sender-94-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/898-taille_skis-156_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Ski de fond occasion Rossignol LTS Junior + fixation SNS Profil",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-434106-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Ski occasion Rossignol React 6 Compact + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-performance/19115-487602-ski-occasion-rossignol-react-6-compact-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Ski de fond occasion Toutes marques + fixation SNS Profil",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15468-165924-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Ski de fond occasion Toutes marques + fixation SNS Profil",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18999-436272-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/912-taille_skis-170_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 6,
#             "name": "Ski de fond occasion Toutes marques  + fixation vieux sns",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15483-167626-ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 7,
#             "name": "Ski occasion junior toutes marques à 29 € + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-junior-pas-cher/18084-388201-ski-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 8,
#             "name": "Ski occasion Rossignol Nova 6 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-femme-loisir/18890-430532-ski-occasion-rossignol-nova-6-fixations.html#/9-etat_du_materiel-qualite_b/891-taille_skis-149_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 9,
#             "name": "Ski occasion junior toutes marques à 19 € + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-junior-pas-cher/1795-223039-ski-occasion-junior-toutes-marques-a-19-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 10,
#             "name": "Ski occasion Femme toutes marques tous modèles à 29€ + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-femme-pas-cher/16352-299199-ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 11,
#             "name": "Ski junior Rossignol Star Wars occasion + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-junior-loisir/14329-142844-ski-junior-rossignol-star-wars-occasion-fixations.html#/3-etat_du_materiel-qualite_a/852-taille_skis-110_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 12,
#             "name": "Ski occasion Salomon Tous Modèles à 29€ + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13078-299840-ski-occasion-salomon-tous-modeles-a-29-fixations.html#/897-taille_skis-155_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 13,
#             "name": "Ski occasion Dynastar SPEED ZONE 4x4 78 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18284-405600-ski-occasion-dynastar-speed-zone-4x4-78-fixations.html#/3-etat_du_materiel-qualite_a/913-taille_skis-171_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 14,
#             "name": "Ski occasion junior Dynastar Team speed  + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-junior-loisir/14533-141180-ski-occasion-junior-dynastar-team-speed-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 15,
#             "name": "Ski de fond occasion Rossignol Progress + fixaxion SNS profil",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18972-434095-ski-de-fond-occasion-rossignol-progress-fixaxion-sns-profil.html#/872-taille_skis-130_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 16,
#             "name": "Ski de fond occasion Fischer Cruiser Crown + fixation NNN",
#             "url": "https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-nnn/18914-431254-ski-de-fond-occasion-fischer-cruiser-crown-fixation-nnn.html#/3-etat_du_materiel-qualite_a/916-taille_skis-174_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 17,
#             "name": "Ski occasion Atomic tous modèle à 29€ + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13097-299277-ski-occasion-atomic-tous-modele-a-29-fixations.html#/900-taille_skis-158_cm/1768-etat_du_materiel-qualite_c"
#             },                    {
#             "@type": "ListItem",
#             "position": 18,
#             "name": "Ski occasion Dynastar Legend X 75 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-loisir/18536-418697-ski-occasion-dynastar-legend-x-75-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 19,
#             "name": "Ski occasion K2 Thrilluvit 85 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17203-409334-ski-occasion-k2-thrilluvit-85-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 20,
#             "name": "Ski occasion Atomic Cloud Q9 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18929-432754-ski-occasion-atomic-cloud-q9-fixations.html#/3-etat_du_materiel-qualite_a/889-taille_skis-147_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 21,
#             "name": "Ski occasion Dynastar SPEED ZONE 4x4 82 + fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18381-411552-ski-occasion-dynastar-speed-zone-4x4-82-fixations.html#/9-etat_du_materiel-qualite_b/906-taille_skis-164_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 22,
#             "name": "Ski FILLE occasion junior toutes marques à 29 € + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-233190-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm"
#             },                    {
#             "@type": "ListItem",
#             "position": 23,
#             "name": "Ski occasion adulte K2 tous modèles à 29€ + Fixations",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13081-299511-ski-occasion-adulte-k2-tous-modeles-a-29-fixations.html#/901-taille_skis-159_cm/1768-etat_du_materiel-qualite_c"
#             }          ]
#         }
# </script>
# <link href="https://freeglisse.com/fr/12-ski-occasion?page=2" rel="next"/>
# <meta content="Ski occasion - Ski d'occasion - Skis occasions (1)" property="og:title"/>
# <meta content="Ski occasion" property="og:description"/>
# <meta content="https://freeglisse.com/fr/12-ski-occasion?page=1" property="og:url"/>
# <meta content="Freeglisse.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://freeglisse.com/themes/rb_davici/assets/cache/theme-76082a899.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var ASSearchUrl = "https:\/\/freeglisse.com\/fr\/module\/pm_advancedsearch4\/advancedsearch4";
#         var PAYPLUG_DOMAIN = "https:\/\/secure.payplug.com";
#         var RB_Meta = {"v":"1.0.0"};
#         var active = "0";
#         var ap5_cartPackProducts = [];
#         var ap5_modalErrorClose = "Fermer";
#         var ap5_modalErrorTitle = "Une erreur est survenue";
#         var as4_orderBySalesAsc = "Meilleures ventes en dernier";
#         var as4_orderBySalesDesc = "Meilleures ventes en premier";
#         var cancel_rating_txt = "Cancel Rating";
#         var collections = ["<a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-femme-loisir\/16365-chaussure-de-ski-occasion-rossignol-vita.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/47822-home_default\/chaussure-de-ski-occasion-rossignol-vita.jpg' alt='Chaussure de ski Occasion Rossignol vita'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-femme-loisir\/16365-chaussure-de-ski-occasion-rossignol-vita.html' title='Chaussure de ski Occasion Rossignol vita'>Chaussure de ski Occasion Rossignol vita<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-adulte-loisir\/8232-chaussure-de-ski-occasion-atomic-modele-hawx-plus.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/20776-home_default\/chaussure-de-ski-occasion-atomic-modele-hawx-plus.jpg' alt='Chaussure de ski occasion Atomic mod\u00e8le Hawx Plus'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-adulte-loisir\/8232-chaussure-de-ski-occasion-atomic-modele-hawx-plus.html' title='Chaussure de ski occasion Atomic mod\u00e8le Hawx Plus'>Chaussure de ski occasion Atomic mod\u00e8le Hawx Plus<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/14244-ski-occasion-volkl-rtm-74-fixation.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/37516-home_default\/ski-occasion-volkl-rtm-74-fixation.jpg' alt='Ski occasion Volkl RTM 7.4 + fixation'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/14244-ski-occasion-volkl-rtm-74-fixation.html' title='Ski occasion Volkl RTM 7.4 + fixation'>Ski occasion Volkl RTM 7.4 + fixation<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-junior-loisir\/14151-ski-occasion-junior-nordica-hot-rod-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/37152-home_default\/ski-occasion-junior-nordica-hot-rod-fixations.jpg' alt='Ski occasion junior Nordica Hot Rod + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-junior-loisir\/14151-ski-occasion-junior-nordica-hot-rod-fixations.html' title='Ski occasion junior Nordica Hot Rod + fixations'>Ski occasion junior Nordica Hot Rod + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/boots-occasion-loisir\/11052-boots-occasion-nidecker-noir-rouge.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/21504-home_default\/boots-occasion-nidecker-noir-rouge.jpg' alt='Boots occasion Nidecker noir rouge'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/boots-occasion-loisir\/11052-boots-occasion-nidecker-noir-rouge.html' title='Boots occasion Nidecker noir rouge'>Boots occasion Nidecker noir rouge<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-adulte-performance\/18047-chaussure-de-ski-occasion-salomon-s-pro-r100.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/63652-home_default\/chaussure-de-ski-occasion-salomon-s-pro-r100.jpg' alt='Chaussure de ski occasion Salomon S Pro R100'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/chaussure-ski-occasion-adulte-performance\/18047-chaussure-de-ski-occasion-salomon-s-pro-r100.html' title= ...
#         var hirEnableMailalert = false;
#         var isLogged = false;
#         var is_sandbox_mode = false;
#         var module_name = "payplug";
#         var payplug_ajax_url = "https:\/\/freeglisse.com\/fr\/module\/payplug\/ajax";
#         var payplug_oney = true;
#         var payplug_oney_loading_msg = "Chargement";
#         var pm_advancedpack = {"ajaxUrl":"https:\/\/freeglisse.com\/fr\/module\/pm_advancedpack\/ajax","staticToken":"0cc26bc1e7fc2c1dd6f4c3106c8304e3"};
#         var popup = "<div\n\tclass=\"rb-popup-container\"\n\tstyle=\"width:770px;\n\theight:460px;\tbackground-image: url('\/modules\/rbthemefunction\/\/views\/img\/imgbg_1.jpg');\tbackground-position: center\"\n>\n\t<div class=\"rb-popup-flex\">\n\t\t<div id=\"rb_newsletter_popup\" class=\"rb-block\">\n\t\t\t<div class=\"rb-block-content\">\n\t\t\t\t<form action=\"\" method=\"POST\">\n\t\t\t\t\t<div class=\"rb-popup-text\">\n    \t\t\t\t\t<h2>Soyez le premier inform\u00e9<\/h2>\n<p>Abonnez-vous pour les derni\u00e8res nouvelles et obtenez 5\u20ac de r\u00e9duction sur votre premi\u00e8re commande.<\/p>\n                    <\/div>\n\n                    \t                    <div class=\"rb-relative-input relative\">\n\t                    \t<span class=\"rb-your-email\">\n\t\t\t\t\t\t\t\t<input class=\"inputNew\" id=\"rb-newsletter-popup\" type=\"email\" name=\"email\" required=\"\" value=\"\" placeholder=\"votre@email.com\" \/>\n\t\t\t\t\t\t\t<\/span>\n\t                    \t<button class=\"rb-send-email\">\n\t                    \t\t<i class=\"material-icons\">trending_flat<\/i>\n\t\t\t\t\t\t\t\tS'inscrire\n\t                    \t<\/button>\n\t                    <\/div>\n\n\t                    <div class=\"rb-email-alert\">\n\t                    \t<div class=\"cssload-container rb-ajax-loading\">\n\t<div class=\"cssload-double-torus\"><\/div>\n<\/div>\t                    \t<p class=\"rb-email rb-email-success alert alert-success\"><\/p>\n\t                    \t<p class=\"rb-email rb-email-error alert alert-danger\"><\/p>\n\t                    <\/div>\n                    \t\t\t\t<\/form>\n\t\t\t<\/div>\n\t\t<\/div>\n\t<\/div>\n<\/div>";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"Total","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Total TTC","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Total HT :","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Sous-total","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Livraison","amount":0,"value":""},"tax":null},"products_count":0,"summary_string":"0 articles","vouchers":{"allowed":1,"added":[]},"discounts":[{"id_cart_rule":"2404","id_customer":"0","date_from":"2018-06-18 13:00:00","date_to":"2028-07-18 13:00:00","description":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity":"994653","quantity_per_user":"100000","priority":"1","partial_use":"1","code":"","minimum_amount":"199.000000","minimum_amount_tax":"1","minimum_amount_currency":"1","minimum_amount_shipping":"0","country_restriction":"1","carrier_restriction":"1","group_restriction":"0","cart_rule_restriction":"0","product_restriction":"0","shop_restriction":"0","free_shipping":"1","reduction_percent":"0.00","reduction_exclude_special":"0","reduction_amount":"0.000000","reduction_tax":"0","reduction_currency":"1","reduction_product":"0","gift_product":"0","gift_product_attribute":"0","highlight":"1","active":"1","date_add":"2018-06-18 13:41:03","date_upd":"2024-05-11 09:59:40","id_lang":"1","name":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity_for_user":100000}],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"Fran\u00e7ais (French)","iso_code":"fr","locale":"fr-FR","language_code":"fr-fr","is_rtl":"0","date_format_lite":"d\/m\/Y","date_format_full":"d\/m\/Y H:i:s","id":1},"page":{"title":"","canonical":"https:\/\/freeglisse.com\/fr\/12-ski-occasion","meta":{"title":"Ski occasion - Ski d'occasion - Skis occasions (1)","description":"Ski occasion","keywords":"ski occasion","robots":"index"},"page_name":"category","body_classes":{"lang-fr":true,"lang-rtl":false,"country-FR":true,"currency-EUR":true,"layout-left-column":true,"page-category":true,"tax-display-enabled":true,"category-id-12":true,"category-Ski occasion":true,"category-id-parent-106":true,"category-depth-level-3":true},"admin_notifications":[]},"shop":{"name":"Freeglisse.com","logo":"https:\/\/freeglisse.com\/img\/logo-1668007595.jpg","stores_icon":"https:\/\/freeglisse.com\/img\/ski-destock-logo_stores-1569515187.gif","favicon":"https:\/\/freeglisse.com\/img\/favicon.ico"},"urls":{"base_url":"https:\/\/freeglisse.com\/","current_url":"https:\/\/freeglisse.com\/fr\/12-ski-occasion?page=1","shop_domain_url":"https:\/\/freeglisse.com","img_ps_url":"https:\/\/freeglisse.com\/img\/","img_cat_url":"https:\/\/freeglisse.com\/img\/c\/","img_lang_url":"https:\/\/freeglisse.com\/img\/l\/","img_prod_url":"https:\/\/freeglisse.com\/img\/p\/","img_manu_url":"https:\/\/freeglisse.com\/img\/m\/","img_sup_url":"https:\/\/freeglisse.com\/img\/su\/","img_ship_url":"https:\/\/freeglisse.com\/img\/s\/","img_store_url":"https:\/\/freeglisse.com\/img\/st\/","img_col_url":"https:\/\/freeglisse.com\/img\/co\/","img_url":"https:\/\/freeglisse.com\/themes\/rb_davici\/assets\/img\/","css_url":"https:\/\/freeglisse.com\/themes\/rb_davici\/assets\/css\/","js_url":"https:\/\/freeglisse.com\/themes\/rb_davici\/assets\/js\/","pic_url":"https:\/\/freeglisse.com\/upload\/","pages":{"address":"https:\/\/freeglisse.com\/fr\/adresse","addresses":"h ...
#         var probance_wt = {"id":null,"wt_token":"LivB9s6KennjnoG","id_type":"customer_email","id_product":"","api_url":"t4.my-probance.one","customer_prefix":"","product_prefix":"","debug":"0"};
#         var psemailsubscription_subscription = "https:\/\/freeglisse.com\/fr\/module\/ps_emailsubscription\/subscription";
#         var psr_icon_color = "#F19D76";
#         var rbFrontendConfig = {"isEditMode":"","stretchedSectionContainer":"","is_rtl":"","rb_day":"Days"};
#         var rb_days = "Days";
#         var rb_facebook = {"general_appid":"1671479023110588","general_pageid":"2005509456220113","chat_state":"0","chat_color":"","chat_delay":"12","login_state":"0","login_redirect":"no_redirect","comments_state":"0","comments_tab":"0","comments_width":"","comments_number":"","comments_admins":"","product_page_url":"https:\/\/freeglisse.com\/fr\/12-ski-occasion","login_destination":"https:\/\/freeglisse.com\/fr\/mon-compte","phrases":{"login":"Se connecter"}};
#         var rb_height = "460";
#         var rb_hours = "Hours";
#         var rb_minutes = "Minutes";
#         var rb_modal = "<div class=\"modal-content\">\n\t<div class=\"modal-header\">\n\t\t<h5 class=\"modal-title text-xs-center\">\n\t\t\tDelete selected item ?\n\t\t<\/h5>\n\t<\/div>\n\n\t<div class=\"modal-footer\">\n\t\t<button type=\"button\" class=\"rb-modal-no rb-modal-accept btn btn-primary\" data-dismiss=\"modal\">\n\t\t\tAnnuler\n\t\t<\/button>\n\n\t\t<button type=\"button\" class=\"rb-modal-yes rb-modal-accept btn btn-primary\">\n\t\t\tOK\n\t\t<\/button>\n\t<\/div>\n<\/div>";
#         var rb_seconds = "Seconds";
#         var rb_slick = {"active":"1","slideshow":"4","slidesToScroll":"1","autoplay":"0","autospeed":""};
#         var rb_text = "You must be logged. <a href=\"https:\/\/freeglisse.com\/fr\/authentification\">Connexion<\/a>";
#         var rb_view = "1";
#         var rb_width = "770";
#         var rb_zoom = {"active":"1","type":"2","scroll":"1"};
#         var recaptcha_position_contact_us = "inline";
#         var recaptcha_position_login = "";
#         var recaptcha_position_mailalert = "";
#         var recaptcha_position_newsletter = "";
#         var recaptcha_position_password = "";
#         var recaptcha_position_productcomment = "";
#         var recaptcha_position_registration = "";
#         var text1 = "No Product";
#         var text2 = "You Can Not Delete Default Wishlist";
#         var token = "0cc26bc1e7fc2c1dd6f4c3106c8304e3";
#         var url_ajax = "https:\/\/freeglisse.com\/fr\/module\/rbthemefunction\/ajax";
#         var url_compare = "https:\/\/freeglisse.com\/fr\/compare";
#         var url_wishlist = "https:\/\/freeglisse.com\/fr\/wishlist";
#       </script>
# <style>.rb_megamenu .rb_menus_li h4,
# .rb_megamenu .rb_menus_li h5,
# .rb_megamenu .rb_menus_li h6,
# .rb_megamenu .rb_menus_li h1,
# .rb_megamenu .rb_menus_li h2,
# .rb_megamenu .rb_menus_li h3,
# .rb_megamenu .rb_menus_li h4 *:not(i),
# .rb_megamenu .rb_menus_li h5 *:not(i),
# .rb_megamenu .rb_menus_li h6 *:not(i),
# .rb_megamenu .rb_menus_li h1 *:not(i),
# .rb_megamenu .rb_menus_li h2 *:not(i),
# .rb_megamenu .rb_menus_li h3 *:not(i),
# .rb_megamenu .rb_menus_li > a{
#     font-family: inherit;
# }
# .rb_megamenu *:not(.fa):not(i){
#     font-family: inherit;
# }
#
# .rb_block *{
#     font-size: px;
# }
#
# @media (min-width: 768px){
# /*layout 1*/
#     .rb_megamenu.layout_layout1{
#         background: ;
#     }
#     .layout_layout1 .rb_megamenu_content{
#       background: linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -webkit-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -o-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#     }
#     .rb_megamenu.layout_layout1:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout1 .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item *{
#         color:
#     }
#     .layout_layout1 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1 .rb_menus_li.active > a,
#     #header .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1:hover .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout1 .rb_menus_li.active > a{
#         color: ;
#     }
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a:before,
#     .layout_layout1.ybc_vertical_menu:hover .ybc-menu-vertical-button:before,
#     .layout_layout1:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar,
#     .ybc-menu-vertical-button.layout_layout1:hover{background-color: ;}
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover,
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover{
#         background: ;
#     }
#
#     .layout_layout1.rb_megamenu .rb_columns_ul,
#     .layout_layout1.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout1 .rb_block_content a,
#     #header .layout_layout1 .rb_block_content p,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout1 .rb_columns_ul h1,
#     .layout_layout1 .rb_columns_ul h2,
#     .layout_layout1 .rb_columns_ul h3,
#     .layout_layout1 .rb_columns_ul h4,
#     .layout_layout1 .rb_columns_ul h5,
#     .layout_layout1 .rb_columns_ul h6,
#     .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout1 .rb_columns_ul .h1,
#     .layout_layout1 .rb_columns_ul .h2,
#     .layout_layout1 .rb_columns_ul .h3,
#     .layout_layout1 .rb_columns_ul .h4,
#     .layout_layout1 .rb_columns_ul .h5,
#     .layout_layout1 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1 li:hover > a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{color: ;}
#
#
# /*end layout 1*/
#
#
#     /*layout 2*/
#     .rb_megamenu.layout_layout2{
#         background-color: ;
#     }
#
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout2 .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item *{
#         color:
#     }
#     .layout_layout2 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:hover .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a{color: ;}
#
#     .layout_layout2:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout2.ybc_vertical_menu:hover{
#         background-color: ;
#     }
#
#     .layout_layout2.rb_megamenu .rb_columns_ul,
#     .layout_layout2.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout2 .rb_block_content a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout2 .rb_columns_ul h1,
#     .layout_layout2 .rb_columns_ul h2,
#     .layout_layout2 .rb_columns_ul h3,
#     .layout_layout2 .rb_columns_ul h4,
#     .layout_layout2 .rb_columns_ul h5,
#     .layout_layout2 .rb_columns_ul h6,
#     .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout2 .rb_columns_ul .h1,
#     .layout_layout2 .rb_columns_ul .h2,
#     .layout_layout2 .rb_columns_ul .h3,
#     .layout_layout2 .rb_columns_ul .h4,
#     .layout_layout2 .rb_columns_ul .h5,
#     .layout_layout2 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 li:hover > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#
#
#     /*layout 3*/
#     .rb_megamenu.layout_layout3,
#     .layout_layout3 .rb_tab_li_content{
#         background-color: ;
#
#     }
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout3 .ybc-menu-vertical-button,
#     .layout_layout3 .rb_extra_item *{
#         color:
#     }
#     .layout_layout3 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout3 .rb_menus_li:hover > a,
#     .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3:hover .ybc-menu-vertical-button,
#     .layout_layout3:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         color: ;
#     }
#
#     .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout3.ybc_vertical_menu:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_columns_contents_ul,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_li_content {
#         background-color: ;
#     }
#     .layout_layout3 .rb_tabs_li.open.rb_tabs_has_content .rb_tab_li_content .rb_tab_name::before{
#         border-right-color: ;
#     }
#     .layout_layout3.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout3 .rb_menus_ul.rb_mn_submenu_full_height .rb_menus_li:hover a::before,
#     .layout_layout3.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#         border-color: ;
#     }
#     #header .layout_layout3 .rb_block_content a,
#     #header .layout_layout3 .rb_block_content p,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout3 .rb_columns_ul h1,
#     .layout_layout3 .rb_columns_ul h2,
#     .layout_layout3 .rb_columns_ul h3,
#     .layout_layout3 .rb_columns_ul h4,
#     .layout_layout3 .rb_columns_ul h5,
#     .layout_layout3 .rb_columns_ul h6,
#     .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout3 .rb_columns_ul .h1,
#     .layout_layout3 .rb_columns_ul .h2,
#     .layout_layout3 .rb_columns_ul .h3,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     .layout_layout3 .rb_columns_ul .h4,
#     .layout_layout3 .rb_columns_ul .h5,
#     .layout_layout3 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#     /*layout 4*/
#
#     .rb_megamenu.layout_layout4{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout4:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout4 .ybc-menu-vertical-button,
#     .layout_layout4 .rb_extra_item *{
#         color:
#     }
#     .layout_layout4 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4 .rb_menus_li.active > a,
#     #header .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4:hover .ybc-menu-vertical-button,
#     #header .layout_layout4 .rb_menus_li.active > a{color: ;}
#
#     .layout_layout4:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > span,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > span,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout4.ybc_vertical_menu:hover,
#     #header .layout_layout4 .rb_menus_li:hover > span,
#     #header .layout_layout4 .rb_menus_li.active > span{
#         background-color: ;
#     }
#     .layout_layout4 .rb_megamenu_content {
#       border-bottom-color: ;
#     }
#
#     .layout_layout4.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout4 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout4.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout4 .rb_block_content a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout4 .rb_columns_ul h1,
#     .layout_layout4 .rb_columns_ul h2,
#     .layout_layout4 .rb_columns_ul h3,
#     .layout_layout4 .rb_columns_ul h4,
#     .layout_layout4 .rb_columns_ul h5,
#     .layout_layout4 .rb_columns_ul h6,
#     .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout4 .rb_columns_ul .h1,
#     .layout_layout4 .rb_columns_ul .h2,
#     .layout_layout4 .rb_columns_ul .h3,
#     .layout_layout4 .rb_columns_ul .h4,
#     .layout_layout4 .rb_columns_ul .h5,
#     .layout_layout4 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 li:hover > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#     /* end layout 4*/
#
#
#
#
#     /* Layout 5*/
#     .rb_megamenu.layout_layout5{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout5:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout5 .ybc-menu-vertical-button,
#     .layout_layout5 .rb_extra_item *{
#         color:
#     }
#     .layout_layout5 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout5 .rb_menus_li:hover > a,
#     .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5:hover .ybc-menu-vertical-button{
#         color: ;
#     }
#     .layout_layout5:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li > a:before{background-color: ;}
#
#
#     .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout5.ybc_vertical_menu:hover,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#
#     .layout_layout5.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout5 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout5.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout5 .rb_block_content a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout5 .rb_columns_ul h1,
#     .layout_layout5 .rb_columns_ul h2,
#     .layout_layout5 .rb_columns_ul h3,
#     .layout_layout5 .rb_columns_ul h4,
#     .layout_layout5 .rb_columns_ul h5,
#     .layout_layout5 .rb_columns_ul h6,
#     .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout5 .rb_columns_ul .h1,
#     .layout_layout5 .rb_columns_ul .h2,
#     .layout_layout5 .rb_columns_ul .h3,
#     .layout_layout5 .rb_columns_ul .h4,
#     .layout_layout5 .rb_columns_ul .h5,
#     .layout_layout5 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 li:hover > a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*end layout 5*/
# }
#
#
# @media (max-width: 767px){
#     .ybc-menu-vertical-button,
#     .transition_floating .close_menu,
#     .transition_full .close_menu{
#         background-color: ;
#         color: ;
#     }
#     .transition_floating .close_menu *,
#     .transition_full .close_menu *,
#     .ybc-menu-vertical-button .icon-bar{
#         color: ;
#     }
#
#     .close_menu .icon-bar,
#     .ybc-menu-vertical-button .icon-bar {
#       background-color: ;
#     }
#     .rb_menus_back_icon{
#         border-color: ;
#     }
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{color: ;}
#     .layout_layout1 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         /*border-color: ;*/
#     }
#
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     #header .layout_layout1 li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
# ...
# <span class="radio-label">Qualité C</span>
# </label>
# </li>
# </ul>
# </div>
# <div class="clearfix product-variants-item">
# <span class="control-label">Longueur des Skis</span>
# <ul class="an_productattributes-group">
# <li class="input-container float-xs-left">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="901"/>
# <span class="radio-label">159 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="902"/>
# <span class="radio-label">160 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="905"/>
# <span class="radio-label">163 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="909"/>
# <span class="radio-label">167 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="916"/>
# <span class="radio-label">174 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" type="radio" value="923"/>
# <span class="radio-label">181 cm</span>
# </label>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="list-buttons clearfix">
# <div class="product-add-cart">
# <form action="https://freeglisse.com/fr/panier" class="add-to-cart-or-refresh" method="post">
# <input name="token" type="hidden" value="0cc26bc1e7fc2c1dd6f4c3106c8304e3"/>
# <input class="product_page_product_id" name="id_product" type="hidden" value="13081"/>
# <input name="qty" type="hidden" value="1"/>
# <div class="product-add-to-cart-rb">
# <div class="product-quantity">
# <div class="add">
# <button class="btn rb-btn-product add-to-cart" data-button-action="add-to-cart" disabled="" title="Add to cart" type="submit">Ajouter au panier</button>
# <span class="product-availability hidden">
# <i class="material-icons product-available">available</i>
# </span>
# </div>
# </div>
# <p class="product-minimal-quantity hidden">
# </p>
# </div>
# </form>
# </div>
# </div>
# <div class="product-description-short" itemprop="description"></div>
# </div>
# <ul class="product-flags">
# </ul>
# </div><!-- end thumbnail-container -->
# </article><!-- end product-miniature -->
# </div>
# </div>
# <nav class="pagination">
# <div class="col-xs-12 col-md-6 col-lg-5 text-md-left text-xs-center hidden-sm-down">
#
#             Affichage 1-24 de 157 article(s)
#
#     </div>
# <div class="col-xs-12 col-md-6 col-lg-7">
# <ul class="page-list clearfix text-md-right text-xs-center">
# <li class="current">
# <a class="disabled js-search-link" href="https://freeglisse.com/fr/12-ski-occasion" rel="nofollow">
#                                                                             1
#                                                                     </a>
# </li>
# <li class="">
# <a class="js-search-link" href="https://freeglisse.com/fr/12-ski-occasion?page=2" rel="nofollow">
#                                                                             2
#                                                                     </a>
# </li>
# <li class="">
# <a class="js-search-link" href="https://freeglisse.com/fr/12-ski-occasion?page=3" rel="nofollow">
#                                                                             3
#                                                                     </a>
# </li>
# <li class="">
# <a class="js-search-link" href="https://freeglisse.com/fr/12-ski-occasion?page=7" rel="nofollow">
#                                                                             7
#                                                                     </a>
# </li>
# <li class="">
# <a class="next js-search-link" href="https://freeglisse.com/fr/12-ski-occasion?page=2" id="infinity-url" rel="next">
# <i aria-hidden="true" class="fa fa-angle-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="hidden-xl-down text-xs-right up">
# <a class="btn btn-secondary" href="#header">
#       Retour en haut
#       <i class="material-icons"></i>
# </a>
# </div>
# </div>
# </div>
# <div>
# <div id="js-product-list-bottom"></div>
# </div>
# </section>
# </section>
# </div>
# </div>
# </div>
# </section>
# <footer class="js-footer" id="footer">
# <div class="footer-container footer-h4 style-2">
# <div class="footer-top">
# <div class="container">
# <div class="footer-blockemail">
# <div class="ps-emailsubscription-block block links accordion_small_screen" id="blockEmailSubscription_displayRbEmail">
# <div class="title-newsletter">
# <h3 class="rb-title">Newsletter</h3>
# <p class="sub-letter">Vous pouvez vous désinscrire à tout moment.
# Vous trouverez pour cela nos informations de contact dans les conditions d'utilisation du site.</p>
# </div>
# <div class="block_content">
# <form action="https://freeglisse.com/fr/12-ski-occasion?page=1#blockEmailSubscription_displayRbEmail" method="post">
# <div class="input-group newsletter-input-group">
# <input aria-labelledby="block-newsletter-label" class="form-control input-subscription" name="email" placeholder="Votre adresse e-mail" required="" type="email" value=""/>
# <button class="btn btn-outline" name="submitNewsletter" type="submit">
# <i aria-hidden="true" class="fa fa-paper-plane"></i>
# <span>S'inscrire</span>
# </button>
# </div>
# <input name="blockHookName" type="hidden" value="displayRbEmail"/>
# <input name="action" type="hidden" value="0"/>
# </form>
# <div class="msg-block">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-top-->
# <div class="footer-center">
# <div class="container">
# <div class="row">
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="box-group">
# <a href="https://freeglisse.com/">
# <img alt="Freeglisse.com" class="logo" src="https://freeglisse.com/img/logo-1668007595.jpg"/>
# </a>
# <br/><br/>
# <div class="block-contact block links">
# <div class="title clearfix">
# <h3 class="h3 rb-title">Contactez-nous</h3>
# </div>
# <ul>
# <li class="address"><i class="rub-map-pin"></i><span>Freeglisse.com<br/>98 B rue des champs plans<br/>74800 Saint-Pierre en Faucigny<br/>France</span></li>
# <li class="phone">
# <i class="icon-telephone"></i>
# <span>Site web : 04 50 07 13 25 / Magasin Freeglisse Shop : 04 85 22 11 04 </span>
# </li>
# <li class="fax">
# <i class="rub-printer"></i>
# <span>RETRAIT DES COMMANDES LE LUNDI 14h-19h ET DU MARDI AU SAMEDI 9h-12h 14h-19h</span>
# </li>
# <li class="email">
# <i class="icon-mail"></i>
# <script type="text/javascript">document.write(unescape('%3c%61%20%68%72%65%66%3d%22%6d%61%69%6c%74%6f%3a%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%22%20%3e%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%3c%2f%61%3e'))</script>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Informations</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/contact" title="Utilisez notre formulaire pour nous contacter">
# 	                                contact
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/4-a-propos" title="Apprenez-en d'avantage sur nous">
# 	                                Qui sommes-nous
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/31-economie-circulaire" title="économie circulaire">
# 	                                Économie circulaire
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/27-choisir-son-materiel" title="Comment bien choisir son matériel ?">
# 	                                Choisir son matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/6-etat-du-materiel" title="Explication de l'état d'usure du matériel en premier, deuxième et troisième choix">
# 	                                État du matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/32-notre-atelier" title="">
# 	                                Notre atelier
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/3-conditions-generales-de-ventes" title="Nos conditions générales de ventes">
# 	                                Conditions générales de ventes
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/5-modes-de-paiement" title="Notre offre de paiement sécurisé">
# 	                                Modes de paiement
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/7-echange-et-retour-produits" title="">
# 	                                Échange et retour produits
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/9-article" title="">
# 	                                Articles
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/26-donnees-personnelles" title="">
# 	                                Données personnelles
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Mon compte</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/mon-compte" title="">
# 	                                Mon compte
# 	                            </a>
# </li>
# </ul>
# </div>
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Catégories</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/106-occasion" title="">
# 	                                Occasion
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/787-destockage-neuf" title="">
# 	                                Déstockage-neuf
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/667-packs" title="">
# 	                                Packs
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/666-recherche-avancee" title="">
# 	                                Recherche avancée
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/fabricants">
# 	                                Toutes nos Marques
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="rb-social-block block links">
# <h3 class="rb-title hidden-sm-down">Follow us</h3>
# <div id="footer_social_block">
# <a href="https://www.facebook.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-facebook-square"></i>
# <span>Facebook</span>
# </a>
# <a href="https://www.instagram.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-instagram"></i>
# <span>Instagram</span>
# </a>
# </div>
# </div>
# <div class="box-footer-html">N°1 du ski occasion en France depuis 30 ans</div>
# <div class="sale-popup flex box-center" data-text1="Acheté il y a " data-text2="minutes"></div>
# </div>
# </div>
# </div>
# </div><!-- end footer-center -->
# <div class="footer-copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-4 col-xs-12 col-sp-12">
# <div class="text-md-left">
# <img alt="Freeglisse.com" class="img-fluid" src="https://freeglisse.com/themes/rb_davici/assets/img/payment.png"/>
# </div>
# </div>
# <div class="col-md-8 col-xs-12 col-sp-12">
# <div class="text-md-right">
# <a class="_blank" href="https://www.nextase.fr" target="_blank">
#                 © 2024 Freeglisse - Par Nextase
#               </a>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-copyright -->
# </div>
# <div class="progress-wrap" id="rb-back-top">
# <a href="#">
# <svg class="progress-circle svg-content" height="100%" viewbox="-1 -1 102 102" width="100%">
# <path d="M50,1 a49,49 0 0,1 0,98 a49,49 0 0,1 0,-98"></path>
# </svg>
# </a>
# </div>
# </footer>
# </main>
# <script src="https://freeglisse.com/themes/rb_davici/assets/cache/bottom-ae2752898.js" type="text/javascript"></script>
# <script type="text/javascript">
#         document.addEventListener('as4PluginReady', function(e) {
#             const as4Plugin = e.detail;
#                             if (typeof(as4Plugin.params[1]) == 'undefined') {
#                     as4Plugin.params[1] = {
#                         hookName: "leftcolumn",
#                         centerColumnCssClasses: "",
#                         availableCriterionsGroups: {"14":"Types de Ski","16":"Votre Pratique","17":"Etat du mat\u00e9riel","6":"Marques","15":"Tailles de Ski","11":"Prix","1":"Fabricant","2":"Fournisseur","3":"Cat\u00e9gories"},
#                         selectedCriterions: {"3":[{"id_criterion":"263","value":"Ski occasion","visible":"1"}]},
#                         stepSearch: 0,
#                         searchMethod: 1,
#                         keep_category_information: 0,
#                         search_results_selector: "#center_column",
#                         insert_in_center_column: 0,
#                         seo_criterion_groups: '',
#                         as4_productFilterListData: '',
#                         as4_productFilterListSource: '',
#                         scrollTopActive: false,
#                         resetURL: "https:\/\/freeglisse.com\/fr\/12-ski-occasion"                    };
#                 }
#
#                                                                         $(document).ready(function() {
#                                 $('#PM_ASBlock_1 .PM_ASResetSearch').html("Retour à Ski occasion");
#                             });
#                                                                                                     as4Plugin.localCacheKey = "fd0652ac67dcdf71787491786bea6c06237caac5";
#                                                                             as4Plugin.localCache = true;
#                                                 as4Plugin.blurEffect = true;
#
#                         as4Plugin.initSearchBlock(1,1,0);
#
#
#                         as4Plugin.initSearchEngine();
#
#                             $(document).ready(function() {
#                                         if (!$('.PM_ASSelectionsResults ul li').length) {
#                         $('.PM_ASSelectionsResults').hide();
#                     }
#                 });
#                     });
#
#                     if (typeof(as4Plugin) !== 'undefined') {
#                 document.dispatchEvent(new CustomEvent('as4PluginReady', { detail: as4Plugin }));
#             }
#             </script>
# <script>
# function ap5_setPackContentData(retryCount) {
# 	if (typeof(retryCount) == 'undefined') {
# 		var retryCount = 0;
# 	}
# 	if (typeof(ap5_cartPackProducts) == 'object') {
# 		let ap5_packContentDataUpdated = false;
# 		for (ap5_uniquePackAttribute in ap5_cartPackProducts) {
# 			$('.product-line-info span:contains("' + ap5_uniquePackAttribute + '"), .product-line-grid span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 			$('#blockcart-modal .modal-body span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 		}
# 		if (!ap5_packContentDataUpdated) {
# 			if (retryCount <= 5) {
# 				retryCount++;
# 				setTimeout(ap5_setPackContentData, 100, retryCount);
# 			}
# 		}
# 	}
# }
#
# document.addEventListener('DOMContentLoaded', function () {
# 	ap5_setPackContentData();
# 	$(document).ajaxSuccess(function() {
# 		ap5_setPackContentData();
# 	});
# 	$(document).on('ap5-After-AddPackToCart', function() {
# 		ap5_setPackContentData();
# 	});
# });
# </script>
# </body>
# </html>

# %% [markdown]
# ## Ciblage sur la balise "h2" et "class":"h3 product-title"

# %%
link = soup.find('h2', {"class":"h3 product-title"}) 
link
# Out:
# <h2 class="h3 product-title"><a content="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm">Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</a></h2>

# %% [markdown]
# ## Ciblage sur la balise "a" et extration du lien "href"

# %%
link.a.get('href')
# Out:
# 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm'

# %% [markdown]
# seconde méthode

# %%
link.find('a', href = True )['href']
# Out:
# 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm'

# %% [markdown]
# ## Mise en place d'une boucle FOR pour extraire tout les url des articles (tout les liens "href")

# %%
article_link = []
for link in soup.find_all('h2', {"class":"h3 product-title"}):
    article_link.append(link.a.get('href'))

# %% [markdown]
# résultat de la boucle

# %%
article_link
# Out:
# ['https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-431270-ski-occasion-rossignol-sender-94-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-434106-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/19115-487602-ski-occasion-rossignol-react-6-compact-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15468-165924-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18999-436272-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/912-taille_skis-170_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15483-167626-ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/18084-388201-ski-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-loisir/18890-430532-ski-occasion-rossignol-nova-6-fixations.html#/9-etat_du_materiel-qualite_b/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/1795-223039-ski-occasion-junior-toutes-marques-a-19-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-pas-cher/16352-299199-ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14329-142844-ski-junior-rossignol-star-wars-occasion-fixations.html#/3-etat_du_materiel-qualite_a/852-taille_skis-110_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13078-299840-ski-occasion-salomon-tous-modeles-a-29-fixations.html#/897-taille_skis-155_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18284-405600-ski-occasion-dynastar-speed-zone-4x4-78-fixations.html#/3-etat_du_materiel-qualite_a/913-taille_skis-171_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14533-141180-ski-occasion-junior-dynastar-team-speed-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18972-434095-ski-de-fond-occasion-rossignol-progress-fixaxion-sns-profil.html#/872-taille_skis-130_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-nnn/18914-431254-ski-de-fond-occasion-fischer-cruiser-crown-fixation-nnn.html#/3-etat_du_materiel-qualite_a/916-taille_skis-174_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13097-299277-ski-occasion-atomic-tous-modele-a-29-fixations.html#/900-taille_skis-158_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18536-418697-ski-occasion-dynastar-legend-x-75-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17203-409334-ski-occasion-k2-thrilluvit-85-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18929-432754-ski-occasion-atomic-cloud-q9-fixations.html#/3-etat_du_materiel-qualite_a/889-taille_skis-147_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18381-411552-ski-occasion-dynastar-speed-zone-4x4-82-fixations.html#/9-etat_du_materiel-qualite_b/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-233190-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13081-299511-ski-occasion-adulte-k2-tous-modeles-a-29-fixations.html#/901-taille_skis-159_cm/1768-etat_du_materiel-qualite_c']

# %%
len(article_link)
# Out:
# 24

# %% [markdown]
# il y a bien 24 articles par pages. La len de "article_link" nous prouve que la boucle a bien fonctionner

# %% [markdown]
# ## Passage a l'obtention de tout les url (d'article) de chaque page

# %% [markdown]
# Reutilisation de morceau de code existant

# %%
temporary_link = []
all_article_link = []
page_number = 1
for i in range(7):
    i = f"https://freeglisse.com/fr/12-ski-occasion?page={page_number}"
    test = requests.get(i)
    test.content
    soup = BeautifulSoup(test.content)
    for link in soup.find_all('h2', {"class":"h3 product-title"}):
        link.a.get('href')
        temporary_link.append(link.a.get('href'))
    all_article_link.extend(temporary_link)
    page_number += 1
    temporary_link = []

# %% [markdown]
# Résultat de la boucle

# %%
all_article_link
# Out:
# ['https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-431270-ski-occasion-rossignol-sender-94-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-434106-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/19115-487602-ski-occasion-rossignol-react-6-compact-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15468-165924-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18999-436272-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html#/912-taille_skis-170_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15483-167626-ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/18084-388201-ski-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-loisir/18890-430532-ski-occasion-rossignol-nova-6-fixations.html#/9-etat_du_materiel-qualite_b/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/1795-223039-ski-occasion-junior-toutes-marques-a-19-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-pas-cher/16352-299199-ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.html#/882-taille_skis-140_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14329-142844-ski-junior-rossignol-star-wars-occasion-fixations.html#/3-etat_du_materiel-qualite_a/852-taille_skis-110_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13078-299840-ski-occasion-salomon-tous-modeles-a-29-fixations.html#/897-taille_skis-155_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18284-405600-ski-occasion-dynastar-speed-zone-4x4-78-fixations.html#/3-etat_du_materiel-qualite_a/913-taille_skis-171_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14533-141180-ski-occasion-junior-dynastar-team-speed-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18972-434095-ski-de-fond-occasion-rossignol-progress-fixaxion-sns-profil.html#/872-taille_skis-130_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-nnn/18914-431254-ski-de-fond-occasion-fischer-cruiser-crown-fixation-nnn.html#/3-etat_du_materiel-qualite_a/916-taille_skis-174_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13097-299277-ski-occasion-atomic-tous-modele-a-29-fixations.html#/900-taille_skis-158_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18536-418697-ski-occasion-dynastar-legend-x-75-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17203-409334-ski-occasion-k2-thrilluvit-85-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-233190-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18929-432754-ski-occasion-atomic-cloud-q9-fixations.html#/3-etat_du_materiel-qualite_a/889-taille_skis-147_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18381-411552-ski-occasion-dynastar-speed-zone-4x4-82-fixations.html#/9-etat_du_materiel-qualite_b/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13081-299511-ski-occasion-adulte-k2-tous-modeles-a-29-fixations.html#/901-taille_skis-159_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-233190-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html#/9-etat_du_materiel-qualite_b/842-taille_skis-100_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16751-404466-ski-occasion-nordica-navigator-85-ca-r-fixations.html#/900-taille_skis-158_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13096-299775-ski-occasion-dynastar-tous-modele-a-29-fixations.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13090-299724-ski-occasion-rossignol-tous-modele-a-29-fixations.html#/902-taille_skis-160_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13083-299626-ski-occasion-volkl-tous-modele-a-29-fixations.html#/905-taille_skis-163_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-femme-performance/15968-186979-ski-occasion-fischer-brilliant-my-turn-fixations.html#/3-etat_du_materiel-qualite_a/887-taille_skis-145_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18966-434041-ski-occasion-rossignol-strato-edition-2023-fixations.html#/3-etat_du_materiel-qualite_a/899-taille_skis-157_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13085-418440-ski-occasion-elan-tous-modele-a-29-fixations.html#/894-taille_skis-152_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14483-407993-ski-occasion-junior-tecnopro-team-pulse-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12512-414388-ski-occasion-junior-head-supershape-fixations.html#/862-taille_skis-120_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/18333-408405-ski-occasion-junior-dynastar-slider-fixations.html#/9-etat_du_materiel-qualite_b/858-taille_skis-116_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/18382-411588-ski-occasion-armada-arv-84-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/18415-414338-ski-occasion-kastle-fx-96-fixations.html#/9-etat_du_materiel-qualite_b/914-taille_skis-172_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18638-419473-ski-occasion-head-kore-93-w-fixations.html#/9-etat_du_materiel-qualite_b/895-taille_skis-153_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18548-415006-ski-occasion-junior-salomon-s-race-jr-fixations.html#/862-taille_skis-120_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/13390-401256-ski-occasion-volkl-rtm-74-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-performance/17653-327152-ski-occasion-rossignol-nova-8-ca-2022-fixations.html#/3-etat_du_materiel-qualite_a/884-taille_skis-142_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17099-293278-ski-occasion-dynastar-intense-4x4-78-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/14269-141103-ski-occasion-junior-tecnopro-team-pulse-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18668-421709-ski-occasion-nordica-dobermann-spitfire-crx-fixations.html#/894-taille_skis-152_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-freeride-freestyle/11479-84387-ski-occasion-junior-nordica-ace-of-spades-fixations.html#/3-etat_du_materiel-qualite_a/860-taille_skis-118_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/14701-147909-ski-occasion-atomic-punx-5-fixations.html#/9-etat_du_materiel-qualite_b/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/11947-407100-ski-occasion-dynastar-speed-zone-16-ti-fixations.html#/9-etat_du_materiel-qualite_b/900-taille_skis-158_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/16762-276358-ski-occasion-rossignol-experience-74-fixations.html#/3-etat_du_materiel-qualite_a/886-taille_skis-144_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18336-409117-ski-occasion-elan-gsx-pro-fixations.html#/3-etat_du_materiel-qualite_a/907-taille_skis-165_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18917-431288-ski-occasion-rossignol-experience-86-basalt-2023-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/10713-70579-ski-occasion-rossignol-9-gs-worldcup-ti-fixations.html#/9-etat_du_materiel-qualite_b/910-taille_skis-168_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/12420-408370-ski-occasion-junior-dynastar-team-cham-fixations.html#/9-etat_du_materiel-qualite_b/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/12945-295650-ski-occasion-head-shape-tx-fixations.html#/912-taille_skis-170_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/13805-123243-ski-occasion-rossignol-radical-9-gs-worldcup-ti-fixations.html#/9-etat_du_materiel-qualite_b/922-taille_skis-180_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/14076-396715-ski-occasion-nordica-dobermann-spitfire-pro-fixations.html#/9-etat_du_materiel-qualite_b/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/16555-274925-ski-occasion-elan-sling-shot-fixations.html#/898-taille_skis-156_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/12615-95539-ski-occasion-rossignol-experience-75-carbon-fixations.html#/9-etat_du_materiel-qualite_b/894-taille_skis-152_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/14644-143743-ski-occasion-dynastar-cham-87-fixations.html#/3-etat_du_materiel-qualite_a/914-taille_skis-172_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-freeride-freestyle/17817-367550-ski-occasion-junior-salomon-shogun-jr-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18174-404520-ski-occasion-dynastar-speed-zone-10-ti-fixations.html#/3-etat_du_materiel-qualite_a/909-taille_skis-167_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/18429-415028-ski-occasion-volkl-revolt-95-fixation.html#/923-taille_skis-181_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17758-358877-ski-occasion-fischer-rc4-the-curv-fixations.html#/3-etat_du_materiel-qualite_a/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17058-295001-ski-occasion-nordica-transfire-rtx-fixations.html#/3-etat_du_materiel-qualite_a/902-taille_skis-160_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-performance/18922-431336-ski-occasion-rossignol-nova-8-ca-2023-fixations.html#/3-etat_du_materiel-qualite_a/884-taille_skis-142_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13088-418516-ski-occasion-movement-tous-modele-a-29-fixations.html#/902-taille_skis-160_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18598-419173-ski-occasion-elan-amphibio-84-ti-fixations.html#/9-etat_du_materiel-qualite_b/924-taille_skis-182_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/16762-276358-ski-occasion-rossignol-experience-74-fixations.html#/3-etat_du_materiel-qualite_a/886-taille_skis-144_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-skating-norme-sns/18996-435952-ski-de-fond-occasion-junior-fischer-rcr-skatecut-fixation-sns-pilot.html#/3-etat_du_materiel-qualite_a/884-taille_skis-142_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/15181-156922-ski-occasion-head-rev-78-fixations.html#/9-etat_du_materiel-qualite_b/900-taille_skis-158_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18550-418812-ski-occasion-atomic-performer-xt-fixations.html#/891-taille_skis-149_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/15216-400333-ski-occasion-dynastar-speed-zone-06-fixations.html#/9-etat_du_materiel-qualite_b/893-taille_skis-151_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14637-146788-ski-occasion-atomic-vantage-86c-fixations.html#/9-etat_du_materiel-qualite_b/915-taille_skis-173_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18598-419173-ski-occasion-elan-amphibio-84-ti-fixations.html#/9-etat_du_materiel-qualite_b/924-taille_skis-182_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/12420-408370-ski-occasion-junior-dynastar-team-cham-fixations.html#/9-etat_du_materiel-qualite_b/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18917-431288-ski-occasion-rossignol-experience-86-basalt-2023-fixations.html#/3-etat_du_materiel-qualite_a/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/10713-70579-ski-occasion-rossignol-9-gs-worldcup-ti-fixations.html#/9-etat_du_materiel-qualite_b/910-taille_skis-168_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/16555-274925-ski-occasion-elan-sling-shot-fixations.html#/898-taille_skis-156_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/18501-417309-ski-occasion-volkl-revolt-95-fixations.html#/923-taille_skis-181_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18649-419811-ski-occasion-fischer-my-pro-mt-80-fixations.html#/9-etat_du_materiel-qualite_b/901-taille_skis-159_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18266-405863-ski-occasion-junior-fischer-rc4-worldcup-gs-fixations.html#/9-etat_du_materiel-qualite_b/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/15051-298781-ski-occasion-rossignol-temptation-style-fixations.html#/3-etat_du_materiel-qualite_a/896-taille_skis-154_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/16860-282918-ski-occasion-dps-foundation-uschi-87-fixations.html#/9-etat_du_materiel-qualite_b/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/10686-69988-ski-occasion-scott-luna-fixations.html#/3-etat_du_materiel-qualite_a/908-taille_skis-166_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18881-430410-ski-occasion-fischer-my-curv-fixations.html#/3-etat_du_materiel-qualite_a/899-taille_skis-157_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18213-404771-ski-occasion-junior-blizzard-racing-gs-fixations.html#/872-taille_skis-130_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18654-419845-ski-occasion-elan-delight-prime-fixations.html#/906-taille_skis-164_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12493-413635-ski-occasion-junior-head-supershape-era-20-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/17445-298545-ski-occasion-movement-go-fast-fixation.html#/3-etat_du_materiel-qualite_a/927-taille_skis-185_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17116-295667-ski-occasion-rossignol-pursuit-600-cam-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-loisir/17164-416904-ski-occasion-fischer-my-mt-xtr-77-fixations.html#/9-etat_du_materiel-qualite_b/887-taille_skis-145_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14344-477053-ski-occasion-movement-jam-er-fixation.html#/3-etat_du_materiel-qualite_a/924-taille_skis-182_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/15991-420978-ski-occasion-head-ishape-rush-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/15190-158454-ski-occasion-rossignol-strato-st-fixations.html#/9-etat_du_materiel-qualite_b/903-taille_skis-161_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/15989-407263-ski-occasion-dynastar-legend-94-fixations.html#/9-etat_du_materiel-qualite_b/931-taille_skis-189_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18549-418801-ski-occasion-dps-cassiar-foundation-f82-fixations.html#/9-etat_du_materiel-qualite_b/910-taille_skis-168_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12473-93498-ski-occasion-junior-volkl-racetiger-sl-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14344-477053-ski-occasion-movement-jam-er-fixation.html#/3-etat_du_materiel-qualite_a/924-taille_skis-182_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14380-143870-ski-occasion-scott-slight-83-fixations.html#/9-etat_du_materiel-qualite_b/920-taille_skis-178_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16815-420131-ski-occasion-kastle-mx-84-fixations.html#/918-taille_skis-176_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/11927-406970-ski-occasion-salomon-x-wing-8-fixations.html#/902-taille_skis-160_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18549-418801-ski-occasion-dps-cassiar-foundation-f82-fixations.html#/9-etat_du_materiel-qualite_b/910-taille_skis-168_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18439-477400-ski-occasion-dynastar-m-freeski-fixations.html#/3-etat_du_materiel-qualite_a/928-taille_skis-186_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/13566-118791-ski-occasion-kastle-mx-83-fixations.html#/9-etat_du_materiel-qualite_b/925-taille_skis-183_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/10867-397980-ski-occasion-atomic-redster-g9-fixations.html#/913-taille_skis-171_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/11431-404137-ski-occasion-volant-pulse-white-fixations.html#/9-etat_du_materiel-qualite_b/891-taille_skis-149_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/10938-74016-ski-occasion-salomon-x-max-x10-fixations.html#/3-etat_du_materiel-qualite_a/918-taille_skis-176_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/13052-158653-ski-occasion-lacroix-lx-gravity-fixations.html#/3-etat_du_materiel-qualite_a/897-taille_skis-155_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/14608-477022-ski-occasion-atomic-redster-s9-fixations.html#/907-taille_skis-165_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/15190-158454-ski-occasion-rossignol-strato-st-fixations.html#/9-etat_du_materiel-qualite_b/903-taille_skis-161_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/15991-420978-ski-occasion-head-ishape-rush-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/16426-399653-ski-occasion-head-worldcup-rebels-irace-fixations.html#/9-etat_du_materiel-qualite_b/922-taille_skis-180_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/14061-396637-ski-occasion-nordica-dobermann-spitfire-crx-fixations.html#/902-taille_skis-160_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/16753-274876-ski-occasion-fischer-rc-one-77-xtr-fixation.html#/9-etat_du_materiel-qualite_b/913-taille_skis-171_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/11422-467942-ski-occasion-dynastar-cr-74-fixations.html#/920-taille_skis-178_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17116-295667-ski-occasion-rossignol-pursuit-600-cam-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/16860-282918-ski-occasion-dps-foundation-uschi-87-fixations.html#/9-etat_du_materiel-qualite_b/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17170-477398-ski-occasion-atomic-redster-g9-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17209-416890-ski-occasion-head-supershape-imagnum-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17263-293817-ski-occasion-head-v-shape-lyt-v10-fixations.html#/9-etat_du_materiel-qualite_b/919-taille_skis-177_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/17975-400383-ski-occasion-fischer-rc4-worldcup-sc-fixations.html#/3-etat_du_materiel-qualite_a/897-taille_skis-155_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18363-408937-ski-occasion-lacroix-pure-fixations.html#/3-etat_du_materiel-qualite_a/888-taille_skis-146_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18398-414180-ski-occasion-fischer-brilliant-the-curv-fixations.html#/9-etat_du_materiel-qualite_b/920-taille_skis-178_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18670-421729-ski-occasion-head-prestige-fixations.html#/9-etat_du_materiel-qualite_b/905-taille_skis-163_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18674-421770-ski-occasion-fischer-rc4-my-curv-fixations.html#/3-etat_du_materiel-qualite_a/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18685-421981-ski-occasion-kastle-rx-12-sl-fixations.html#/3-etat_du_materiel-qualite_a/897-taille_skis-155_cm',
#  'https://freeglisse.com/fr/ski-occasion-adulte-performance/18881-430410-ski-occasion-fischer-my-curv-fixations.html#/3-etat_du_materiel-qualite_a/899-taille_skis-157_cm',
#  'https://freeglisse.com/fr/ski-test-all-mountain/15020-158540-ski-test-kastle-fx-95-fixations.html#/3-etat_du_materiel-qualite_a/899-taille_skis-157_cm',
#  'https://freeglisse.com/fr/ski-test-all-mountain/16856-274166-ski-test-zag-h-96-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm',
#  'https://freeglisse.com/fr/ski-test-all-mountain/17433-298196-ski-test-zag-h-105-fixations.html#/3-etat_du_materiel-qualite_a/924-taille_skis-182_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/15234-401520-ski-occasion-k2-pinnacle-95-fixation.html#/9-etat_du_materiel-qualite_b/933-taille_skis-191_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/15989-407263-ski-occasion-dynastar-legend-94-fixations.html#/9-etat_du_materiel-qualite_b/931-taille_skis-189_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/17445-298545-ski-occasion-movement-go-fast-fixation.html#/3-etat_du_materiel-qualite_a/927-taille_skis-185_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/17516-408694-ski-occasion-volkl-kendo-88-fixations.html#/919-taille_skis-177_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-freeride/17518-305673-ski-occasion-salomon-rocker-fixations.html#/3-etat_du_materiel-qualite_a/934-taille_skis-192_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/17648-477401-ski-occasion-rossignol-blackops-sender-2022-fixations.html#/3-etat_du_materiel-qualite_a/936-taille_skis-194_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/18391-413676-ski-occasion-rossignol-sky-7-hd-w-fixations.html#/3-etat_du_materiel-qualite_a/898-taille_skis-156_cm',
#  'https://freeglisse.com/fr/ski-occasion-freeride/18356-410500-ski-occasion-exonde-xo-97-v31-fixations.html#/3-etat_du_materiel-qualite_a/926-taille_skis-184_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/16913-406122-ski-occasion-dynastar-menace-90-fixations.html#/3-etat_du_materiel-qualite_a/882-taille_skis-140_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/17545-410503-ski-occasion-armada-el-rey-fixations.html#/9-etat_du_materiel-qualite_b/899-taille_skis-157_cm',
#  'https://freeglisse.com/fr/ski-occasion-freestyle/18501-417309-ski-occasion-volkl-revolt-95-fixations.html#/923-taille_skis-181_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/12455-286955-ski-occasion-junior-wedze-team-onebreaker-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/16851-481609-ski-occasion-junior-tecnopro-flyte-jr-fixations.html#/3-etat_du_materiel-qualite_a/892-taille_skis-150_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/17002-480398-ski-occasion-junior-volkl-rtm-jr-fixations.html#/3-etat_du_materiel-qualite_a/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-loisir/18613-399745-ski-occasion-junior-fischer-stunner-fixations.html#/893-taille_skis-151_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12473-93498-ski-occasion-junior-volkl-racetiger-sl-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12493-413635-ski-occasion-junior-head-supershape-era-20-fixations.html#/9-etat_du_materiel-qualite_b/862-taille_skis-120_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/12566-378892-ski-occasion-junior-dynastar-team-course-wc-fixations.html#/907-taille_skis-165_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/14324-408318-ski-occasion-junior-rossignol-hero-junior-pro-multi-event-fixations.html#/3-etat_du_materiel-qualite_a/852-taille_skis-110_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/14557-286076-ski-occasion-junior-dynastar-team-course-wc-fixations.html#/900-taille_skis-158_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18213-404771-ski-occasion-junior-blizzard-racing-gs-fixations.html#/872-taille_skis-130_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18266-405863-ski-occasion-junior-fischer-rc4-worldcup-gs-fixations.html#/9-etat_du_materiel-qualite_b/872-taille_skis-130_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/18309-406279-ski-occasion-junior-volkl-racetiger-gs-fixations.html#/892-taille_skis-150_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/16441-414362-ski-occasion-junior-head-team-supershape-era-20-fixations.html#/859-taille_skis-117_cm/1768-etat_du_materiel-qualite_c',
#  'https://freeglisse.com/fr/ski-de-rando-occasion-et-fin-de-serie/18871-429531-ski-occasion-rando-pack-dynastar-cham-alti-85-fixation-look-hm-12.html#/9-etat_du_materiel-qualite_b/920-taille_skis-178_cm',
#  'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/17488-437370-ski-de-fond-occasion-junior-salomon-skin-race-fixation-sns-access.html#/3-etat_du_materiel-qualite_a/877-taille_skis-135_cm',
#  'https://freeglisse.com/fr/ski-occasion-femme-loisir/15097-157595-ski-occasion-head-full-joy-fixations.html#/3-etat_du_materiel-qualite_a/885-taille_skis-143_cm',
#  'https://freeglisse.com/fr/ski-occasion-junior-performance/14184-136072-ski-occasion-junior-elan-race-rc-waveflex-fixations.html#/3-etat_du_materiel-qualite_a/862-taille_skis-120_cm']

# %%
len(all_article_link)
# Out:
# 157

# %% [markdown]
# La boucle fonctionne bien il y a bien 158 articles au moment de l'éxecution

# %% [markdown]
# ## Extraction du détail produit

# %%
first_article = requests.get("https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm")
first_article.content
# Out:
# b'<!doctype html>\n<html lang="fr-FR">\n\n  <head>\n    \n      \n  <meta charset="utf-8">\n\n\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\n\n  <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>\n  \n    \n  \n  <meta name="description" content="De la poudreuse \xc3\xa0 la neige tass\xc3\xa9e, le nouveau Sender 104 Ti est l\xe2\x80\x99arme absolue pour dompter toute la montagne. Sa facilit\xc3\xa9 et sa r\xc3\xa9activit\xc3\xa9 permettent d\xe2\x80\x99aller s">\n  <meta name="keywords" content="">\n        <link rel="canonical" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html">\n    \n          <link rel="alternate" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr">\n          <link rel="alternate" href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de">\n          <link rel="alternate" href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en">\n          <link rel="alternate" href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es">\n          <link rel="alternate" href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it">\n      \n  \n  \n    <script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "Organization",\n    "name" : "Freeglisse.com",\n    "url" : "https://freeglisse.com/fr/",\n    "logo": {\n      "@type": "ImageObject",\n      "url":"https://freeglisse.com/img/logo-1668007595.jpg"\n    }\n  }\n</script>\n\n<script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "WebPage",\n    "isPartOf": {\n      "@type": "WebSite",\n      "url":  "https://freeglisse.com/fr/",\n      "name": "Freeglisse.com"\n    },\n    "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n    "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"\n  }\n</script>\n\n\n  <script type="application/ld+json">\n    {\n      "@context": "https://schema.org",\n      "@type": "BreadcrumbList",\n      "itemListElement": [\n                      {\n              "@type": "ListItem",\n              "position": 1,\n              "name": "Accueil",\n              "item": "https://freeglisse.com/fr/"\n              },                        {\n              "@type": "ListItem",\n              "position": 2,\n              "name": "Occasion",\n              "item": "https://freeglisse.com/fr/106-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 3,\n              "name": "Ski occasion",\n              "item": "https://freeglisse.com/fr/12-ski-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 4,\n              "name": "Ski occasion adulte freeride et freestyle",\n              "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"\n              },                        {\n              "@type": "ListItem",\n              "position": 5,\n              "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n              "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"\n              }            ]\n          }\n  </script>\n  \n  \n  \n  <script type="ap ...

# %% [markdown]
# ## mise en soup

# %%
soup_first_article = BeautifulSoup(first_article.content)
soup_first_article
# Out:
# <!DOCTYPE html>
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" name="description"/>
# <meta content="" name="keywords"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" rel="canonical"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr" rel="alternate"/>
# <link href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de" rel="alternate"/>
# <link href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en" rel="alternate"/>
# <link href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es" rel="alternate"/>
# <link href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it" rel="alternate"/>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "name" : "Freeglisse.com",
#     "url" : "https://freeglisse.com/fr/",
#     "logo": {
#       "@type": "ImageObject",
#       "url":"https://freeglisse.com/img/logo-1668007595.jpg"
#     }
#   }
# </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "WebPage",
#     "isPartOf": {
#       "@type": "WebSite",
#       "url":  "https://freeglisse.com/fr/",
#       "name": "Freeglisse.com"
#     },
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"
#   }
# </script>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement": [
#                       {
#               "@type": "ListItem",
#               "position": 1,
#               "name": "Accueil",
#               "item": "https://freeglisse.com/fr/"
#               },                        {
#               "@type": "ListItem",
#               "position": 2,
#               "name": "Occasion",
#               "item": "https://freeglisse.com/fr/106-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 3,
#               "name": "Ski occasion",
#               "item": "https://freeglisse.com/fr/12-ski-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 4,
#               "name": "Ski occasion adulte freeride et freestyle",
#               "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"
#               },                        {
#               "@type": "ListItem",
#               "position": 5,
#               "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#               "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"
#               }            ]
#           }
#   </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "description": "De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s",
#     "category": "Ski occasion adulte freeride et freestyle",
#     "image" :"https://freeglisse.com/70892-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg",    "sku": "m33",
#     "mpn": "m33",
#         "brand": {
#       "@type": "Thing",
#       "name": "Rossignol"
#     },              "weight": {
#         "@context": "https://schema.org",
#         "@type": "QuantitativeValue",
#         "value": "6.000000",
#         "unitCode": "kg"
#       },                "offers": {
#             "@type": "Offer",
#             "priceCurrency": "EUR",
#             "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#             "price": "335.2",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm",
#             "priceValidUntil": "2024-06-18",
#                           "image": ["https://freeglisse.com/70892-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70929-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70930-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg"],
#                         "sku": "m33",
#             "mpn": "m33",
#                                                                                         "availability": "https://schema.org/InStock",
#             "seller": {
#               "@type": "Organization",
#               "name": "Freeglisse.com"
#             }
#           }
#                 }
# </script>
# <meta content="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations" property="og:title"/>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" property="og:description"/>
# <meta content="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" property="og:url"/>
# <meta content="Freeglisse.com" property="og:site_name"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://freeglisse.com/themes/rb_davici/assets/cache/theme-24ff1d899.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var ASSearchUrl = "https:\/\/freeglisse.com\/fr\/module\/pm_advancedsearch4\/advancedsearch4";
#         var PAYPLUG_DOMAIN = "https:\/\/secure.payplug.com";
#         var RB_Meta = {"v":"1.0.0"};
#         var active = "0";
#         var ap5_cartPackProducts = [];
#         var ap5_modalErrorClose = "Fermer";
#         var ap5_modalErrorTitle = "Une erreur est survenue";
#         var as4_orderBySalesAsc = "Meilleures ventes en dernier";
#         var as4_orderBySalesDesc = "Meilleures ventes en premier";
#         var cancel_rating_txt = "Cancel Rating";
#         var collections = ["<a href='https:\/\/freeglisse.com\/fr\/ski-de-rando-occasion-et-fin-de-serie\/13544-ski-randonnee-occasion-atomic-betaride-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/34081-home_default\/ski-randonnee-occasion-atomic-betaride-fixations.jpg' alt='Ski randonn\u00e9e occasion Atomic Betaride + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-de-rando-occasion-et-fin-de-serie\/13544-ski-randonnee-occasion-atomic-betaride-fixations.html' title='Ski randonn\u00e9e occasion Atomic Betaride + fixations'>Ski randonn\u00e9e occasion Atomic Betaride + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-test-all-mountain\/17429-ski-test-rossignol-experience-80-ci-w-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/54210-home_default\/ski-test-rossignol-experience-80-ci-w-fixations.jpg' alt='Ski test Rossignol Experience 80 CI W + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-test-all-mountain\/17429-ski-test-rossignol-experience-80-ci-w-fixations.html' title='Ski test Rossignol Experience 80 CI W + fixations'>Ski test Rossignol Experience 80 CI W + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-pas-cher\/11746-ski-occasion-dynastar-d-stinct-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/26749-home_default\/ski-occasion-dynastar-d-stinct-fixations.jpg' alt='Ski occasion Dynastar D'Stinct + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-pas-cher\/11746-ski-occasion-dynastar-d-stinct-fixations.html' title='Ski occasion Dynastar D'Stinct + fixations'>Ski occasion Dynastar D'Stinct + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-freestyle\/12289-ski-occasion-wedze-twintricks-proteam-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/28393-home_default\/ski-occasion-wedze-twintricks-proteam-fixations.jpg' alt='Ski occasion Wedze Twintricks ProTeam + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-freestyle\/12289-ski-occasion-wedze-twintricks-proteam-fixations.html' title='Ski occasion Wedze Twintricks ProTeam + fixations'>Ski occasion Wedze Twintricks ProTeam + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-freeride\/12632-ski-occasion-elan-apex-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/30681-home_default\/ski-occasion-elan-apex-fixations.jpg' alt='Ski occasion Elan Apex + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-freeride\/12632-ski-occasion-elan-apex-fixations.html' title='Ski occasion Elan Apex + fixations'>Ski occasion Elan Apex + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/14629-ski-occasion-atomic-vantage-90-cti-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/39582-home_default\/ski-occasion-atomic-vantage-90-cti-fixations.jpg' alt='Ski occasion Atomic Vantage 90 cti + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/14629-ski-occasion-atomic-vantag ...
#         var hirEnableMailalert = false;
#         var isLogged = false;
#         var is_sandbox_mode = false;
#         var module_name = "payplug";
#         var payplug_ajax_url = "https:\/\/freeglisse.com\/fr\/module\/payplug\/ajax";
#         var payplug_oney = true;
#         var payplug_oney_loading_msg = "Chargement";
#         var pm_advancedpack = {"ajaxUrl":"https:\/\/freeglisse.com\/fr\/module\/pm_advancedpack\/ajax","staticToken":"0cc26bc1e7fc2c1dd6f4c3106c8304e3"};
#         var popup = "<div\n\tclass=\"rb-popup-container\"\n\tstyle=\"width:770px;\n\theight:460px;\tbackground-image: url('\/modules\/rbthemefunction\/\/views\/img\/imgbg_1.jpg');\tbackground-position: center\"\n>\n\t<div class=\"rb-popup-flex\">\n\t\t<div id=\"rb_newsletter_popup\" class=\"rb-block\">\n\t\t\t<div class=\"rb-block-content\">\n\t\t\t\t<form action=\"\" method=\"POST\">\n\t\t\t\t\t<div class=\"rb-popup-text\">\n    \t\t\t\t\t<h2>Soyez le premier inform\u00e9<\/h2>\n<p>Abonnez-vous pour les derni\u00e8res nouvelles et obtenez 5\u20ac de r\u00e9duction sur votre premi\u00e8re commande.<\/p>\n                    <\/div>\n\n                    \t                    <div class=\"rb-relative-input relative\">\n\t                    \t<span class=\"rb-your-email\">\n\t\t\t\t\t\t\t\t<input class=\"inputNew\" id=\"rb-newsletter-popup\" type=\"email\" name=\"email\" required=\"\" value=\"\" placeholder=\"votre@email.com\" \/>\n\t\t\t\t\t\t\t<\/span>\n\t                    \t<button class=\"rb-send-email\">\n\t                    \t\t<i class=\"material-icons\">trending_flat<\/i>\n\t\t\t\t\t\t\t\tS'inscrire\n\t                    \t<\/button>\n\t                    <\/div>\n\n\t                    <div class=\"rb-email-alert\">\n\t                    \t<div class=\"cssload-container rb-ajax-loading\">\n\t<div class=\"cssload-double-torus\"><\/div>\n<\/div>\t                    \t<p class=\"rb-email rb-email-success alert alert-success\"><\/p>\n\t                    \t<p class=\"rb-email rb-email-error alert alert-danger\"><\/p>\n\t                    <\/div>\n                    \t\t\t\t<\/form>\n\t\t\t<\/div>\n\t\t<\/div>\n\t<\/div>\n<\/div>";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"Total","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Total TTC","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Total HT :","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Sous-total","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Livraison","amount":0,"value":""},"tax":null},"products_count":0,"summary_string":"0 articles","vouchers":{"allowed":1,"added":[]},"discounts":[{"id_cart_rule":"2404","id_customer":"0","date_from":"2018-06-18 13:00:00","date_to":"2028-07-18 13:00:00","description":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity":"994653","quantity_per_user":"100000","priority":"1","partial_use":"1","code":"","minimum_amount":"199.000000","minimum_amount_tax":"1","minimum_amount_currency":"1","minimum_amount_shipping":"0","country_restriction":"1","carrier_restriction":"1","group_restriction":"0","cart_rule_restriction":"0","product_restriction":"0","shop_restriction":"0","free_shipping":"1","reduction_percent":"0.00","reduction_exclude_special":"0","reduction_amount":"0.000000","reduction_tax":"0","reduction_currency":"1","reduction_product":"0","gift_product":"0","gift_product_attribute":"0","highlight":"1","active":"1","date_add":"2018-06-18 13:41:03","date_upd":"2024-05-11 09:59:40","id_lang":"1","name":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity_for_user":100000}],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"Fran\u00e7ais (French)","iso_code":"fr","locale":"fr-FR","language_code":"fr-fr","is_rtl":"0","date_format_lite":"d\/m\/Y","date_format_full":"d\/m\/Y H:i:s","id":1},"page":{"title":"","canonical":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","meta":{"title":"Ski occasion Rossignol Sender 104 Ti 2023  + Fixations","description":"De la poudreuse \u00e0 la neige tass\u00e9e, le nouveau Sender 104 Ti est l\u2019arme absolue pour dompter toute la montagne. Sa facilit\u00e9 et sa r\u00e9activit\u00e9 permettent d\u2019aller s","keywords":"","robots":"index"},"page_name":"product","body_classes":{"lang-fr":true,"lang-rtl":false,"country-FR":true,"currency-EUR":true,"layout-full-width":true,"page-product":true,"tax-display-enabled":true,"product-id-18916":true,"product-Ski occasion Rossignol Sender 104 Ti 2023  + Fixations":true,"product-id-category-606":true,"product-id-manufacturer-135":true,"product-id-supplier-0":true,"product-available-for-order":true,"product-customizable":true},"admin_notifications":[]},"shop":{"name":"Freeglisse.com","logo":"https:\/\/freeglisse.com\/img\/logo-1668007595.jpg","stores_icon":"https:\/\/freeglisse.com\/img\/ski-destock-logo_stores-1569515187.gif","favicon":"https:\/\/freeglisse.com\/img\/favicon.ico"},"urls":{"base_url":"https:\/\/freeglisse.com\/","current_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","shop_domain_url":"https:\/\/freeglisse.com","img_ps_url":"https:\/\/freeglisse.com\/img\/","img_cat_url":"https:\/\/freeglisse.com\/img\/c\/","img_lang_url":"https:\/\/freeglisse.com\/img\/l\/","img_prod_url":"https:\/\/freeglisse.com\/img\/p\/","img_manu_url":"https:\/\/freeglisse.com\/img\/m\/","img_sup_url":"https:\/\/freeglisse.com\/img\/su ...
#         var probance_wt = {"id":null,"wt_token":"LivB9s6KennjnoG","id_type":"customer_email","id_product":"18916","api_url":"t4.my-probance.one","customer_prefix":"","product_prefix":"","debug":"0"};
#         var psemailsubscription_subscription = "https:\/\/freeglisse.com\/fr\/module\/ps_emailsubscription\/subscription";
#         var psr_icon_color = "#F19D76";
#         var rbFrontendConfig = {"isEditMode":"","stretchedSectionContainer":"","is_rtl":"","rb_day":"Days"};
#         var rb_days = "Days";
#         var rb_facebook = {"general_appid":"1671479023110588","general_pageid":"2005509456220113","chat_state":"0","chat_color":"","chat_delay":"12","login_state":"0","login_redirect":"no_redirect","comments_state":"0","comments_tab":"0","comments_width":"","comments_number":"","comments_admins":"","product_page_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","login_destination":"https:\/\/freeglisse.com\/fr\/mon-compte","phrases":{"login":"Se connecter"}};
#         var rb_height = "460";
#         var rb_hours = "Hours";
#         var rb_minutes = "Minutes";
#         var rb_modal = "<div class=\"modal-content\">\n\t<div class=\"modal-header\">\n\t\t<h5 class=\"modal-title text-xs-center\">\n\t\t\tDelete selected item ?\n\t\t<\/h5>\n\t<\/div>\n\n\t<div class=\"modal-footer\">\n\t\t<button type=\"button\" class=\"rb-modal-no rb-modal-accept btn btn-primary\" data-dismiss=\"modal\">\n\t\t\tAnnuler\n\t\t<\/button>\n\n\t\t<button type=\"button\" class=\"rb-modal-yes rb-modal-accept btn btn-primary\">\n\t\t\tOK\n\t\t<\/button>\n\t<\/div>\n<\/div>";
#         var rb_seconds = "Seconds";
#         var rb_slick = {"active":"1","slideshow":"4","slidesToScroll":"1","autoplay":"0","autospeed":""};
#         var rb_text = "You must be logged. <a href=\"https:\/\/freeglisse.com\/fr\/authentification\">Connexion<\/a>";
#         var rb_view = "1";
#         var rb_width = "770";
#         var rb_zoom = {"active":"1","type":"2","scroll":"1"};
#         var recaptcha_position_contact_us = "inline";
#         var recaptcha_position_login = "";
#         var recaptcha_position_mailalert = "";
#         var recaptcha_position_newsletter = "";
#         var recaptcha_position_password = "";
#         var recaptcha_position_productcomment = "";
#         var recaptcha_position_registration = "";
#         var text1 = "No Product";
#         var text2 = "You Can Not Delete Default Wishlist";
#         var token = "0cc26bc1e7fc2c1dd6f4c3106c8304e3";
#         var url_ajax = "https:\/\/freeglisse.com\/fr\/module\/rbthemefunction\/ajax";
#         var url_compare = "https:\/\/freeglisse.com\/fr\/compare";
#         var url_wishlist = "https:\/\/freeglisse.com\/fr\/wishlist";
#       </script>
# <style>.rb_megamenu .rb_menus_li h4,
# .rb_megamenu .rb_menus_li h5,
# .rb_megamenu .rb_menus_li h6,
# .rb_megamenu .rb_menus_li h1,
# .rb_megamenu .rb_menus_li h2,
# .rb_megamenu .rb_menus_li h3,
# .rb_megamenu .rb_menus_li h4 *:not(i),
# .rb_megamenu .rb_menus_li h5 *:not(i),
# .rb_megamenu .rb_menus_li h6 *:not(i),
# .rb_megamenu .rb_menus_li h1 *:not(i),
# .rb_megamenu .rb_menus_li h2 *:not(i),
# .rb_megamenu .rb_menus_li h3 *:not(i),
# .rb_megamenu .rb_menus_li > a{
#     font-family: inherit;
# }
# .rb_megamenu *:not(.fa):not(i){
#     font-family: inherit;
# }
#
# .rb_block *{
#     font-size: px;
# }
#
# @media (min-width: 768px){
# /*layout 1*/
#     .rb_megamenu.layout_layout1{
#         background: ;
#     }
#     .layout_layout1 .rb_megamenu_content{
#       background: linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -webkit-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -o-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#     }
#     .rb_megamenu.layout_layout1:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout1 .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item *{
#         color:
#     }
#     .layout_layout1 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1 .rb_menus_li.active > a,
#     #header .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1:hover .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout1 .rb_menus_li.active > a{
#         color: ;
#     }
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a:before,
#     .layout_layout1.ybc_vertical_menu:hover .ybc-menu-vertical-button:before,
#     .layout_layout1:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar,
#     .ybc-menu-vertical-button.layout_layout1:hover{background-color: ;}
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover,
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover{
#         background: ;
#     }
#
#     .layout_layout1.rb_megamenu .rb_columns_ul,
#     .layout_layout1.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout1 .rb_block_content a,
#     #header .layout_layout1 .rb_block_content p,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout1 .rb_columns_ul h1,
#     .layout_layout1 .rb_columns_ul h2,
#     .layout_layout1 .rb_columns_ul h3,
#     .layout_layout1 .rb_columns_ul h4,
#     .layout_layout1 .rb_columns_ul h5,
#     .layout_layout1 .rb_columns_ul h6,
#     .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout1 .rb_columns_ul .h1,
#     .layout_layout1 .rb_columns_ul .h2,
#     .layout_layout1 .rb_columns_ul .h3,
#     .layout_layout1 .rb_columns_ul .h4,
#     .layout_layout1 .rb_columns_ul .h5,
#     .layout_layout1 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1 li:hover > a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{color: ;}
#
#
# /*end layout 1*/
#
#
#     /*layout 2*/
#     .rb_megamenu.layout_layout2{
#         background-color: ;
#     }
#
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout2 .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item *{
#         color:
#     }
#     .layout_layout2 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:hover .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a{color: ;}
#
#     .layout_layout2:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout2.ybc_vertical_menu:hover{
#         background-color: ;
#     }
#
#     .layout_layout2.rb_megamenu .rb_columns_ul,
#     .layout_layout2.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout2 .rb_block_content a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout2 .rb_columns_ul h1,
#     .layout_layout2 .rb_columns_ul h2,
#     .layout_layout2 .rb_columns_ul h3,
#     .layout_layout2 .rb_columns_ul h4,
#     .layout_layout2 .rb_columns_ul h5,
#     .layout_layout2 .rb_columns_ul h6,
#     .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout2 .rb_columns_ul .h1,
#     .layout_layout2 .rb_columns_ul .h2,
#     .layout_layout2 .rb_columns_ul .h3,
#     .layout_layout2 .rb_columns_ul .h4,
#     .layout_layout2 .rb_columns_ul .h5,
#     .layout_layout2 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 li:hover > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#
#
#     /*layout 3*/
#     .rb_megamenu.layout_layout3,
#     .layout_layout3 .rb_tab_li_content{
#         background-color: ;
#
#     }
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout3 .ybc-menu-vertical-button,
#     .layout_layout3 .rb_extra_item *{
#         color:
#     }
#     .layout_layout3 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout3 .rb_menus_li:hover > a,
#     .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3:hover .ybc-menu-vertical-button,
#     .layout_layout3:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         color: ;
#     }
#
#     .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout3.ybc_vertical_menu:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_columns_contents_ul,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_li_content {
#         background-color: ;
#     }
#     .layout_layout3 .rb_tabs_li.open.rb_tabs_has_content .rb_tab_li_content .rb_tab_name::before{
#         border-right-color: ;
#     }
#     .layout_layout3.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout3 .rb_menus_ul.rb_mn_submenu_full_height .rb_menus_li:hover a::before,
#     .layout_layout3.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#         border-color: ;
#     }
#     #header .layout_layout3 .rb_block_content a,
#     #header .layout_layout3 .rb_block_content p,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout3 .rb_columns_ul h1,
#     .layout_layout3 .rb_columns_ul h2,
#     .layout_layout3 .rb_columns_ul h3,
#     .layout_layout3 .rb_columns_ul h4,
#     .layout_layout3 .rb_columns_ul h5,
#     .layout_layout3 .rb_columns_ul h6,
#     .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout3 .rb_columns_ul .h1,
#     .layout_layout3 .rb_columns_ul .h2,
#     .layout_layout3 .rb_columns_ul .h3,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     .layout_layout3 .rb_columns_ul .h4,
#     .layout_layout3 .rb_columns_ul .h5,
#     .layout_layout3 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#     /*layout 4*/
#
#     .rb_megamenu.layout_layout4{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout4:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout4 .ybc-menu-vertical-button,
#     .layout_layout4 .rb_extra_item *{
#         color:
#     }
#     .layout_layout4 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4 .rb_menus_li.active > a,
#     #header .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4:hover .ybc-menu-vertical-button,
#     #header .layout_layout4 .rb_menus_li.active > a{color: ;}
#
#     .layout_layout4:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > span,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > span,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout4.ybc_vertical_menu:hover,
#     #header .layout_layout4 .rb_menus_li:hover > span,
#     #header .layout_layout4 .rb_menus_li.active > span{
#         background-color: ;
#     }
#     .layout_layout4 .rb_megamenu_content {
#       border-bottom-color: ;
#     }
#
#     .layout_layout4.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout4 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout4.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout4 .rb_block_content a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout4 .rb_columns_ul h1,
#     .layout_layout4 .rb_columns_ul h2,
#     .layout_layout4 .rb_columns_ul h3,
#     .layout_layout4 .rb_columns_ul h4,
#     .layout_layout4 .rb_columns_ul h5,
#     .layout_layout4 .rb_columns_ul h6,
#     .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout4 .rb_columns_ul .h1,
#     .layout_layout4 .rb_columns_ul .h2,
#     .layout_layout4 .rb_columns_ul .h3,
#     .layout_layout4 .rb_columns_ul .h4,
#     .layout_layout4 .rb_columns_ul .h5,
#     .layout_layout4 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 li:hover > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#     /* end layout 4*/
#
#
#
#
#     /* Layout 5*/
#     .rb_megamenu.layout_layout5{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout5:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout5 .ybc-menu-vertical-button,
#     .layout_layout5 .rb_extra_item *{
#         color:
#     }
#     .layout_layout5 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout5 .rb_menus_li:hover > a,
#     .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5:hover .ybc-menu-vertical-button{
#         color: ;
#     }
#     .layout_layout5:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li > a:before{background-color: ;}
#
#
#     .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout5.ybc_vertical_menu:hover,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#
#     .layout_layout5.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout5 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout5.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout5 .rb_block_content a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout5 .rb_columns_ul h1,
#     .layout_layout5 .rb_columns_ul h2,
#     .layout_layout5 .rb_columns_ul h3,
#     .layout_layout5 .rb_columns_ul h4,
#     .layout_layout5 .rb_columns_ul h5,
#     .layout_layout5 .rb_columns_ul h6,
#     .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout5 .rb_columns_ul .h1,
#     .layout_layout5 .rb_columns_ul .h2,
#     .layout_layout5 .rb_columns_ul .h3,
#     .layout_layout5 .rb_columns_ul .h4,
#     .layout_layout5 .rb_columns_ul .h5,
#     .layout_layout5 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 li:hover > a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*end layout 5*/
# }
#
#
# @media (max-width: 767px){
#     .ybc-menu-vertical-button,
#     .transition_floating .close_menu,
#     .transition_full .close_menu{
#         background-color: ;
#         color: ;
#     }
#     .transition_floating .close_menu *,
#     .transition_full .close_menu *,
#     .ybc-menu-vertical-button .icon-bar{
#         color: ;
#     }
#
#     .close_menu .icon-bar,
#     .ybc-menu-vertical-button .icon-bar {
#       background-color: ;
#     }
#     .rb_menus_back_icon{
#         border-color: ;
#     }
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{color: ;}
#     .layout_layout1 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         /*border-color: ;*/
#     }
#
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     #header .layout_layout1 li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{
#         color: ;
#     }
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{color: ;}
#     .layout_layout2 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     #header .layout_layout2 li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         color: ;
#     }
#     .layout_layout3 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         color: ;
#     }
#
#     .layout_layout4 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     #header .layout_layout4 li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{color: ;}
#     .layout_layout5 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     #header .layout_layout5 li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </style>
# <meta content="Powered by Rubikthem1.0.0 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Module for PrestaShop." name="generator"/>
# <script>
# 	var an_productattributes = {
# 		controller: "https://freeglisse.com/fr/module/an_productattributes/ajax",
# 		config: JSON.parse('{\"type_view\":\"standart\",\"color_type_view\":\"color\",\"display_add_to_cart\":\"0\",\"display_quantity\":\"1\",\"display_labels\":\"1\",\"product_miniature\":\".js-product-miniature\",\"thumbnail_container\":\".thumbnail-container\",\"price\":\".price\",\"regular_price\":\".regular-price\",\"product_price_and_shipping\":\".product-price-and-shipping\",\"separator\":\" \\/ \",\"background_sold_out\":\"#ffc427\",\"color_sold_out\":\"#ffffff\",\"background_sale\":\"#e53d60\",\"color_sale\":\"#ffffff\",\"display_prices\":\"1\"}'),
# 		loader: '<div class="anpa-loader js-anpa-loader"><div class="anpa-loader-bg" data-js-loader-bg=""></div><div class="anpa-loader-spinner" data-js-loader-spinner=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="margin: auto; background-image: none; display: block; shape-rendering: auto; animation-play-state: running; animation-delay: 0s; background-position: initial initial; background-repeat: initial initial;" width="254px" height="254px" viewBox="0 0 100 100" preserveAspectRatio="xMidYMid"><path fill="none" stroke="#1d0e0b" stroke-width="3" stroke-dasharray="42.76482137044271 42.76482137044271" d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" stroke-linecap="round" style="transform: scale(0.22); transform-origin: 50px 50px; animation-play-state: running; animation-delay: 0s;"> <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1s" keyTimes="0;1" values="0;256.58892822265625" style="animation-play-state: running; animation-delay: 0s;"></animate></path></svg></div></div>',
# 	}
# </script>
# <meta class="netreviewsWidget" data-jsurl="//cl.avis-verifies.com/fr/cache/8/2/e/82e3f014-3834-3c84-e5c2-57a3c8fd31c1/widget4/widget02-11446_script.js" id="netreviewsWidgetNum11446"/><script src="//cl.avis-verifies.com/fr/widget4/widget02.min.js"></script><script type="text/javascript">
#
#         var psv = 1.7;
#         var hiRecaptchaSiteKey = '6Lc-ItgiAAAAAEmILb2ozb1TIHdQ83-QWWBjyfP9';
#         var hirecaptchaContact = '1';
#         var hirEnableContactPageCaptcha = '';
#         var hirEnableAuthPageCaptcha = '';
# ...
# </li>
# <li class="thumb-container js-thumb-container">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="thumb js-modal-thumb img-fluid" data-image-large-src="https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" height="148" src="https://freeglisse.com/70931-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" width="523"/>
# </li>
# </ul>
# </div>
# </aside>
# </div>
# </div><!-- /.modal-content -->
# </div><!-- /.modal-dialog -->
# </div><!-- /.modal -->
# <footer class="page-footer">
# <!-- Footer content -->
# </footer>
# <div class="page-loading-overlay main-product-details-loading"></div>
# </section>
# </div>
# </div>
# </div>
# </section>
# <footer class="js-footer" id="footer">
# <div class="footer-container footer-h4 style-2">
# <div class="footer-top">
# <div class="container">
# <div class="footer-blockemail">
# <div class="ps-emailsubscription-block block links accordion_small_screen" id="blockEmailSubscription_displayRbEmail">
# <div class="title-newsletter">
# <h3 class="rb-title">Newsletter</h3>
# <p class="sub-letter">Vous pouvez vous désinscrire à tout moment.
# Vous trouverez pour cela nos informations de contact dans les conditions d'utilisation du site.</p>
# </div>
# <div class="block_content">
# <form action="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#blockEmailSubscription_displayRbEmail" method="post">
# <div class="input-group newsletter-input-group">
# <input aria-labelledby="block-newsletter-label" class="form-control input-subscription" name="email" placeholder="Votre adresse e-mail" required="" type="email" value=""/>
# <button class="btn btn-outline" name="submitNewsletter" type="submit">
# <i aria-hidden="true" class="fa fa-paper-plane"></i>
# <span>S'inscrire</span>
# </button>
# </div>
# <input name="blockHookName" type="hidden" value="displayRbEmail"/>
# <input name="action" type="hidden" value="0"/>
# </form>
# <div class="msg-block">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-top-->
# <div class="footer-center">
# <div class="container">
# <div class="row">
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="box-group">
# <a href="https://freeglisse.com/">
# <img alt="Freeglisse.com" class="logo" src="https://freeglisse.com/img/logo-1668007595.jpg"/>
# </a>
# <br/><br/>
# <div class="block-contact block links">
# <div class="title clearfix">
# <h3 class="h3 rb-title">Contactez-nous</h3>
# </div>
# <ul>
# <li class="address"><i class="rub-map-pin"></i><span>Freeglisse.com<br/>98 B rue des champs plans<br/>74800 Saint-Pierre en Faucigny<br/>France</span></li>
# <li class="phone">
# <i class="icon-telephone"></i>
# <span>Site web : 04 50 07 13 25 / Magasin Freeglisse Shop : 04 85 22 11 04 </span>
# </li>
# <li class="fax">
# <i class="rub-printer"></i>
# <span>RETRAIT DES COMMANDES LE LUNDI 14h-19h ET DU MARDI AU SAMEDI 9h-12h 14h-19h</span>
# </li>
# <li class="email">
# <i class="icon-mail"></i>
# <script type="text/javascript">document.write(unescape('%3c%61%20%68%72%65%66%3d%22%6d%61%69%6c%74%6f%3a%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%22%20%3e%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%3c%2f%61%3e'))</script>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Informations</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/contact" title="Utilisez notre formulaire pour nous contacter">
# 	                                contact
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/4-a-propos" title="Apprenez-en d'avantage sur nous">
# 	                                Qui sommes-nous
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/31-economie-circulaire" title="économie circulaire">
# 	                                Économie circulaire
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/27-choisir-son-materiel" title="Comment bien choisir son matériel ?">
# 	                                Choisir son matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/6-etat-du-materiel" title="Explication de l'état d'usure du matériel en premier, deuxième et troisième choix">
# 	                                État du matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/32-notre-atelier" title="">
# 	                                Notre atelier
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/3-conditions-generales-de-ventes" title="Nos conditions générales de ventes">
# 	                                Conditions générales de ventes
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/5-modes-de-paiement" title="Notre offre de paiement sécurisé">
# 	                                Modes de paiement
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/7-echange-et-retour-produits" title="">
# 	                                Échange et retour produits
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/9-article" title="">
# 	                                Articles
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/26-donnees-personnelles" title="">
# 	                                Données personnelles
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Mon compte</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/mon-compte" title="">
# 	                                Mon compte
# 	                            </a>
# </li>
# </ul>
# </div>
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Catégories</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/106-occasion" title="">
# 	                                Occasion
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/787-destockage-neuf" title="">
# 	                                Déstockage-neuf
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/667-packs" title="">
# 	                                Packs
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/666-recherche-avancee" title="">
# 	                                Recherche avancée
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/fabricants">
# 	                                Toutes nos Marques
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="rb-social-block block links">
# <h3 class="rb-title hidden-sm-down">Follow us</h3>
# <div id="footer_social_block">
# <a href="https://www.facebook.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-facebook-square"></i>
# <span>Facebook</span>
# </a>
# <a href="https://www.instagram.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-instagram"></i>
# <span>Instagram</span>
# </a>
# </div>
# </div>
# <div class="box-footer-html">N°1 du ski occasion en France depuis 30 ans</div>
# <div class="sale-popup flex box-center" data-text1="Acheté il y a " data-text2="minutes"></div>
# </div>
# </div>
# </div>
# </div><!-- end footer-center -->
# <div class="footer-copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-4 col-xs-12 col-sp-12">
# <div class="text-md-left">
# <img alt="Freeglisse.com" class="img-fluid" src="https://freeglisse.com/themes/rb_davici/assets/img/payment.png"/>
# </div>
# </div>
# <div class="col-md-8 col-xs-12 col-sp-12">
# <div class="text-md-right">
# <a class="_blank" href="https://www.nextase.fr" target="_blank">
#                 © 2024 Freeglisse - Par Nextase
#               </a>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-copyright -->
# <div class="rb-hidden hidden-md-down" id="rb-product-cart">
# <div class="container">
# <div class="rb-product-thumb">
# <div class="product-cover-img">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="js-qv-product-cover img img-thumb" itemprop="image" src="https://freeglisse.com/70892-small_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A"/>
# </div>
# <div class="rb-description-sticky">
# <h1 class="h1 product-detail-name" itemprop="name">
#             Ski occasion Rossignol Sender 104 Ti 2023  + Fixations
#           </h1>
# <div class="product-prices js-product-prices">
# <div class="product-discount">
# <span class="regular-price">419,00 €</span>
# </div>
# <div class="product-price h5 has-discount">
# <div class="current-price">
# <span class="current-price-value" content="335.2">
#                                       335,20 €
#                       </span>
# <span class="discount discount-percentage">Économisez 20%</span>
# </div>
# </div>
# <div class="tax-shipping-delivery-label">
#               TTC
#
#
#                                           </div>
# </div>
# </div>
# </div>
# <div class="product-actions">
# <div class="product-variants js-product-variants">
# <div class="clearfix product-variants-item">
# <span class="control-label">Etat du matériel :
#                                                                         <span>Qualité A</span>
# </span>
# <ul id="group_3">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="3" name="group[3]" title="Qualité A" type="radio" value="3"/>
# <span class="radio-label">Qualité A</span>
# </label>
# </li>
# </ul>
# </div>
# <div class="clearfix product-variants-item">
# <span class="control-label">Longueur des Skis :
#                                                                         <span>164 cm</span>
# </span>
# <ul id="group_14">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="14" name="group[14]" title="164 cm" type="radio" value="906"/>
# <span class="radio-label">164 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="172 cm" type="radio" value="914"/>
# <span class="radio-label">172 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="178 cm" type="radio" value="920"/>
# <span class="radio-label">178 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="186 cm" type="radio" value="928"/>
# <span class="radio-label">186 cm</span>
# </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="rb-product-add-to-cart">
# <span class="control-label">Quantity</span>
# <div class="rb-product-quantity clearfix">
# <div class="qty">
# <div class="input-group bootstrap-touchspin">
# <input aria-label="Quantity" class="input-group form-control" id="quantity_wanted" min="1" name="qty" type="number" value="1"/>
# <span class="input-group-btn-vertical">
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-up" type="button">
# <i class="material-icons touchspin-up"></i>
# </button>
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-down" type="button">
# <i class="material-icons touchspin-down"></i>
# </button>
# </span>
# </div>
# </div>
# <div class="add">
# <a class="btn btn-primary add-to-cart">
# <i class="material-icons shopping-cart"></i>
#                   Add to cart
#                 </a>
# </div>
# </div>
# </div>
# <section class="product-discounts js-product-discounts">
# </section>
# </div>
# </div>
# </div>
# </div>
# <div class="progress-wrap" id="rb-back-top">
# <a href="#">
# <svg class="progress-circle svg-content" height="100%" viewbox="-1 -1 102 102" width="100%">
# <path d="M50,1 a49,49 0 0,1 0,98 a49,49 0 0,1 0,-98"></path>
# </svg>
# </a>
# </div>
# </footer>
# </main>
# <script src="https://freeglisse.com/themes/rb_davici/assets/cache/bottom-73e215898.js" type="text/javascript"></script>
# <div aria-hidden="true" class="modal rbsizeguide-modal fade" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-header">
# <div class="modal-body">
# <div class="row">
# <div class="col-md-6">
# <img src="https://freeglisse.com/modules/rbsizeguide/views/img/img.jpg" style="max-width:100%;height:auto;"/>
# </div>
# <div class="col-md-6">
# <ul class="nav nav-tabs">
# <li class="nav-item">
# <a class="nav-link active" data-toggle="tab" href="#rb_sizeguide" title="Size Guide">
# <h5>Size Guide</h5>
# </a>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane rte fade active in" id="rb_sizeguide">
# <table class="table table-sizegudie" style="height:36px;" width="1215"><tbody><tr><td style="text-align:left;">CLOTHES</td></tr></tbody></table><p></p><table class="table table-sizegudie" style="height:157px;" width="1217"><thead><tr><th>MEASURE</th><th>XS/34</th><th>S/36</th><th>M/38-40</th><th>L/40-42</th></tr></thead><tbody><tr class="background-odd"><td>UK</td><td>6</td><td>8</td><td>10</td><td>12</td></tr><tr><td>USA</td><td>4</td><td>6</td><td>8</td><td>10</td></tr><tr class="background-odd"><td>FRA</td><td>36</td><td>38</td><td>40</td><td>42</td></tr><tr><td>Waist (cm)</td><td>64</td><td>68</td><td>72</td><td>76</td></tr><tr class="background-odd"><td>Chest (cm)</td><td>81</td><td>85</td><td>89</td><td>93</td></tr><tr><td>Seat (cm)</td><td>89</td><td>93</td><td>97</td><td>101</td></tr><tr class="background-odd"><td>Inseam (cm)</td><td>81</td><td>82</td><td>83</td><td>84</td></tr></tbody></table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><script>
# function ap5_setPackContentData(retryCount) {
# 	if (typeof(retryCount) == 'undefined') {
# 		var retryCount = 0;
# 	}
# 	if (typeof(ap5_cartPackProducts) == 'object') {
# 		let ap5_packContentDataUpdated = false;
# 		for (ap5_uniquePackAttribute in ap5_cartPackProducts) {
# 			$('.product-line-info span:contains("' + ap5_uniquePackAttribute + '"), .product-line-grid span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 			$('#blockcart-modal .modal-body span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 		}
# 		if (!ap5_packContentDataUpdated) {
# 			if (retryCount <= 5) {
# 				retryCount++;
# 				setTimeout(ap5_setPackContentData, 100, retryCount);
# 			}
# 		}
# 	}
# }
#
# document.addEventListener('DOMContentLoaded', function () {
# 	ap5_setPackContentData();
# 	$(document).ajaxSuccess(function() {
# 		ap5_setPackContentData();
# 	});
# 	$(document).on('ap5-After-AddPackToCart', function() {
# 		ap5_setPackContentData();
# 	});
# });
# </script>
# </body>
# </html>

# %% [markdown]
# ## ciblage sur la balise principal

# %%
link_first_article = soup_first_article.find('div', {"class":"tab-content"}) 
link_first_article
# Out:
# <div class="tab-content" id="tab-content">
# <div class="tab-pane fade in active js-product-tab-active" id="description" role="tabpanel">
# <div class="product-description"><p><span class="js-description-disp" style="font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;">De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller sur n’importe quel terrain, sur piste ou hors piste, grâce à double technologie LCT et Air Tip. Notre technologie d’amortissement des vibrations s’associe à un noyau léger en bois de paulownia pour offrir la polyvalence nécessaire pour la glisse décontractée ou l’attaque à outrance. Franchissez les limites et lancez-vous sans hésitation sur tous les terrains.</span><a class="js-description-toggle" href="https://www.skipass.com/guide-matos/ski/2023/rossignol/sender-104-ti.html#" style="color:#00a4ff;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;"><i class="icon icon-plus-sign" style='width:14px;height:14px;line-height:14px;vertical-align:text-top;background-image:url("/c/i/xglyphicons-halflings.png.pagespeed.ic.8eojXb2vsK.png");background-position:0px -96px;background-repeat:no-repeat;margin-top:1px;'></i></a></p>
# <p><span style="font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;">Lignes de cotes : 138 104 128</span></p>
# <p><span style="font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;">Rayon de 18m pour un ski de 178cm</span></p>
# <p><span style="font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;">Ski de l'année 2023 sorti une saison en location </span></p>
# <p><span style="font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;">Valeur du ski neuf avec fixation : 869 €</span></p></div>
# </div>
# <div class="js-product-details tab-pane fade" data-product="{&quot;id_shop_default&quot;:&quot;1&quot;,&quot;id_manufacturer&quot;:&quot;135&quot;,&quot;id_supplier&quot;:&quot;0&quot;,&quot;reference&quot;:&quot;m33&quot;,&quot;is_virtual&quot;:&quot;0&quot;,&quot;delivery_in_stock&quot;:&quot;&quot;,&quot;delivery_out_stock&quot;:&quot;&quot;,&quot;id_category_default&quot;:&quot;606&quot;,&quot;on_sale&quot;:&quot;0&quot;,&quot;online_only&quot;:&quot;0&quot;,&quot;ecotax&quot;:0,&quot;minimal_quantity&quot;:&quot;1&quot;,&quot;low_stock_threshold&quot;:null,&quot;low_stock_alert&quot;:&quot;0&quot;,&quot;price&quot;:&quot;335,20\u00a0\u20ac&quot;,&quot;unity&quot;:&quot;&quot;,&quot;unit_price_ratio&quot;:&quot;0.000000&quot;,&quot;additional_shipping_cost&quot;:&quot;0.000000&quot;,&quot;customizable&quot;:&quot;1&quot;,&quot;text_fields&quot;:&quot;2&quot;,&quot;uploadable_files&quot;:&quot;0&quot;,&quot;redirect_type&quot;:&quot;301-category&quot;,&quot;id_type_redirected&quot;:&quot;608&quot;,&quot;available_for_order&quot;:&quot;1&quot;,&quot;available_date&quot;:null,&quot;show_condition&quot;:&quot;1&quot;,&quot;condition&quot;:&quot;used&quot;,&quot;show_price&quot;:&quot;1&quot;,&quot;indexed&quot;:&quot;1&quot;,&quot;visibility&quot;:&quot;both&quot;,&quot;cache_default_attribute&quot;:&quot;431280&quot;,&quot;advanced_stock_management&quot;:&quot;0&quot;,&quot;date_add&quot;:&quot;2023-10-12 22:25:45&quot;,&quot;date_upd&quot;:&quot;2024-05-24 12:16:17&quot;,&quot;pack_stock_type&quot;:&quot;3&quot;,&quot;meta_description&quot;:&quot;De la poudreuse \u00e0 la neige tass\u00e9e, le nouveau Sender 104 Ti est l\u2019arme absolue pour dompter toute la montagne. Sa facilit\u00e9 et sa r\u00e9activit\u00e9 permettent d\u2019aller s&quot;,&quot;meta_keywords&quot;:&quot;&quot;,&quot;meta_title&quot;:&quot;Ski occasion Rossignol Sender 104 Ti 2023  + Fixations&quot;,&quot;link_rewrite&quot;:&quot;ski-occasion-rossignol-sender-104-ti-2023-fixations&quot;,&quot;name&quot;:&quot;Ski occasion Rossignol Sender 104 Ti 2023  + Fixations&quot;,&quot;description&quot;:&quot;&lt;p&gt;&lt;span class=\&quot;js-description-disp\&quot; style=\&quot;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;\&quot;&gt;De la poudreuse \u00e0 la neige tass\u00e9e, le nouveau Sender 104 Ti est l\u2019arme absolue pour dompter toute la montagne. Sa facilit\u00e9 et sa r\u00e9activit\u00e9 permettent d\u2019aller sur n\u2019importe quel terrain, sur piste ou hors piste, gr\u00e2ce \u00e0 double technologie LCT et Air Tip. Notre technologie d\u2019amortissement des vibrations s\u2019associe \u00e0 un noyau l\u00e9ger en bois de paulownia pour offrir la polyvalence n\u00e9cessaire pour la glisse d\u00e9contract\u00e9e ou l\u2019attaque \u00e0 outrance. Franchissez les limites et lancez-vous sans h\u00e9sitation sur tous les terrains.&lt;\/span&gt;&lt;a href=\&quot;https:\/\/www.skipass.com\/guide-matos\/ski\/2023\/rossignol\/sender-104-ti.html#\&quot; class=\&quot;js-description-toggle\&quot; style=\&quot;color:#00a4ff;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;\&quot;&gt;&lt;i class=\&quot;icon icon-plus-sign\&quot; style=\&quot;width:14px;height:14px;line-height:14px;vertical-align:text-top;background-image:url(&amp;quot;\/c\/i\/xglyphicons-halflings.png.pagespeed.ic.8eojXb2vsK.png&amp;quot;);background-position:0px -96px;background-repeat:no-repeat;margin-top:1px;\&quot;&gt;&lt;\/i&gt;&lt;\/a&gt;&lt;\/p&gt;\n&lt;p&gt;&lt;span style=\&quot;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;\&quot;&gt;Lignes de cotes : 138 104 128&lt;\/span&gt;&lt;\/p&gt;\n&lt;p&gt;&lt;span style=\&quot;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;\&quot;&gt;Rayon de 18m pour un ski de 178cm&lt;\/span&gt;&lt;\/p&gt;\n&lt;p&gt;&lt;span style=\&quot;font-family:Verdana, Arial;font-size:13px;background-color:#ffffff;\&quot;&gt;Ski de l'ann\u00e9e 2023 sorti une saison en location &lt;\/span& ...
# <div class="product-manufacturer">
# <a href="https://freeglisse.com/fr/135_rossignol">
# <img alt="Rossignol" class="img img-thumbnail manufacturer-logo" height="50" loading="lazy" src="https://freeglisse.com/img/m/135.jpg" width="98"/>
# </a>
# </div>
# <div class="product-out-of-stock">
# </div>
# <section class="product-features">
# <p class="h6">Fiche technique</p>
# <dl class="data-sheet">
# <dt class="name">Type</dt>
# <dd class="value">Freeride</dd>
# <dt class="name">Utilisateur</dt>
# <dd class="value">Mixte</dd>
# <dt class="name">Niveau</dt>
# <dd class="value">Performant</dd>
# <dt class="name">Coloris</dt>
# <dd class="value">Gris</dd>
# <dt class="name">Utilisateur - Configurateur</dt>
# <dd class="value">Freerideur adulte</dd>
# <dt class="name">Economie de CO2 pour la planète (en kg)</dt>
# <dd class="value">3.6</dd>
# <dt class="name">Type de produit</dt>
# <dd class="value">Ski occasion freeride</dd>
# </dl>
# </section>
# </div>
# <div class="tab-pane fade in netreviews_tab" id="extra-0" role="tabpanel">
# <section class="" id="netreviews_reviews_tab">
# <div data-current-option="horodate_DESC" data-current-page="1" data-group-name="" data-idshop="" data-max-page="1" data-productid="18916" data-sortbynote="0" data-url-ajax="/modules/" id="netreviews_rating_section">
# <input id="av_idwebsite" type="hidden" value="82e3f014-3834-3c84-e5c2-57a3c8fd31c1"/>
# <input id="avHelpfulURL" type="hidden" value="https://www.avis-verifies.com/index.php?action=act_api_product_reviews_helpful"/>
# <input id="avHelpfulSuccessMessage" type="hidden" value="Merci, votre vote sera publié prochainement."/>
# <input id="avHelpfulErrorMessage" type="hidden" value="Une erreur s'est produite."/>
# <div class="netreviews_rating_header">
# <img alt="Logo Avis Vérifiés" class="netreviews_logo" src="/modules/netreviews/views/img/logo_full_fr.png"/>
# <div class="av-certificate">
# <a class="netreviews_certification" href="http://www.avis-verifies.com/avis-clients/freeglisse.com" rel="nofollow noreferrer noopener" target="_blank">Voir l'attestation de confiance</a><br/>
# <label id="netreviews_informations_label">
# <div class="av-labeltext">Avis soumis à un contrôle</div>
# <img alt="" height="15px" src="/modules/netreviews/views/img/icone_information.png" width="15px"/> </label>
# <span id="netreviews_informations">
# <img alt="" height="15px" src="/modules/netreviews/views/img/exit_information.png" width="15px"/> <ul>
# <li> Pour plus d'informations sur les caractéristiques du contrôle des avis et la possibilité de contacter l'auteur de l'avis, merci de consulter nos <a href="https://www.netreviews.com/consumers/fr/charte-de-transparence/" rel="nofollow noreferrer noopener" target="_blank">Charte de transparence</a>.</li>
# <li> Aucune contrepartie n'a été fournie en échange des avis</li>
# <li> Les avis sont publiés et conservés pendant une durée de cinq ans</li>
# <li> Les avis ne sont pas modifiables : si un client souhaite modifier son avis, il doit contacter Avis Verifiés afin de supprimer l'avis existant, et en publier un nouveau</li>
# <li> Les motifs de suppression des avis sont disponibles <a href="https://www.avis-verifies.com/index.php?page=mod_conditions_utilisation#Rejet_de_lavis_de_consommateur" rel="nofollow noreferrer noopener" target="_blank">ici</a>.
#                   </li>
# </ul>
# </span>
# </div>
# </div>
# <div class="netreviews_rating_content">
# <div class="netreviews_global_rating">
# <p class="netreviews_note_generale">
#                5<span> /5</span>
# </p>
# <div class="netreviews_bg_stars_big">
# <div>
# <span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span> </div>
# <div style="color:#FFCD00">
# <span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span> </div>
# </div>
# <p class="netreviews_subtitle">
#                 Calculé à partir de  <span id="reviewCount"> 1</span>  avis client(s)
#             </p>
# </div>
# <div class="netreviews_global_rating_details">
# <ul class="netreviews_rates_list">
# <li class="netreviews_rate_list_item">
# <span class="av_star_index">1</span>
# <img alt="" height="15px" src="/modules/netreviews/views/img/star-gold-16.png" width="15px"/> <div class="netreviews_rate_graph">
# <span class="netreviews_rate_percent" style="height:1%">
# <span class="netreviews_rate_total1"> 0 </span>
# </span>
# </div>
# </li>
# <li class="netreviews_rate_list_item">
# <span class="av_star_index">2</span>
# <img alt="" height="15px" src="/modules/netreviews/views/img/star-gold-16.png" width="15px"/> <div class="netreviews_rate_graph">
# <span class="netreviews_rate_percent" style="height:1%">
# <span class="netreviews_rate_total2"> 0 </span>
# </span>
# </div>
# </li>
# <li class="netreviews_rate_list_item">
# <span class="av_star_index">3</span>
# <img alt="" height="15px" src="/modules/netreviews/views/img/star-gold-16.png" width="15px"/> <div class="netreviews_rate_graph">
# <span class="netreviews_rate_percent" style="height:1%">
# <span class="netreviews_rate_total3"> 0 </span>
# </span>
# </div>
# </li>
# <li class="netreviews_rate_list_item">
# <span class="av_star_index">4</span>
# <img alt="" height="15px" src="/modules/netreviews/views/img/star-gold-16.png" width="15px"/> <div class="netreviews_rate_graph">
# <span class="netreviews_rate_percent" style="height:1%">
# <span class="netreviews_rate_total4"> 0 </span>
# </span>
# </div>
# </li>
# <li class="netreviews_rate_list_item cursorp" onclick="javascript:netreviewsFilter(5);">
# <span class="av_star_index">5</span>
# <img alt="" height="15px" src="/modules/netreviews/views/img/star-gold-16.png" width="15px"/> <div class="netreviews_rate_graph">
# <span class="netreviews_rate_percent" style="height:100%">
# <span class="netreviews_rate_total5"> 1 </span>
# </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- filtering section -->
# <div class="netreviews_filtering_section">
# <span class="netreviews_filtering_section_title">Trier l'affichage des avis :</span>
# <select id="netreviews_reviews_filter" name="netreviews_reviews_filter" onchange="javascript:netreviewsFilter(this.value);">
# <option selected="selected" value="horodate_DESC">---</option>
# <option value="horodate_DESC">Les plus récents</option>
# <option value="horodate_ASC">Les plus anciens</option>
# <option value="rate_DESC">Note la plus élevée</option>
# <option value="rate_ASC">Note la plus faible</option>
# <option value="helpfulrating_DESC">Les plus utiles</option> </select>
# </div>
# </div>
# <div class="netreviews_reviews_section">
# <div class="loader_av"></div>
# <div class="netreviews_review_part first-child">
# <p class="netreviews_customer_name">
#                                   FERNAND L.
#
#                <span>publié le 17/04/2024</span>
# <span class="order_date">suite à une commande du 09/04/2024</span>
# </p>
# <div class="netreviews_review_rate_and_stars">
# <div class="netreviews_font_stars">
# <div>
# <span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span><span class="nr-icon nr-star grey"></span> </div>
# <div style="color:#FFCD00">
# <span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span><span class="nr-icon nr-star"></span> </div>
# </div>
# <div class="netreviews_reviews_rate">
#                   5/5
#                </div>
# </div>
# <p class="netreviews_customer_review">
#                Hormis le problème de fixations après avoir pris le soins de les lustré préparé les cares et fartage la notation qualité A n'ai pas mis en  défaut.
#             </p>
# <!-- helpful START -->
# <p class="netreviews_helpful_block">
#                         Cet avis vous a-t-il été utile ?                        <a class="netreviewsVote" data-review-id="83f20583-d71f-44b9-9aed-fd50f88c85a9" href="javascript:" id="83f20583-d71f-44b9-9aed-fd50f88c85a9_1" onclick="javascript:avHelpfulClick('83f20583-d71f-44b9-9aed-fd50f88c85a9','1','af10c10ab4fd2d041f0293d98257452f8d84f275')">Oui <span>0</span></a>
# <a class="netreviewsVote" data-review-id="83f20583-d71f-44b9-9aed-fd50f88c85a9" href="javascript:" id="83f20583-d71f-44b9-9aed-fd50f88c85a9_0" onclick="javascript:avHelpfulClick('83f20583-d71f-44b9-9aed-fd50f88c85a9','0','af10c10ab4fd2d041f0293d98257452f8d84f275')">Non <span>0</span></a>
# </p>
# <p class="netreviews_helpfulmsg" id="83f20583-d71f-44b9-9aed-fd50f88c85a9_msg"></p>
# <!-- helpful END-->
# <!-- Media part -->
# <!-- End media part -->
# </div>
# </div>
# <!-- The Modal -->
# <div id="netreviews_media_modal">
# <div id="netreviews_media_content"></div>
# <!-- The Close Button -->
# <a id="netreviews_media_close">×</a>
# <!-- Modal Content (The Image) -->
# </div>
# </section>
# </div>
# <div class="tab-pane fade in" id="extra-1" role="tabpanel">
# <h2>►<strong> </strong>État d'usure de nos skis et snowboards</h2>
# <h3><strong><em>■ Qualité A : Matériel d'occasion en bon état</em></strong></h3>
# <p>Qualité A propose du matériel d'occasion ayant un bon état général, bien entretenu et pouvant être utilisé pendant de nombreuses saisons :</p>
# <ul>
# <li>Les qualités techniques et la durabilité du matériel sont excellentes</li>
# <li>La sérigraphie peut également comporter quelques rayures et quelques accrocs</li>
# <li>Fixations d'occasion en bon état (vérifiées par nos skimans) mais pouvant comporter cependant quelques rayures d'usage &amp; quelque peu décolorées</li>
# <li>La semelle est parfaitement rebouchée, structurée et fartée. Les carres sont affûtées.</li>
# </ul>
# <h3><strong><em>■ Qualité B : Matériel d'occasion en état correct</em></strong></h3>
# <p>La catégorie Qualité B possède du matériel d'occasion en état correct, mais présentant des marques d'usures plus prononcées (présence de rayures et d'accrocs) :</p>
# <ul>
# <li>La technicité et la durabilité du matériel restent bonnes malgré un esthétique plus ancien</li>
# <li>Présence de rayures et d'accrocs plus prononcés sur plusieurs endroits de la sérigraphie, notamment au niveau de la spatule et du talon</li>
# <li>La fixation peut être rayée ou décolorée (toujours révisée par nos skimans)</li>
# <li>La semelle est parfaitement rebouchée, structurée ainsi que fartée et les carres sont affûtées, comme pour le matériel de Qualité A</li>
# <li>Prix attractif</li>
# </ul>
# <h3><strong><em>■ Qualité C : Matériel dont la sérigraphie est dégradée mais toujours performant</em></strong></h3>
# <p>La catégorie Qualité C propose du matériel abîmé, dont la sérigraphie est dégradée mais qui reste skiable et performant :</p>
# <ul>
# <li>Le matériel ayant déjà servi pendant plusieurs saisons, la sérigraphie est abimée et présente des traces plus importantes d'usures comme des rayures et des accrocs, mais qui n'a aucune influence sur la performance de celui-ci</li>
# <li>La fixation (toujours révisée par nos skimans) présente des traces d'usures plus importantes : décoloration, rayures, accrocs… Elle ne présente aucun danger pour l'utilisateur.</li>
# <li>La semelle est parfaitement rebouchée, structurée et fartée. Les carres sont également affûtées, exactement comme les choix précédents. Attention : le matériel ayant déjà été bien utilisé, il ne reste plus beaucoup d'épaisseur de semelle ou de carre qui permettront de nouveaux entretiens.</li>
# </ul>
# <p>Plus de détails sur la page <a href="/content/6-etat-du-materie">état du matériel</a>.<a href="/content/6-etat-du-materie"></a></p>
# </div>
# <div class="tab-pane fade in" id="rb_review" role="tabpanel">
# </div>
# </div>

# %% [markdown]
# ## application du premier filtre

# %% [markdown]
# les valeurs si dessous sont les informations du "détail produit"

# %%
filter_one = link_first_article.find('section', {"class":"product-features"})
filter_one
# Out:
# <section class="product-features">
# <p class="h6">Fiche technique</p>
# <dl class="data-sheet">
# <dt class="name">Type</dt>
# <dd class="value">Freeride</dd>
# <dt class="name">Utilisateur</dt>
# <dd class="value">Mixte</dd>
# <dt class="name">Niveau</dt>
# <dd class="value">Performant</dd>
# <dt class="name">Coloris</dt>
# <dd class="value">Gris</dd>
# <dt class="name">Utilisateur - Configurateur</dt>
# <dd class="value">Freerideur adulte</dd>
# <dt class="name">Economie de CO2 pour la planète (en kg)</dt>
# <dd class="value">3.6</dd>
# <dt class="name">Type de produit</dt>
# <dd class="value">Ski occasion freeride</dd>
# </dl>
# </section>

# %% [markdown]
# Extraction du text du première article

# %%
str(filter_one).split('Type')[1].split('>')[2].split('<')[0]
str(filter_one).split('Utilisateur')[1].split('>')[2].split('<')[0]
str(filter_one).split('Coloris')[1].split('>')[2].split('<')[0]
# Out:
# 'Gris'

# %% [markdown]
# ## Extraction du prix de tout les articles

# %%
price = requests.get("https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm")
price.content
# Out:
# b'<!doctype html>\n<html lang="fr-FR">\n\n  <head>\n    \n      \n  <meta charset="utf-8">\n\n\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\n\n  <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>\n  \n    \n  \n  <meta name="description" content="De la poudreuse \xc3\xa0 la neige tass\xc3\xa9e, le nouveau Sender 104 Ti est l\xe2\x80\x99arme absolue pour dompter toute la montagne. Sa facilit\xc3\xa9 et sa r\xc3\xa9activit\xc3\xa9 permettent d\xe2\x80\x99aller s">\n  <meta name="keywords" content="">\n        <link rel="canonical" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html">\n    \n          <link rel="alternate" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr">\n          <link rel="alternate" href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de">\n          <link rel="alternate" href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en">\n          <link rel="alternate" href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es">\n          <link rel="alternate" href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it">\n      \n  \n  \n    <script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "Organization",\n    "name" : "Freeglisse.com",\n    "url" : "https://freeglisse.com/fr/",\n    "logo": {\n      "@type": "ImageObject",\n      "url":"https://freeglisse.com/img/logo-1668007595.jpg"\n    }\n  }\n</script>\n\n<script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "WebPage",\n    "isPartOf": {\n      "@type": "WebSite",\n      "url":  "https://freeglisse.com/fr/",\n      "name": "Freeglisse.com"\n    },\n    "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n    "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"\n  }\n</script>\n\n\n  <script type="application/ld+json">\n    {\n      "@context": "https://schema.org",\n      "@type": "BreadcrumbList",\n      "itemListElement": [\n                      {\n              "@type": "ListItem",\n              "position": 1,\n              "name": "Accueil",\n              "item": "https://freeglisse.com/fr/"\n              },                        {\n              "@type": "ListItem",\n              "position": 2,\n              "name": "Occasion",\n              "item": "https://freeglisse.com/fr/106-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 3,\n              "name": "Ski occasion",\n              "item": "https://freeglisse.com/fr/12-ski-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 4,\n              "name": "Ski occasion adulte freeride et freestyle",\n              "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"\n              },                        {\n              "@type": "ListItem",\n              "position": 5,\n              "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n              "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"\n              }            ]\n          }\n  </script>\n  \n  \n  \n  <script type="ap ...

# %%
soup_price = BeautifulSoup(price.content)
soup_price
# Out:
# <!DOCTYPE html>
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" name="description"/>
# <meta content="" name="keywords"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" rel="canonical"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr" rel="alternate"/>
# <link href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de" rel="alternate"/>
# <link href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en" rel="alternate"/>
# <link href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es" rel="alternate"/>
# <link href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it" rel="alternate"/>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "name" : "Freeglisse.com",
#     "url" : "https://freeglisse.com/fr/",
#     "logo": {
#       "@type": "ImageObject",
#       "url":"https://freeglisse.com/img/logo-1668007595.jpg"
#     }
#   }
# </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "WebPage",
#     "isPartOf": {
#       "@type": "WebSite",
#       "url":  "https://freeglisse.com/fr/",
#       "name": "Freeglisse.com"
#     },
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"
#   }
# </script>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement": [
#                       {
#               "@type": "ListItem",
#               "position": 1,
#               "name": "Accueil",
#               "item": "https://freeglisse.com/fr/"
#               },                        {
#               "@type": "ListItem",
#               "position": 2,
#               "name": "Occasion",
#               "item": "https://freeglisse.com/fr/106-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 3,
#               "name": "Ski occasion",
#               "item": "https://freeglisse.com/fr/12-ski-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 4,
#               "name": "Ski occasion adulte freeride et freestyle",
#               "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"
#               },                        {
#               "@type": "ListItem",
#               "position": 5,
#               "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#               "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"
#               }            ]
#           }
#   </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "description": "De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s",
#     "category": "Ski occasion adulte freeride et freestyle",
#     "image" :"https://freeglisse.com/70892-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg",    "sku": "m33",
#     "mpn": "m33",
#         "brand": {
#       "@type": "Thing",
#       "name": "Rossignol"
#     },              "weight": {
#         "@context": "https://schema.org",
#         "@type": "QuantitativeValue",
#         "value": "6.000000",
#         "unitCode": "kg"
#       },                "offers": {
#             "@type": "Offer",
#             "priceCurrency": "EUR",
#             "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#             "price": "335.2",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm",
#             "priceValidUntil": "2024-06-18",
#                           "image": ["https://freeglisse.com/70892-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70929-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70930-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg"],
#                         "sku": "m33",
#             "mpn": "m33",
#                                                                                         "availability": "https://schema.org/InStock",
#             "seller": {
#               "@type": "Organization",
#               "name": "Freeglisse.com"
#             }
#           }
#                 }
# </script>
# <meta content="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations" property="og:title"/>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" property="og:description"/>
# <meta content="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" property="og:url"/>
# <meta content="Freeglisse.com" property="og:site_name"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://freeglisse.com/themes/rb_davici/assets/cache/theme-24ff1d899.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var ASSearchUrl = "https:\/\/freeglisse.com\/fr\/module\/pm_advancedsearch4\/advancedsearch4";
#         var PAYPLUG_DOMAIN = "https:\/\/secure.payplug.com";
#         var RB_Meta = {"v":"1.0.0"};
#         var active = "0";
#         var ap5_cartPackProducts = [];
#         var ap5_modalErrorClose = "Fermer";
#         var ap5_modalErrorTitle = "Une erreur est survenue";
#         var as4_orderBySalesAsc = "Meilleures ventes en dernier";
#         var as4_orderBySalesDesc = "Meilleures ventes en premier";
#         var cancel_rating_txt = "Cancel Rating";
#         var collections = ["<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/18399-ski-occasion-elan-amphibio-78-ti-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/68143-home_default\/ski-occasion-elan-amphibio-78-ti-fixations.jpg' alt='Ski occasion Elan Amphibio 78 ti + Fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-all-mountain\/18399-ski-occasion-elan-amphibio-78-ti-fixations.html' title='Ski occasion Elan Amphibio 78 ti + Fixations'>Ski occasion Elan Amphibio 78 ti + Fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-loisir\/12047-ski-occasion-dynamic-night-elve-fixation.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/33147-home_default\/ski-occasion-dynamic-night-elve-fixation.jpg' alt='Ski occasion Dynamic Night Elve + fixation'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-loisir\/12047-ski-occasion-dynamic-night-elve-fixation.html' title='Ski occasion Dynamic Night Elve + fixation'>Ski occasion Dynamic Night Elve + fixation<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-loisir\/14371-ski-occasion-volkl-rtm-74-fixation.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/37960-home_default\/ski-occasion-volkl-rtm-74-fixation.jpg' alt='Ski occasion Volkl RTM 7.4 + fixation'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-loisir\/14371-ski-occasion-volkl-rtm-74-fixation.html' title='Ski occasion Volkl RTM 7.4 + fixation'>Ski occasion Volkl RTM 7.4 + fixation<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-performance\/12915-ski-occasion-atomic-cloud-eight-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/31260-home_default\/ski-occasion-atomic-cloud-eight-fixations.jpg' alt='Ski occasion Atomic Cloud Eight + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-performance\/12915-ski-occasion-atomic-cloud-eight-fixations.html' title='Ski occasion Atomic Cloud Eight + fixations'>Ski occasion Atomic Cloud Eight + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-loisir\/16916-ski-occasion-tecnopro-safine-prestige-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/52385-home_default\/ski-occasion-tecnopro-safine-prestige-fixations.jpg' alt='Ski occasion Tecnopro Safine Prestige + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-femme-loisir\/16916-ski-occasion-tecnopro-safine-prestige-fixations.html' title='Ski occasion Tecnopro Safine Prestige + fixations'>Ski occasion Tecnopro Safine Prestige + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-de-rando-occasion-et-fin-de-serie\/17814-ski-occasion-rando-pack-k2-wayback-fixations-marker-tour-f12.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/59349-home_default\/ski-occasion-rando-pack-k2-wayback-fixations-marker-tour-f12.jpg' alt='Ski occasion RANDO PACK K2 Wayback + fixations Marker Tour F12'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-de-rando-occasion-et-fin-de-serie\/17814-ski-occasion-rando-pac ...
#         var hirEnableMailalert = false;
#         var isLogged = false;
#         var is_sandbox_mode = false;
#         var module_name = "payplug";
#         var payplug_ajax_url = "https:\/\/freeglisse.com\/fr\/module\/payplug\/ajax";
#         var payplug_oney = true;
#         var payplug_oney_loading_msg = "Chargement";
#         var pm_advancedpack = {"ajaxUrl":"https:\/\/freeglisse.com\/fr\/module\/pm_advancedpack\/ajax","staticToken":"0cc26bc1e7fc2c1dd6f4c3106c8304e3"};
#         var popup = "<div\n\tclass=\"rb-popup-container\"\n\tstyle=\"width:770px;\n\theight:460px;\tbackground-image: url('\/modules\/rbthemefunction\/\/views\/img\/imgbg_1.jpg');\tbackground-position: center\"\n>\n\t<div class=\"rb-popup-flex\">\n\t\t<div id=\"rb_newsletter_popup\" class=\"rb-block\">\n\t\t\t<div class=\"rb-block-content\">\n\t\t\t\t<form action=\"\" method=\"POST\">\n\t\t\t\t\t<div class=\"rb-popup-text\">\n    \t\t\t\t\t<h2>Soyez le premier inform\u00e9<\/h2>\n<p>Abonnez-vous pour les derni\u00e8res nouvelles et obtenez 5\u20ac de r\u00e9duction sur votre premi\u00e8re commande.<\/p>\n                    <\/div>\n\n                    \t                    <div class=\"rb-relative-input relative\">\n\t                    \t<span class=\"rb-your-email\">\n\t\t\t\t\t\t\t\t<input class=\"inputNew\" id=\"rb-newsletter-popup\" type=\"email\" name=\"email\" required=\"\" value=\"\" placeholder=\"votre@email.com\" \/>\n\t\t\t\t\t\t\t<\/span>\n\t                    \t<button class=\"rb-send-email\">\n\t                    \t\t<i class=\"material-icons\">trending_flat<\/i>\n\t\t\t\t\t\t\t\tS'inscrire\n\t                    \t<\/button>\n\t                    <\/div>\n\n\t                    <div class=\"rb-email-alert\">\n\t                    \t<div class=\"cssload-container rb-ajax-loading\">\n\t<div class=\"cssload-double-torus\"><\/div>\n<\/div>\t                    \t<p class=\"rb-email rb-email-success alert alert-success\"><\/p>\n\t                    \t<p class=\"rb-email rb-email-error alert alert-danger\"><\/p>\n\t                    <\/div>\n                    \t\t\t\t<\/form>\n\t\t\t<\/div>\n\t\t<\/div>\n\t<\/div>\n<\/div>";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"Total","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Total TTC","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Total HT :","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Sous-total","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Livraison","amount":0,"value":""},"tax":null},"products_count":0,"summary_string":"0 articles","vouchers":{"allowed":1,"added":[]},"discounts":[{"id_cart_rule":"2404","id_customer":"0","date_from":"2018-06-18 13:00:00","date_to":"2028-07-18 13:00:00","description":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity":"994653","quantity_per_user":"100000","priority":"1","partial_use":"1","code":"","minimum_amount":"199.000000","minimum_amount_tax":"1","minimum_amount_currency":"1","minimum_amount_shipping":"0","country_restriction":"1","carrier_restriction":"1","group_restriction":"0","cart_rule_restriction":"0","product_restriction":"0","shop_restriction":"0","free_shipping":"1","reduction_percent":"0.00","reduction_exclude_special":"0","reduction_amount":"0.000000","reduction_tax":"0","reduction_currency":"1","reduction_product":"0","gift_product":"0","gift_product_attribute":"0","highlight":"1","active":"1","date_add":"2018-06-18 13:41:03","date_upd":"2024-05-11 09:59:40","id_lang":"1","name":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity_for_user":100000}],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"Fran\u00e7ais (French)","iso_code":"fr","locale":"fr-FR","language_code":"fr-fr","is_rtl":"0","date_format_lite":"d\/m\/Y","date_format_full":"d\/m\/Y H:i:s","id":1},"page":{"title":"","canonical":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","meta":{"title":"Ski occasion Rossignol Sender 104 Ti 2023  + Fixations","description":"De la poudreuse \u00e0 la neige tass\u00e9e, le nouveau Sender 104 Ti est l\u2019arme absolue pour dompter toute la montagne. Sa facilit\u00e9 et sa r\u00e9activit\u00e9 permettent d\u2019aller s","keywords":"","robots":"index"},"page_name":"product","body_classes":{"lang-fr":true,"lang-rtl":false,"country-FR":true,"currency-EUR":true,"layout-full-width":true,"page-product":true,"tax-display-enabled":true,"product-id-18916":true,"product-Ski occasion Rossignol Sender 104 Ti 2023  + Fixations":true,"product-id-category-606":true,"product-id-manufacturer-135":true,"product-id-supplier-0":true,"product-available-for-order":true,"product-customizable":true},"admin_notifications":[]},"shop":{"name":"Freeglisse.com","logo":"https:\/\/freeglisse.com\/img\/logo-1668007595.jpg","stores_icon":"https:\/\/freeglisse.com\/img\/ski-destock-logo_stores-1569515187.gif","favicon":"https:\/\/freeglisse.com\/img\/favicon.ico"},"urls":{"base_url":"https:\/\/freeglisse.com\/","current_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","shop_domain_url":"https:\/\/freeglisse.com","img_ps_url":"https:\/\/freeglisse.com\/img\/","img_cat_url":"https:\/\/freeglisse.com\/img\/c\/","img_lang_url":"https:\/\/freeglisse.com\/img\/l\/","img_prod_url":"https:\/\/freeglisse.com\/img\/p\/","img_manu_url":"https:\/\/freeglisse.com\/img\/m\/","img_sup_url":"https:\/\/freeglisse.com\/img\/su ...
#         var probance_wt = {"id":null,"wt_token":"LivB9s6KennjnoG","id_type":"customer_email","id_product":"18916","api_url":"t4.my-probance.one","customer_prefix":"","product_prefix":"","debug":"0"};
#         var psemailsubscription_subscription = "https:\/\/freeglisse.com\/fr\/module\/ps_emailsubscription\/subscription";
#         var psr_icon_color = "#F19D76";
#         var rbFrontendConfig = {"isEditMode":"","stretchedSectionContainer":"","is_rtl":"","rb_day":"Days"};
#         var rb_days = "Days";
#         var rb_facebook = {"general_appid":"1671479023110588","general_pageid":"2005509456220113","chat_state":"0","chat_color":"","chat_delay":"12","login_state":"0","login_redirect":"no_redirect","comments_state":"0","comments_tab":"0","comments_width":"","comments_number":"","comments_admins":"","product_page_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","login_destination":"https:\/\/freeglisse.com\/fr\/mon-compte","phrases":{"login":"Se connecter"}};
#         var rb_height = "460";
#         var rb_hours = "Hours";
#         var rb_minutes = "Minutes";
#         var rb_modal = "<div class=\"modal-content\">\n\t<div class=\"modal-header\">\n\t\t<h5 class=\"modal-title text-xs-center\">\n\t\t\tDelete selected item ?\n\t\t<\/h5>\n\t<\/div>\n\n\t<div class=\"modal-footer\">\n\t\t<button type=\"button\" class=\"rb-modal-no rb-modal-accept btn btn-primary\" data-dismiss=\"modal\">\n\t\t\tAnnuler\n\t\t<\/button>\n\n\t\t<button type=\"button\" class=\"rb-modal-yes rb-modal-accept btn btn-primary\">\n\t\t\tOK\n\t\t<\/button>\n\t<\/div>\n<\/div>";
#         var rb_seconds = "Seconds";
#         var rb_slick = {"active":"1","slideshow":"4","slidesToScroll":"1","autoplay":"0","autospeed":""};
#         var rb_text = "You must be logged. <a href=\"https:\/\/freeglisse.com\/fr\/authentification\">Connexion<\/a>";
#         var rb_view = "1";
#         var rb_width = "770";
#         var rb_zoom = {"active":"1","type":"2","scroll":"1"};
#         var recaptcha_position_contact_us = "inline";
#         var recaptcha_position_login = "";
#         var recaptcha_position_mailalert = "";
#         var recaptcha_position_newsletter = "";
#         var recaptcha_position_password = "";
#         var recaptcha_position_productcomment = "";
#         var recaptcha_position_registration = "";
#         var text1 = "No Product";
#         var text2 = "You Can Not Delete Default Wishlist";
#         var token = "0cc26bc1e7fc2c1dd6f4c3106c8304e3";
#         var url_ajax = "https:\/\/freeglisse.com\/fr\/module\/rbthemefunction\/ajax";
#         var url_compare = "https:\/\/freeglisse.com\/fr\/compare";
#         var url_wishlist = "https:\/\/freeglisse.com\/fr\/wishlist";
#       </script>
# <style>.rb_megamenu .rb_menus_li h4,
# .rb_megamenu .rb_menus_li h5,
# .rb_megamenu .rb_menus_li h6,
# .rb_megamenu .rb_menus_li h1,
# .rb_megamenu .rb_menus_li h2,
# .rb_megamenu .rb_menus_li h3,
# .rb_megamenu .rb_menus_li h4 *:not(i),
# .rb_megamenu .rb_menus_li h5 *:not(i),
# .rb_megamenu .rb_menus_li h6 *:not(i),
# .rb_megamenu .rb_menus_li h1 *:not(i),
# .rb_megamenu .rb_menus_li h2 *:not(i),
# .rb_megamenu .rb_menus_li h3 *:not(i),
# .rb_megamenu .rb_menus_li > a{
#     font-family: inherit;
# }
# .rb_megamenu *:not(.fa):not(i){
#     font-family: inherit;
# }
#
# .rb_block *{
#     font-size: px;
# }
#
# @media (min-width: 768px){
# /*layout 1*/
#     .rb_megamenu.layout_layout1{
#         background: ;
#     }
#     .layout_layout1 .rb_megamenu_content{
#       background: linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -webkit-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -o-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#     }
#     .rb_megamenu.layout_layout1:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout1 .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item *{
#         color:
#     }
#     .layout_layout1 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1 .rb_menus_li.active > a,
#     #header .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1:hover .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout1 .rb_menus_li.active > a{
#         color: ;
#     }
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a:before,
#     .layout_layout1.ybc_vertical_menu:hover .ybc-menu-vertical-button:before,
#     .layout_layout1:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar,
#     .ybc-menu-vertical-button.layout_layout1:hover{background-color: ;}
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover,
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover{
#         background: ;
#     }
#
#     .layout_layout1.rb_megamenu .rb_columns_ul,
#     .layout_layout1.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout1 .rb_block_content a,
#     #header .layout_layout1 .rb_block_content p,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout1 .rb_columns_ul h1,
#     .layout_layout1 .rb_columns_ul h2,
#     .layout_layout1 .rb_columns_ul h3,
#     .layout_layout1 .rb_columns_ul h4,
#     .layout_layout1 .rb_columns_ul h5,
#     .layout_layout1 .rb_columns_ul h6,
#     .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout1 .rb_columns_ul .h1,
#     .layout_layout1 .rb_columns_ul .h2,
#     .layout_layout1 .rb_columns_ul .h3,
#     .layout_layout1 .rb_columns_ul .h4,
#     .layout_layout1 .rb_columns_ul .h5,
#     .layout_layout1 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1 li:hover > a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{color: ;}
#
#
# /*end layout 1*/
#
#
#     /*layout 2*/
#     .rb_megamenu.layout_layout2{
#         background-color: ;
#     }
#
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout2 .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item *{
#         color:
#     }
#     .layout_layout2 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:hover .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a{color: ;}
#
#     .layout_layout2:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout2.ybc_vertical_menu:hover{
#         background-color: ;
#     }
#
#     .layout_layout2.rb_megamenu .rb_columns_ul,
#     .layout_layout2.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout2 .rb_block_content a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout2 .rb_columns_ul h1,
#     .layout_layout2 .rb_columns_ul h2,
#     .layout_layout2 .rb_columns_ul h3,
#     .layout_layout2 .rb_columns_ul h4,
#     .layout_layout2 .rb_columns_ul h5,
#     .layout_layout2 .rb_columns_ul h6,
#     .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout2 .rb_columns_ul .h1,
#     .layout_layout2 .rb_columns_ul .h2,
#     .layout_layout2 .rb_columns_ul .h3,
#     .layout_layout2 .rb_columns_ul .h4,
#     .layout_layout2 .rb_columns_ul .h5,
#     .layout_layout2 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 li:hover > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#
#
#     /*layout 3*/
#     .rb_megamenu.layout_layout3,
#     .layout_layout3 .rb_tab_li_content{
#         background-color: ;
#
#     }
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout3 .ybc-menu-vertical-button,
#     .layout_layout3 .rb_extra_item *{
#         color:
#     }
#     .layout_layout3 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout3 .rb_menus_li:hover > a,
#     .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3:hover .ybc-menu-vertical-button,
#     .layout_layout3:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         color: ;
#     }
#
#     .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout3.ybc_vertical_menu:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_columns_contents_ul,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_li_content {
#         background-color: ;
#     }
#     .layout_layout3 .rb_tabs_li.open.rb_tabs_has_content .rb_tab_li_content .rb_tab_name::before{
#         border-right-color: ;
#     }
#     .layout_layout3.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout3 .rb_menus_ul.rb_mn_submenu_full_height .rb_menus_li:hover a::before,
#     .layout_layout3.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#         border-color: ;
#     }
#     #header .layout_layout3 .rb_block_content a,
#     #header .layout_layout3 .rb_block_content p,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout3 .rb_columns_ul h1,
#     .layout_layout3 .rb_columns_ul h2,
#     .layout_layout3 .rb_columns_ul h3,
#     .layout_layout3 .rb_columns_ul h4,
#     .layout_layout3 .rb_columns_ul h5,
#     .layout_layout3 .rb_columns_ul h6,
#     .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout3 .rb_columns_ul .h1,
#     .layout_layout3 .rb_columns_ul .h2,
#     .layout_layout3 .rb_columns_ul .h3,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     .layout_layout3 .rb_columns_ul .h4,
#     .layout_layout3 .rb_columns_ul .h5,
#     .layout_layout3 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#     /*layout 4*/
#
#     .rb_megamenu.layout_layout4{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout4:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout4 .ybc-menu-vertical-button,
#     .layout_layout4 .rb_extra_item *{
#         color:
#     }
#     .layout_layout4 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4 .rb_menus_li.active > a,
#     #header .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4:hover .ybc-menu-vertical-button,
#     #header .layout_layout4 .rb_menus_li.active > a{color: ;}
#
#     .layout_layout4:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > span,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > span,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout4.ybc_vertical_menu:hover,
#     #header .layout_layout4 .rb_menus_li:hover > span,
#     #header .layout_layout4 .rb_menus_li.active > span{
#         background-color: ;
#     }
#     .layout_layout4 .rb_megamenu_content {
#       border-bottom-color: ;
#     }
#
#     .layout_layout4.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout4 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout4.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout4 .rb_block_content a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout4 .rb_columns_ul h1,
#     .layout_layout4 .rb_columns_ul h2,
#     .layout_layout4 .rb_columns_ul h3,
#     .layout_layout4 .rb_columns_ul h4,
#     .layout_layout4 .rb_columns_ul h5,
#     .layout_layout4 .rb_columns_ul h6,
#     .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout4 .rb_columns_ul .h1,
#     .layout_layout4 .rb_columns_ul .h2,
#     .layout_layout4 .rb_columns_ul .h3,
#     .layout_layout4 .rb_columns_ul .h4,
#     .layout_layout4 .rb_columns_ul .h5,
#     .layout_layout4 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 li:hover > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#     /* end layout 4*/
#
#
#
#
#     /* Layout 5*/
#     .rb_megamenu.layout_layout5{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout5:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout5 .ybc-menu-vertical-button,
#     .layout_layout5 .rb_extra_item *{
#         color:
#     }
#     .layout_layout5 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout5 .rb_menus_li:hover > a,
#     .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5:hover .ybc-menu-vertical-button{
#         color: ;
#     }
#     .layout_layout5:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li > a:before{background-color: ;}
#
#
#     .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout5.ybc_vertical_menu:hover,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#
#     .layout_layout5.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout5 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout5.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout5 .rb_block_content a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout5 .rb_columns_ul h1,
#     .layout_layout5 .rb_columns_ul h2,
#     .layout_layout5 .rb_columns_ul h3,
#     .layout_layout5 .rb_columns_ul h4,
#     .layout_layout5 .rb_columns_ul h5,
#     .layout_layout5 .rb_columns_ul h6,
#     .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout5 .rb_columns_ul .h1,
#     .layout_layout5 .rb_columns_ul .h2,
#     .layout_layout5 .rb_columns_ul .h3,
#     .layout_layout5 .rb_columns_ul .h4,
#     .layout_layout5 .rb_columns_ul .h5,
#     .layout_layout5 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 li:hover > a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*end layout 5*/
# }
#
#
# @media (max-width: 767px){
#     .ybc-menu-vertical-button,
#     .transition_floating .close_menu,
#     .transition_full .close_menu{
#         background-color: ;
#         color: ;
#     }
#     .transition_floating .close_menu *,
#     .transition_full .close_menu *,
#     .ybc-menu-vertical-button .icon-bar{
#         color: ;
#     }
#
#     .close_menu .icon-bar,
#     .ybc-menu-vertical-button .icon-bar {
#       background-color: ;
#     }
#     .rb_menus_back_icon{
#         border-color: ;
#     }
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{color: ;}
#     .layout_layout1 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         /*border-color: ;*/
#     }
#
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     #header .layout_layout1 li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{
#         color: ;
#     }
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{color: ;}
#     .layout_layout2 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     #header .layout_layout2 li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         color: ;
#     }
#     .layout_layout3 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         color: ;
#     }
#
#     .layout_layout4 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     #header .layout_layout4 li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{color: ;}
#     .layout_layout5 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     #header .layout_layout5 li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </style>
# <meta content="Powered by Rubikthem1.0.0 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Module for PrestaShop." name="generator"/>
# <script>
# 	var an_productattributes = {
# 		controller: "https://freeglisse.com/fr/module/an_productattributes/ajax",
# 		config: JSON.parse('{\"type_view\":\"standart\",\"color_type_view\":\"color\",\"display_add_to_cart\":\"0\",\"display_quantity\":\"1\",\"display_labels\":\"1\",\"product_miniature\":\".js-product-miniature\",\"thumbnail_container\":\".thumbnail-container\",\"price\":\".price\",\"regular_price\":\".regular-price\",\"product_price_and_shipping\":\".product-price-and-shipping\",\"separator\":\" \\/ \",\"background_sold_out\":\"#ffc427\",\"color_sold_out\":\"#ffffff\",\"background_sale\":\"#e53d60\",\"color_sale\":\"#ffffff\",\"display_prices\":\"1\"}'),
# 		loader: '<div class="anpa-loader js-anpa-loader"><div class="anpa-loader-bg" data-js-loader-bg=""></div><div class="anpa-loader-spinner" data-js-loader-spinner=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="margin: auto; background-image: none; display: block; shape-rendering: auto; animation-play-state: running; animation-delay: 0s; background-position: initial initial; background-repeat: initial initial;" width="254px" height="254px" viewBox="0 0 100 100" preserveAspectRatio="xMidYMid"><path fill="none" stroke="#1d0e0b" stroke-width="3" stroke-dasharray="42.76482137044271 42.76482137044271" d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" stroke-linecap="round" style="transform: scale(0.22); transform-origin: 50px 50px; animation-play-state: running; animation-delay: 0s;"> <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1s" keyTimes="0;1" values="0;256.58892822265625" style="animation-play-state: running; animation-delay: 0s;"></animate></path></svg></div></div>',
# 	}
# </script>
# <meta class="netreviewsWidget" data-jsurl="//cl.avis-verifies.com/fr/cache/8/2/e/82e3f014-3834-3c84-e5c2-57a3c8fd31c1/widget4/widget02-11446_script.js" id="netreviewsWidgetNum11446"/><script src="//cl.avis-verifies.com/fr/widget4/widget02.min.js"></script><script type="text/javascript">
#
#         var psv = 1.7;
#         var hiRecaptchaSiteKey = '6Lc-ItgiAAAAAEmILb2ozb1TIHdQ83-QWWBjyfP9';
#         var hirecaptchaContact = '1';
#         var hirEnableContactPageCaptcha = '';
#         var hirEnableAuthPageCaptcha = '';
# ...
# </li>
# <li class="thumb-container js-thumb-container">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="thumb js-modal-thumb img-fluid" data-image-large-src="https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" height="148" src="https://freeglisse.com/70931-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" width="523"/>
# </li>
# </ul>
# </div>
# </aside>
# </div>
# </div><!-- /.modal-content -->
# </div><!-- /.modal-dialog -->
# </div><!-- /.modal -->
# <footer class="page-footer">
# <!-- Footer content -->
# </footer>
# <div class="page-loading-overlay main-product-details-loading"></div>
# </section>
# </div>
# </div>
# </div>
# </section>
# <footer class="js-footer" id="footer">
# <div class="footer-container footer-h4 style-2">
# <div class="footer-top">
# <div class="container">
# <div class="footer-blockemail">
# <div class="ps-emailsubscription-block block links accordion_small_screen" id="blockEmailSubscription_displayRbEmail">
# <div class="title-newsletter">
# <h3 class="rb-title">Newsletter</h3>
# <p class="sub-letter">Vous pouvez vous désinscrire à tout moment.
# Vous trouverez pour cela nos informations de contact dans les conditions d'utilisation du site.</p>
# </div>
# <div class="block_content">
# <form action="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#blockEmailSubscription_displayRbEmail" method="post">
# <div class="input-group newsletter-input-group">
# <input aria-labelledby="block-newsletter-label" class="form-control input-subscription" name="email" placeholder="Votre adresse e-mail" required="" type="email" value=""/>
# <button class="btn btn-outline" name="submitNewsletter" type="submit">
# <i aria-hidden="true" class="fa fa-paper-plane"></i>
# <span>S'inscrire</span>
# </button>
# </div>
# <input name="blockHookName" type="hidden" value="displayRbEmail"/>
# <input name="action" type="hidden" value="0"/>
# </form>
# <div class="msg-block">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-top-->
# <div class="footer-center">
# <div class="container">
# <div class="row">
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="box-group">
# <a href="https://freeglisse.com/">
# <img alt="Freeglisse.com" class="logo" src="https://freeglisse.com/img/logo-1668007595.jpg"/>
# </a>
# <br/><br/>
# <div class="block-contact block links">
# <div class="title clearfix">
# <h3 class="h3 rb-title">Contactez-nous</h3>
# </div>
# <ul>
# <li class="address"><i class="rub-map-pin"></i><span>Freeglisse.com<br/>98 B rue des champs plans<br/>74800 Saint-Pierre en Faucigny<br/>France</span></li>
# <li class="phone">
# <i class="icon-telephone"></i>
# <span>Site web : 04 50 07 13 25 / Magasin Freeglisse Shop : 04 85 22 11 04 </span>
# </li>
# <li class="fax">
# <i class="rub-printer"></i>
# <span>RETRAIT DES COMMANDES LE LUNDI 14h-19h ET DU MARDI AU SAMEDI 9h-12h 14h-19h</span>
# </li>
# <li class="email">
# <i class="icon-mail"></i>
# <script type="text/javascript">document.write(unescape('%3c%61%20%68%72%65%66%3d%22%6d%61%69%6c%74%6f%3a%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%22%20%3e%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%3c%2f%61%3e'))</script>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Informations</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/contact" title="Utilisez notre formulaire pour nous contacter">
# 	                                contact
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/4-a-propos" title="Apprenez-en d'avantage sur nous">
# 	                                Qui sommes-nous
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/31-economie-circulaire" title="économie circulaire">
# 	                                Économie circulaire
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/27-choisir-son-materiel" title="Comment bien choisir son matériel ?">
# 	                                Choisir son matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/6-etat-du-materiel" title="Explication de l'état d'usure du matériel en premier, deuxième et troisième choix">
# 	                                État du matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/32-notre-atelier" title="">
# 	                                Notre atelier
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/3-conditions-generales-de-ventes" title="Nos conditions générales de ventes">
# 	                                Conditions générales de ventes
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/5-modes-de-paiement" title="Notre offre de paiement sécurisé">
# 	                                Modes de paiement
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/7-echange-et-retour-produits" title="">
# 	                                Échange et retour produits
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/9-article" title="">
# 	                                Articles
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/26-donnees-personnelles" title="">
# 	                                Données personnelles
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Mon compte</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/mon-compte" title="">
# 	                                Mon compte
# 	                            </a>
# </li>
# </ul>
# </div>
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Catégories</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/106-occasion" title="">
# 	                                Occasion
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/787-destockage-neuf" title="">
# 	                                Déstockage-neuf
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/667-packs" title="">
# 	                                Packs
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/666-recherche-avancee" title="">
# 	                                Recherche avancée
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/fabricants">
# 	                                Toutes nos Marques
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="rb-social-block block links">
# <h3 class="rb-title hidden-sm-down">Follow us</h3>
# <div id="footer_social_block">
# <a href="https://www.facebook.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-facebook-square"></i>
# <span>Facebook</span>
# </a>
# <a href="https://www.instagram.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-instagram"></i>
# <span>Instagram</span>
# </a>
# </div>
# </div>
# <div class="box-footer-html">N°1 du ski occasion en France depuis 30 ans</div>
# <div class="sale-popup flex box-center" data-text1="Acheté il y a " data-text2="minutes"></div>
# </div>
# </div>
# </div>
# </div><!-- end footer-center -->
# <div class="footer-copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-4 col-xs-12 col-sp-12">
# <div class="text-md-left">
# <img alt="Freeglisse.com" class="img-fluid" src="https://freeglisse.com/themes/rb_davici/assets/img/payment.png"/>
# </div>
# </div>
# <div class="col-md-8 col-xs-12 col-sp-12">
# <div class="text-md-right">
# <a class="_blank" href="https://www.nextase.fr" target="_blank">
#                 © 2024 Freeglisse - Par Nextase
#               </a>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-copyright -->
# <div class="rb-hidden hidden-md-down" id="rb-product-cart">
# <div class="container">
# <div class="rb-product-thumb">
# <div class="product-cover-img">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="js-qv-product-cover img img-thumb" itemprop="image" src="https://freeglisse.com/70892-small_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A"/>
# </div>
# <div class="rb-description-sticky">
# <h1 class="h1 product-detail-name" itemprop="name">
#             Ski occasion Rossignol Sender 104 Ti 2023  + Fixations
#           </h1>
# <div class="product-prices js-product-prices">
# <div class="product-discount">
# <span class="regular-price">419,00 €</span>
# </div>
# <div class="product-price h5 has-discount">
# <div class="current-price">
# <span class="current-price-value" content="335.2">
#                                       335,20 €
#                       </span>
# <span class="discount discount-percentage">Économisez 20%</span>
# </div>
# </div>
# <div class="tax-shipping-delivery-label">
#               TTC
#
#
#                                           </div>
# </div>
# </div>
# </div>
# <div class="product-actions">
# <div class="product-variants js-product-variants">
# <div class="clearfix product-variants-item">
# <span class="control-label">Etat du matériel :
#                                                                         <span>Qualité A</span>
# </span>
# <ul id="group_3">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="3" name="group[3]" title="Qualité A" type="radio" value="3"/>
# <span class="radio-label">Qualité A</span>
# </label>
# </li>
# </ul>
# </div>
# <div class="clearfix product-variants-item">
# <span class="control-label">Longueur des Skis :
#                                                                         <span>164 cm</span>
# </span>
# <ul id="group_14">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="14" name="group[14]" title="164 cm" type="radio" value="906"/>
# <span class="radio-label">164 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="172 cm" type="radio" value="914"/>
# <span class="radio-label">172 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="178 cm" type="radio" value="920"/>
# <span class="radio-label">178 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="186 cm" type="radio" value="928"/>
# <span class="radio-label">186 cm</span>
# </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="rb-product-add-to-cart">
# <span class="control-label">Quantity</span>
# <div class="rb-product-quantity clearfix">
# <div class="qty">
# <div class="input-group bootstrap-touchspin">
# <input aria-label="Quantity" class="input-group form-control" id="quantity_wanted" min="1" name="qty" type="number" value="1"/>
# <span class="input-group-btn-vertical">
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-up" type="button">
# <i class="material-icons touchspin-up"></i>
# </button>
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-down" type="button">
# <i class="material-icons touchspin-down"></i>
# </button>
# </span>
# </div>
# </div>
# <div class="add">
# <a class="btn btn-primary add-to-cart">
# <i class="material-icons shopping-cart"></i>
#                   Add to cart
#                 </a>
# </div>
# </div>
# </div>
# <section class="product-discounts js-product-discounts">
# </section>
# </div>
# </div>
# </div>
# </div>
# <div class="progress-wrap" id="rb-back-top">
# <a href="#">
# <svg class="progress-circle svg-content" height="100%" viewbox="-1 -1 102 102" width="100%">
# <path d="M50,1 a49,49 0 0,1 0,98 a49,49 0 0,1 0,-98"></path>
# </svg>
# </a>
# </div>
# </footer>
# </main>
# <script src="https://freeglisse.com/themes/rb_davici/assets/cache/bottom-73e215898.js" type="text/javascript"></script>
# <div aria-hidden="true" class="modal rbsizeguide-modal fade" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-header">
# <div class="modal-body">
# <div class="row">
# <div class="col-md-6">
# <img src="https://freeglisse.com/modules/rbsizeguide/views/img/img.jpg" style="max-width:100%;height:auto;"/>
# </div>
# <div class="col-md-6">
# <ul class="nav nav-tabs">
# <li class="nav-item">
# <a class="nav-link active" data-toggle="tab" href="#rb_sizeguide" title="Size Guide">
# <h5>Size Guide</h5>
# </a>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane rte fade active in" id="rb_sizeguide">
# <table class="table table-sizegudie" style="height:36px;" width="1215"><tbody><tr><td style="text-align:left;">CLOTHES</td></tr></tbody></table><p></p><table class="table table-sizegudie" style="height:157px;" width="1217"><thead><tr><th>MEASURE</th><th>XS/34</th><th>S/36</th><th>M/38-40</th><th>L/40-42</th></tr></thead><tbody><tr class="background-odd"><td>UK</td><td>6</td><td>8</td><td>10</td><td>12</td></tr><tr><td>USA</td><td>4</td><td>6</td><td>8</td><td>10</td></tr><tr class="background-odd"><td>FRA</td><td>36</td><td>38</td><td>40</td><td>42</td></tr><tr><td>Waist (cm)</td><td>64</td><td>68</td><td>72</td><td>76</td></tr><tr class="background-odd"><td>Chest (cm)</td><td>81</td><td>85</td><td>89</td><td>93</td></tr><tr><td>Seat (cm)</td><td>89</td><td>93</td><td>97</td><td>101</td></tr><tr class="background-odd"><td>Inseam (cm)</td><td>81</td><td>82</td><td>83</td><td>84</td></tr></tbody></table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><script>
# function ap5_setPackContentData(retryCount) {
# 	if (typeof(retryCount) == 'undefined') {
# 		var retryCount = 0;
# 	}
# 	if (typeof(ap5_cartPackProducts) == 'object') {
# 		let ap5_packContentDataUpdated = false;
# 		for (ap5_uniquePackAttribute in ap5_cartPackProducts) {
# 			$('.product-line-info span:contains("' + ap5_uniquePackAttribute + '"), .product-line-grid span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 			$('#blockcart-modal .modal-body span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 		}
# 		if (!ap5_packContentDataUpdated) {
# 			if (retryCount <= 5) {
# 				retryCount++;
# 				setTimeout(ap5_setPackContentData, 100, retryCount);
# 			}
# 		}
# 	}
# }
#
# document.addEventListener('DOMContentLoaded', function () {
# 	ap5_setPackContentData();
# 	$(document).ajaxSuccess(function() {
# 		ap5_setPackContentData();
# 	});
# 	$(document).on('ap5-After-AddPackToCart', function() {
# 		ap5_setPackContentData();
# 	});
# });
# </script>
# </body>
# </html>

# %%
filter_price = soup_price.find('span', {"class":"current-price-value"}) 
filter_price
# Out:
# <span class="current-price-value" content="335.2">
#                                       335,20 €
#                       </span>

# %%
str(filter_price).split('content')[1].split('\"')[1]
# Out:
# '335.2'

# %% [markdown]
# ## Extraction de la marque

# %%
maker = requests.get("https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm")
maker.content
# Out:
# b'<!doctype html>\n<html lang="fr-FR">\n\n  <head>\n    \n      \n  <meta charset="utf-8">\n\n\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\n\n  <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>\n  \n    \n  \n  <meta name="description" content="De la poudreuse \xc3\xa0 la neige tass\xc3\xa9e, le nouveau Sender 104 Ti est l\xe2\x80\x99arme absolue pour dompter toute la montagne. Sa facilit\xc3\xa9 et sa r\xc3\xa9activit\xc3\xa9 permettent d\xe2\x80\x99aller s">\n  <meta name="keywords" content="">\n        <link rel="canonical" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html">\n    \n          <link rel="alternate" href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr">\n          <link rel="alternate" href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de">\n          <link rel="alternate" href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en">\n          <link rel="alternate" href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es">\n          <link rel="alternate" href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it">\n      \n  \n  \n    <script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "Organization",\n    "name" : "Freeglisse.com",\n    "url" : "https://freeglisse.com/fr/",\n    "logo": {\n      "@type": "ImageObject",\n      "url":"https://freeglisse.com/img/logo-1668007595.jpg"\n    }\n  }\n</script>\n\n<script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type": "WebPage",\n    "isPartOf": {\n      "@type": "WebSite",\n      "url":  "https://freeglisse.com/fr/",\n      "name": "Freeglisse.com"\n    },\n    "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n    "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"\n  }\n</script>\n\n\n  <script type="application/ld+json">\n    {\n      "@context": "https://schema.org",\n      "@type": "BreadcrumbList",\n      "itemListElement": [\n                      {\n              "@type": "ListItem",\n              "position": 1,\n              "name": "Accueil",\n              "item": "https://freeglisse.com/fr/"\n              },                        {\n              "@type": "ListItem",\n              "position": 2,\n              "name": "Occasion",\n              "item": "https://freeglisse.com/fr/106-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 3,\n              "name": "Ski occasion",\n              "item": "https://freeglisse.com/fr/12-ski-occasion"\n              },                        {\n              "@type": "ListItem",\n              "position": 4,\n              "name": "Ski occasion adulte freeride et freestyle",\n              "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"\n              },                        {\n              "@type": "ListItem",\n              "position": 5,\n              "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",\n              "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"\n              }            ]\n          }\n  </script>\n  \n  \n  \n  <script type="ap ...

# %%
maker_soup = BeautifulSoup(maker.content)
maker_soup
# Out:
# <!DOCTYPE html>
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Ski occasion Rossignol Sender 104 Ti 2023  + Fixations</title>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" name="description"/>
# <meta content="" name="keywords"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" rel="canonical"/>
# <link href="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" hreflang="fr-fr" rel="alternate"/>
# <link href="https://freeglisse.com/de/erwachsener-benutzter-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-gelegenheit-befestigungen.html" hreflang="de-de" rel="alternate"/>
# <link href="https://freeglisse.com/en/adult-used-ski-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-opportunity-bindings.html" hreflang="en-en" rel="alternate"/>
# <link href="https://freeglisse.com/es/esqui-de-adultos-usado-freeride-freestyle/18916-ski-rossignol-sender-104-ti-2023-oportunidad-fijaciones.html" hreflang="es-es" rel="alternate"/>
# <link href="https://freeglisse.com/it/sci-per-adulti-usato-freeride-freestyle/18916-sci-rossignol-sender-104-ti-2023-opportunity-fissazioni.html" hreflang="it-it" rel="alternate"/>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "name" : "Freeglisse.com",
#     "url" : "https://freeglisse.com/fr/",
#     "logo": {
#       "@type": "ImageObject",
#       "url":"https://freeglisse.com/img/logo-1668007595.jpg"
#     }
#   }
# </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "WebPage",
#     "isPartOf": {
#       "@type": "WebSite",
#       "url":  "https://freeglisse.com/fr/",
#       "name": "Freeglisse.com"
#     },
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "url":  "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html"
#   }
# </script>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement": [
#                       {
#               "@type": "ListItem",
#               "position": 1,
#               "name": "Accueil",
#               "item": "https://freeglisse.com/fr/"
#               },                        {
#               "@type": "ListItem",
#               "position": 2,
#               "name": "Occasion",
#               "item": "https://freeglisse.com/fr/106-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 3,
#               "name": "Ski occasion",
#               "item": "https://freeglisse.com/fr/12-ski-occasion"
#               },                        {
#               "@type": "ListItem",
#               "position": 4,
#               "name": "Ski occasion adulte freeride et freestyle",
#               "item": "https://freeglisse.com/fr/606-ski-occasion-adulte-freeride-et-freestyle"
#               },                        {
#               "@type": "ListItem",
#               "position": 5,
#               "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#               "item": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/etat_du_materiel-qualite_a/taille_skis-164_cm"
#               }            ]
#           }
#   </script>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#     "description": "De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s",
#     "category": "Ski occasion adulte freeride et freestyle",
#     "image" :"https://freeglisse.com/70892-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg",    "sku": "m33",
#     "mpn": "m33",
#         "brand": {
#       "@type": "Thing",
#       "name": "Rossignol"
#     },              "weight": {
#         "@context": "https://schema.org",
#         "@type": "QuantitativeValue",
#         "value": "6.000000",
#         "unitCode": "kg"
#       },                "offers": {
#             "@type": "Offer",
#             "priceCurrency": "EUR",
#             "name": "Ski occasion Rossignol Sender 104 Ti 2023  + Fixations",
#             "price": "335.2",
#             "url": "https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#/3-etat_du_materiel-qualite_a/906-taille_skis-164_cm",
#             "priceValidUntil": "2024-06-18",
#                           "image": ["https://freeglisse.com/70892-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70929-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70930-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg","https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg"],
#                         "sku": "m33",
#             "mpn": "m33",
#                                                                                         "availability": "https://schema.org/InStock",
#             "seller": {
#               "@type": "Organization",
#               "name": "Freeglisse.com"
#             }
#           }
#                 }
# </script>
# <meta content="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations" property="og:title"/>
# <meta content="De la poudreuse à la neige tassée, le nouveau Sender 104 Ti est l’arme absolue pour dompter toute la montagne. Sa facilité et sa réactivité permettent d’aller s" property="og:description"/>
# <meta content="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html" property="og:url"/>
# <meta content="Freeglisse.com" property="og:site_name"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://freeglisse.com/img/favicon.ico?1668007595" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://freeglisse.com/themes/rb_davici/assets/cache/theme-24ff1d899.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var ASSearchUrl = "https:\/\/freeglisse.com\/fr\/module\/pm_advancedsearch4\/advancedsearch4";
#         var PAYPLUG_DOMAIN = "https:\/\/secure.payplug.com";
#         var RB_Meta = {"v":"1.0.0"};
#         var active = "0";
#         var ap5_cartPackProducts = [];
#         var ap5_modalErrorClose = "Fermer";
#         var ap5_modalErrorTitle = "Une erreur est survenue";
#         var as4_orderBySalesAsc = "Meilleures ventes en dernier";
#         var as4_orderBySalesDesc = "Meilleures ventes en premier";
#         var cancel_rating_txt = "Cancel Rating";
#         var collections = ["<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-performance\/10931-ski-nordica-dobermann-slr-rb-evo-occasion-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/25305-home_default\/ski-nordica-dobermann-slr-rb-evo-occasion-fixations.jpg' alt='Ski Nordica Dobermann SLR RB EVO occasion + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-performance\/10931-ski-nordica-dobermann-slr-rb-evo-occasion-fixations.html' title='Ski Nordica Dobermann SLR RB EVO occasion + fixations'>Ski Nordica Dobermann SLR RB EVO occasion + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-junior-freeride-freestyle\/14231-ski-occasion-junior-rossignol-scratch-pro-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/37468-home_default\/ski-occasion-junior-rossignol-scratch-pro-fixations.jpg' alt='Ski occasion Junior Rossignol Scratch pro  + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-junior-freeride-freestyle\/14231-ski-occasion-junior-rossignol-scratch-pro-fixations.html' title='Ski occasion Junior Rossignol Scratch pro  + fixations'>Ski occasion Junior Rossignol Scratch pro  + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-performance\/10896-ski-occasion-salomon-x-max-x12-fixations.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/25314-home_default\/ski-occasion-salomon-x-max-x12-fixations.jpg' alt='Ski occasion Salomon X Max X12 + fixations'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-performance\/10896-ski-occasion-salomon-x-max-x12-fixations.html' title='Ski occasion Salomon X Max X12 + fixations'>Ski occasion Salomon X Max X12 + fixations<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/snowboard-occasion-loisir-fixation\/11643-snowboard-occasion-junior-nidecker-vibes-fixation.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/23752-home_default\/snowboard-occasion-junior-nidecker-vibes-fixation.jpg' alt='Snowboard occasion junior Nidecker Vibes + fixation'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/snowboard-occasion-loisir-fixation\/11643-snowboard-occasion-junior-nidecker-vibes-fixation.html' title='Snowboard occasion junior Nidecker Vibes + fixation'>Snowboard occasion junior Nidecker Vibes + fixation<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/ski-de-fond-occasion-alternatif-norme-sns\/13242-ski-de-fond-occasion-rossignol-tempo-classic-fixation-sns-profil.html' class='sale-popup-img'><img src='https:\/\/freeglisse.com\/32258-home_default\/ski-de-fond-occasion-rossignol-tempo-classic-fixation-sns-profil.jpg' alt='Ski de fond occasion Rossignol Tempo Classic + fixation SNS profil'\/><\/a><div class='sale-popup-content'><h3><a href='https:\/\/freeglisse.com\/fr\/ski-de-fond-occasion-alternatif-norme-sns\/13242-ski-de-fond-occasion-rossignol-tempo-classic-fixation-sns-profil.html' title='Ski de fond occasion Rossignol Tempo Classic + fixation SNS profil'>Ski de fond occasion Rossignol Tempo Classic + fixation SNS profil<\/a><\/h3><span class='sale-popup-timeago'><\/span><\/div><span class='button-close'><i class='material-icons'>close<\/i><\/span>","<a href='https:\/\/freeglisse.com\/fr\/snowboard-occasion-loisir-fixation\/17355-snowboard-occasion-rossignol-accelerator-fixation-coq ...
#         var hirEnableMailalert = false;
#         var isLogged = false;
#         var is_sandbox_mode = false;
#         var module_name = "payplug";
#         var payplug_ajax_url = "https:\/\/freeglisse.com\/fr\/module\/payplug\/ajax";
#         var payplug_oney = true;
#         var payplug_oney_loading_msg = "Chargement";
#         var pm_advancedpack = {"ajaxUrl":"https:\/\/freeglisse.com\/fr\/module\/pm_advancedpack\/ajax","staticToken":"0cc26bc1e7fc2c1dd6f4c3106c8304e3"};
#         var popup = "<div\n\tclass=\"rb-popup-container\"\n\tstyle=\"width:770px;\n\theight:460px;\tbackground-image: url('\/modules\/rbthemefunction\/\/views\/img\/imgbg_1.jpg');\tbackground-position: center\"\n>\n\t<div class=\"rb-popup-flex\">\n\t\t<div id=\"rb_newsletter_popup\" class=\"rb-block\">\n\t\t\t<div class=\"rb-block-content\">\n\t\t\t\t<form action=\"\" method=\"POST\">\n\t\t\t\t\t<div class=\"rb-popup-text\">\n    \t\t\t\t\t<h2>Soyez le premier inform\u00e9<\/h2>\n<p>Abonnez-vous pour les derni\u00e8res nouvelles et obtenez 5\u20ac de r\u00e9duction sur votre premi\u00e8re commande.<\/p>\n                    <\/div>\n\n                    \t                    <div class=\"rb-relative-input relative\">\n\t                    \t<span class=\"rb-your-email\">\n\t\t\t\t\t\t\t\t<input class=\"inputNew\" id=\"rb-newsletter-popup\" type=\"email\" name=\"email\" required=\"\" value=\"\" placeholder=\"votre@email.com\" \/>\n\t\t\t\t\t\t\t<\/span>\n\t                    \t<button class=\"rb-send-email\">\n\t                    \t\t<i class=\"material-icons\">trending_flat<\/i>\n\t\t\t\t\t\t\t\tS'inscrire\n\t                    \t<\/button>\n\t                    <\/div>\n\n\t                    <div class=\"rb-email-alert\">\n\t                    \t<div class=\"cssload-container rb-ajax-loading\">\n\t<div class=\"cssload-double-torus\"><\/div>\n<\/div>\t                    \t<p class=\"rb-email rb-email-success alert alert-success\"><\/p>\n\t                    \t<p class=\"rb-email rb-email-error alert alert-danger\"><\/p>\n\t                    <\/div>\n                    \t\t\t\t<\/form>\n\t\t\t<\/div>\n\t\t<\/div>\n\t<\/div>\n<\/div>";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"Total","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Total TTC","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Total HT :","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Sous-total","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Livraison","amount":0,"value":""},"tax":null},"products_count":0,"summary_string":"0 articles","vouchers":{"allowed":1,"added":[]},"discounts":[{"id_cart_rule":"2404","id_customer":"0","date_from":"2018-06-18 13:00:00","date_to":"2028-07-18 13:00:00","description":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity":"994653","quantity_per_user":"100000","priority":"1","partial_use":"1","code":"","minimum_amount":"199.000000","minimum_amount_tax":"1","minimum_amount_currency":"1","minimum_amount_shipping":"0","country_restriction":"1","carrier_restriction":"1","group_restriction":"0","cart_rule_restriction":"0","product_restriction":"0","shop_restriction":"0","free_shipping":"1","reduction_percent":"0.00","reduction_exclude_special":"0","reduction_amount":"0.000000","reduction_tax":"0","reduction_currency":"1","reduction_product":"0","gift_product":"0","gift_product_attribute":"0","highlight":"1","active":"1","date_add":"2018-06-18 13:41:03","date_upd":"2024-05-11 09:59:40","id_lang":"1","name":"Livraison offerte \u00e0 partir de 199 \u20ac d'achat pour une livraison en France metropolitaine","quantity_for_user":100000}],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"Fran\u00e7ais (French)","iso_code":"fr","locale":"fr-FR","language_code":"fr-fr","is_rtl":"0","date_format_lite":"d\/m\/Y","date_format_full":"d\/m\/Y H:i:s","id":1},"page":{"title":"","canonical":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","meta":{"title":"Ski occasion Rossignol Sender 104 Ti 2023  + Fixations","description":"De la poudreuse \u00e0 la neige tass\u00e9e, le nouveau Sender 104 Ti est l\u2019arme absolue pour dompter toute la montagne. Sa facilit\u00e9 et sa r\u00e9activit\u00e9 permettent d\u2019aller s","keywords":"","robots":"index"},"page_name":"product","body_classes":{"lang-fr":true,"lang-rtl":false,"country-FR":true,"currency-EUR":true,"layout-full-width":true,"page-product":true,"tax-display-enabled":true,"product-id-18916":true,"product-Ski occasion Rossignol Sender 104 Ti 2023  + Fixations":true,"product-id-category-606":true,"product-id-manufacturer-135":true,"product-id-supplier-0":true,"product-available-for-order":true,"product-customizable":true},"admin_notifications":[]},"shop":{"name":"Freeglisse.com","logo":"https:\/\/freeglisse.com\/img\/logo-1668007595.jpg","stores_icon":"https:\/\/freeglisse.com\/img\/ski-destock-logo_stores-1569515187.gif","favicon":"https:\/\/freeglisse.com\/img\/favicon.ico"},"urls":{"base_url":"https:\/\/freeglisse.com\/","current_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","shop_domain_url":"https:\/\/freeglisse.com","img_ps_url":"https:\/\/freeglisse.com\/img\/","img_cat_url":"https:\/\/freeglisse.com\/img\/c\/","img_lang_url":"https:\/\/freeglisse.com\/img\/l\/","img_prod_url":"https:\/\/freeglisse.com\/img\/p\/","img_manu_url":"https:\/\/freeglisse.com\/img\/m\/","img_sup_url":"https:\/\/freeglisse.com\/img\/su ...
#         var probance_wt = {"id":null,"wt_token":"LivB9s6KennjnoG","id_type":"customer_email","id_product":"18916","api_url":"t4.my-probance.one","customer_prefix":"","product_prefix":"","debug":"0"};
#         var psemailsubscription_subscription = "https:\/\/freeglisse.com\/fr\/module\/ps_emailsubscription\/subscription";
#         var psr_icon_color = "#F19D76";
#         var rbFrontendConfig = {"isEditMode":"","stretchedSectionContainer":"","is_rtl":"","rb_day":"Days"};
#         var rb_days = "Days";
#         var rb_facebook = {"general_appid":"1671479023110588","general_pageid":"2005509456220113","chat_state":"0","chat_color":"","chat_delay":"12","login_state":"0","login_redirect":"no_redirect","comments_state":"0","comments_tab":"0","comments_width":"","comments_number":"","comments_admins":"","product_page_url":"https:\/\/freeglisse.com\/fr\/ski-occasion-adulte-freeride-et-freestyle\/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html","login_destination":"https:\/\/freeglisse.com\/fr\/mon-compte","phrases":{"login":"Se connecter"}};
#         var rb_height = "460";
#         var rb_hours = "Hours";
#         var rb_minutes = "Minutes";
#         var rb_modal = "<div class=\"modal-content\">\n\t<div class=\"modal-header\">\n\t\t<h5 class=\"modal-title text-xs-center\">\n\t\t\tDelete selected item ?\n\t\t<\/h5>\n\t<\/div>\n\n\t<div class=\"modal-footer\">\n\t\t<button type=\"button\" class=\"rb-modal-no rb-modal-accept btn btn-primary\" data-dismiss=\"modal\">\n\t\t\tAnnuler\n\t\t<\/button>\n\n\t\t<button type=\"button\" class=\"rb-modal-yes rb-modal-accept btn btn-primary\">\n\t\t\tOK\n\t\t<\/button>\n\t<\/div>\n<\/div>";
#         var rb_seconds = "Seconds";
#         var rb_slick = {"active":"1","slideshow":"4","slidesToScroll":"1","autoplay":"0","autospeed":""};
#         var rb_text = "You must be logged. <a href=\"https:\/\/freeglisse.com\/fr\/authentification\">Connexion<\/a>";
#         var rb_view = "1";
#         var rb_width = "770";
#         var rb_zoom = {"active":"1","type":"2","scroll":"1"};
#         var recaptcha_position_contact_us = "inline";
#         var recaptcha_position_login = "";
#         var recaptcha_position_mailalert = "";
#         var recaptcha_position_newsletter = "";
#         var recaptcha_position_password = "";
#         var recaptcha_position_productcomment = "";
#         var recaptcha_position_registration = "";
#         var text1 = "No Product";
#         var text2 = "You Can Not Delete Default Wishlist";
#         var token = "0cc26bc1e7fc2c1dd6f4c3106c8304e3";
#         var url_ajax = "https:\/\/freeglisse.com\/fr\/module\/rbthemefunction\/ajax";
#         var url_compare = "https:\/\/freeglisse.com\/fr\/compare";
#         var url_wishlist = "https:\/\/freeglisse.com\/fr\/wishlist";
#       </script>
# <style>.rb_megamenu .rb_menus_li h4,
# .rb_megamenu .rb_menus_li h5,
# .rb_megamenu .rb_menus_li h6,
# .rb_megamenu .rb_menus_li h1,
# .rb_megamenu .rb_menus_li h2,
# .rb_megamenu .rb_menus_li h3,
# .rb_megamenu .rb_menus_li h4 *:not(i),
# .rb_megamenu .rb_menus_li h5 *:not(i),
# .rb_megamenu .rb_menus_li h6 *:not(i),
# .rb_megamenu .rb_menus_li h1 *:not(i),
# .rb_megamenu .rb_menus_li h2 *:not(i),
# .rb_megamenu .rb_menus_li h3 *:not(i),
# .rb_megamenu .rb_menus_li > a{
#     font-family: inherit;
# }
# .rb_megamenu *:not(.fa):not(i){
#     font-family: inherit;
# }
#
# .rb_block *{
#     font-size: px;
# }
#
# @media (min-width: 768px){
# /*layout 1*/
#     .rb_megamenu.layout_layout1{
#         background: ;
#     }
#     .layout_layout1 .rb_megamenu_content{
#       background: linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -webkit-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#       background: -o-linear-gradient(#FFFFFF, #F2F2F2) repeat scroll 0 0 rgba(0, 0, 0, 0);
#     }
#     .rb_megamenu.layout_layout1:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout1 .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item *{
#         color:
#     }
#     .layout_layout1 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1 .rb_menus_li.active > a,
#     #header .layout_layout1 .rb_menus_li:hover > a,
#     .layout_layout1:hover .ybc-menu-vertical-button,
#     .layout_layout1 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout1 .rb_menus_li.active > a{
#         color: ;
#     }
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li > a:before,
#     .layout_layout1.ybc_vertical_menu:hover .ybc-menu-vertical-button:before,
#     .layout_layout1:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar,
#     .ybc-menu-vertical-button.layout_layout1:hover{background-color: ;}
#
#     .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover,
#     #header .layout_layout1:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout1.ybc_vertical_menu:hover{
#         background: ;
#     }
#
#     .layout_layout1.rb_megamenu .rb_columns_ul,
#     .layout_layout1.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout1 .rb_block_content a,
#     #header .layout_layout1 .rb_block_content p,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout1 .rb_columns_ul h1,
#     .layout_layout1 .rb_columns_ul h2,
#     .layout_layout1 .rb_columns_ul h3,
#     .layout_layout1 .rb_columns_ul h4,
#     .layout_layout1 .rb_columns_ul h5,
#     .layout_layout1 .rb_columns_ul h6,
#     .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout1 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout1 .rb_columns_ul .h1,
#     .layout_layout1 .rb_columns_ul .h2,
#     .layout_layout1 .rb_columns_ul .h3,
#     .layout_layout1 .rb_columns_ul .h4,
#     .layout_layout1 .rb_columns_ul .h5,
#     .layout_layout1 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout1 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout1 li:hover > a,
#     .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{color: ;}
#
#
# /*end layout 1*/
#
#
#     /*layout 2*/
#     .rb_megamenu.layout_layout2{
#         background-color: ;
#     }
#
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout2 .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item *{
#         color:
#     }
#     .layout_layout2 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout2:hover .ybc-menu-vertical-button,
#     .layout_layout2 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li.active > a{color: ;}
#
#     .layout_layout2:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#     .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout2:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout2.ybc_vertical_menu:hover{
#         background-color: ;
#     }
#
#     .layout_layout2.rb_megamenu .rb_columns_ul,
#     .layout_layout2.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout2 .rb_block_content a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout2 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout2 .rb_columns_ul h1,
#     .layout_layout2 .rb_columns_ul h2,
#     .layout_layout2 .rb_columns_ul h3,
#     .layout_layout2 .rb_columns_ul h4,
#     .layout_layout2 .rb_columns_ul h5,
#     .layout_layout2 .rb_columns_ul h6,
#     .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout2 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout2 .rb_columns_ul .h1,
#     .layout_layout2 .rb_columns_ul .h2,
#     .layout_layout2 .rb_columns_ul .h3,
#     .layout_layout2 .rb_columns_ul .h4,
#     .layout_layout2 .rb_columns_ul .h5,
#     .layout_layout2 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout2 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout2 li:hover > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#
#
#     /*layout 3*/
#     .rb_megamenu.layout_layout3,
#     .layout_layout3 .rb_tab_li_content{
#         background-color: ;
#
#     }
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout3 .ybc-menu-vertical-button,
#     .layout_layout3 .rb_extra_item *{
#         color:
#     }
#     .layout_layout3 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout3 .rb_menus_li:hover > a,
#     .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li.active > a,
#     .layout_layout3:hover .ybc-menu-vertical-button,
#     .layout_layout3:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         color: ;
#     }
#
#     .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout3:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout3.ybc_vertical_menu:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_columns_contents_ul,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_li_content {
#         background-color: ;
#     }
#     .layout_layout3 .rb_tabs_li.open.rb_tabs_has_content .rb_tab_li_content .rb_tab_name::before{
#         border-right-color: ;
#     }
#     .layout_layout3.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout3 .rb_menus_ul.rb_mn_submenu_full_height .rb_menus_li:hover a::before,
#     .layout_layout3.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#         border-color: ;
#     }
#     #header .layout_layout3 .rb_block_content a,
#     #header .layout_layout3 .rb_block_content p,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li > a{
#         color: ;
#     }
#
#     .layout_layout3 .rb_columns_ul h1,
#     .layout_layout3 .rb_columns_ul h2,
#     .layout_layout3 .rb_columns_ul h3,
#     .layout_layout3 .rb_columns_ul h4,
#     .layout_layout3 .rb_columns_ul h5,
#     .layout_layout3 .rb_columns_ul h6,
#     .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout3 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout3 .rb_columns_ul .h1,
#     .layout_layout3 .rb_columns_ul .h2,
#     .layout_layout3 .rb_columns_ul .h3,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout3.ybc_vertical_menu .rb_menus_li:hover > a,
#     .layout_layout3 .rb_columns_ul .h4,
#     .layout_layout3 .rb_columns_ul .h5,
#     .layout_layout3 .rb_columns_ul .h6{
#         color: ;
#     }
#
#
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout3 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#     /*layout 4*/
#
#     .rb_megamenu.layout_layout4{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout4:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout4 .ybc-menu-vertical-button,
#     .layout_layout4 .rb_extra_item *{
#         color:
#     }
#     .layout_layout4 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4 .rb_menus_li.active > a,
#     #header .layout_layout4 .rb_menus_li:hover > a,
#     .layout_layout4:hover .ybc-menu-vertical-button,
#     #header .layout_layout4 .rb_menus_li.active > a{color: ;}
#
#     .layout_layout4:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > span,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > span,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li.active > a,
#     .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout4:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout4.ybc_vertical_menu:hover,
#     #header .layout_layout4 .rb_menus_li:hover > span,
#     #header .layout_layout4 .rb_menus_li.active > span{
#         background-color: ;
#     }
#     .layout_layout4 .rb_megamenu_content {
#       border-bottom-color: ;
#     }
#
#     .layout_layout4.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout4 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout4.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout4 .rb_block_content a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout4 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout4 .rb_columns_ul h1,
#     .layout_layout4 .rb_columns_ul h2,
#     .layout_layout4 .rb_columns_ul h3,
#     .layout_layout4 .rb_columns_ul h4,
#     .layout_layout4 .rb_columns_ul h5,
#     .layout_layout4 .rb_columns_ul h6,
#     .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout4 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout4 .rb_columns_ul .h1,
#     .layout_layout4 .rb_columns_ul .h2,
#     .layout_layout4 .rb_columns_ul .h3,
#     .layout_layout4 .rb_columns_ul .h4,
#     .layout_layout4 .rb_columns_ul .h5,
#     .layout_layout4 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout4 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout4 li:hover > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li > a,
#     .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#     /* end layout 4*/
#
#
#
#
#     /* Layout 5*/
#     .rb_megamenu.layout_layout5{
#         background-color: ;
#     }
#     .rb_megamenu.layout_layout5:not(.ybc_vertical_menu) .rb_menus_ul{
#          background: ;
#     }
#
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li > a,
#     .layout_layout5 .ybc-menu-vertical-button,
#     .layout_layout5 .rb_extra_item *{
#         color:
#     }
#     .layout_layout5 .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color:
#     }
#     .layout_layout5 .rb_menus_li:hover > a,
#     .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5 .rb_extra_item button[type="submit"]:hover i,
#     #header .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li.active > a,
#     .layout_layout5:hover .ybc-menu-vertical-button{
#         color: ;
#     }
#     .layout_layout5:hover .ybc-menu-vertical-button .ybc-menu-button-toggle_icon_default .icon-bar{
#         background-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li > a:before{background-color: ;}
#
#
#     .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     #header .layout_layout5:not(.ybc_vertical_menu) .rb_menus_li:hover > a,
#     .rb_megamenu.layout_layout5.ybc_vertical_menu:hover,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#
#     .layout_layout5.rb_megamenu .rb_columns_ul,
#     .ybc_vertical_menu.layout_layout5 .rb_menus_ul .rb_menus_li:hover a::before,
#     .layout_layout5.ybc_vertical_menu .rb_menus_ul{
#         background-color: ;
#     }
#     #header .layout_layout5 .rb_block_content a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 .rb_block_content p{
#         color: ;
#     }
#
#     .layout_layout5 .rb_columns_ul h1,
#     .layout_layout5 .rb_columns_ul h2,
#     .layout_layout5 .rb_columns_ul h3,
#     .layout_layout5 .rb_columns_ul h4,
#     .layout_layout5 .rb_columns_ul h5,
#     .layout_layout5 .rb_columns_ul h6,
#     .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h1 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h2 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h3 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h4 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h5 a,
#     #header .layout_layout5 .rb_columns_ul .rb_block > h6 a,
#     .layout_layout5 .rb_columns_ul .h1,
#     .layout_layout5 .rb_columns_ul .h2,
#     .layout_layout5 .rb_columns_ul .h3,
#     .layout_layout5 .rb_columns_ul .h4,
#     .layout_layout5 .rb_columns_ul .h5,
#     .layout_layout5 .rb_columns_ul .h6{
#         color: ;
#     }
#
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li.open .rb_tab_toggle_title a,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title,
#     #header .layout_layout5 .rb_tabs_li:hover .rb_tab_toggle_title a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li > a,
#     #header .layout_layout5 li:hover > a,
#     .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5.ybc_vertical_menu .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*end layout 5*/
# }
#
#
# @media (max-width: 767px){
#     .ybc-menu-vertical-button,
#     .transition_floating .close_menu,
#     .transition_full .close_menu{
#         background-color: ;
#         color: ;
#     }
#     .transition_floating .close_menu *,
#     .transition_full .close_menu *,
#     .ybc-menu-vertical-button .icon-bar{
#         color: ;
#     }
#
#     .close_menu .icon-bar,
#     .ybc-menu-vertical-button .icon-bar {
#       background-color: ;
#     }
#     .rb_menus_back_icon{
#         border-color: ;
#     }
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{color: ;}
#     .layout_layout1 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         /*border-color: ;*/
#     }
#
#
#     .layout_layout1 .rb_menus_li:hover > a,
#     #header .layout_layout1 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout1 li:hover > a,
#     .layout_layout1 li > a:hover,
#     #header .layout_layout1 li:hover > a,
#     #header .layout_layout1 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout1 li > a:hover{
#         color: ;
#     }
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{color: ;}
#     .layout_layout2 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout2 .rb_menus_li:hover > a,
#     #header .layout_layout2 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout2 li:hover > a,
#     .layout_layout2 li > a:hover,
#     #header .layout_layout2 li:hover > a,
#     #header .layout_layout2 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout2 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         color: ;
#     }
#     .layout_layout3 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout3 .rb_menus_li:hover > a,
#     #header .layout_layout3 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout3 li:hover > a,
#     .layout_layout3 li > a:hover,
#     #header .layout_layout3 li:hover > a,
#     #header .layout_layout3 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout3 li > a:hover,
#     .layout_layout3 .has-sub .rb_categories li > a:hover,
#     #header .layout_layout3 .has-sub .rb_categories li > a:hover{color: ;}
#
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         color: ;
#     }
#
#     .layout_layout4 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout4 .rb_menus_li:hover > a,
#     #header .layout_layout4 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout4 li:hover > a,
#     .layout_layout4 li > a:hover,
#     #header .layout_layout4 li:hover > a,
#     #header .layout_layout4 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout4 li > a:hover{color: ;}
#
#
#     /*------------------------------------------------------*/
#
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{color: ;}
#     .layout_layout5 .rb_has_sub.rb_menus_li:hover .arrow::before{
#         border-color: ;
#     }
#
#     .layout_layout5 .rb_menus_li:hover > a,
#     #header .layout_layout5 .rb_menus_li:hover > a{
#         background-color: ;
#     }
#     .layout_layout5 li:hover > a,
#     .layout_layout5 li > a:hover,
#     #header .layout_layout5 li:hover > a,
#     #header .layout_layout5 .rb_columns_ul .rb_block_type_product .product-title > a:hover,
#     #header .layout_layout5 li > a:hover{color: ;}
#
#     /*------------------------------------------------------*/
#
#
#
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </style>
# <meta content="Powered by Rubikthem1.0.0 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Module for PrestaShop." name="generator"/>
# <script>
# 	var an_productattributes = {
# 		controller: "https://freeglisse.com/fr/module/an_productattributes/ajax",
# 		config: JSON.parse('{\"type_view\":\"standart\",\"color_type_view\":\"color\",\"display_add_to_cart\":\"0\",\"display_quantity\":\"1\",\"display_labels\":\"1\",\"product_miniature\":\".js-product-miniature\",\"thumbnail_container\":\".thumbnail-container\",\"price\":\".price\",\"regular_price\":\".regular-price\",\"product_price_and_shipping\":\".product-price-and-shipping\",\"separator\":\" \\/ \",\"background_sold_out\":\"#ffc427\",\"color_sold_out\":\"#ffffff\",\"background_sale\":\"#e53d60\",\"color_sale\":\"#ffffff\",\"display_prices\":\"1\"}'),
# 		loader: '<div class="anpa-loader js-anpa-loader"><div class="anpa-loader-bg" data-js-loader-bg=""></div><div class="anpa-loader-spinner" data-js-loader-spinner=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="margin: auto; background-image: none; display: block; shape-rendering: auto; animation-play-state: running; animation-delay: 0s; background-position: initial initial; background-repeat: initial initial;" width="254px" height="254px" viewBox="0 0 100 100" preserveAspectRatio="xMidYMid"><path fill="none" stroke="#1d0e0b" stroke-width="3" stroke-dasharray="42.76482137044271 42.76482137044271" d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" stroke-linecap="round" style="transform: scale(0.22); transform-origin: 50px 50px; animation-play-state: running; animation-delay: 0s;"> <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1s" keyTimes="0;1" values="0;256.58892822265625" style="animation-play-state: running; animation-delay: 0s;"></animate></path></svg></div></div>',
# 	}
# </script>
# <meta class="netreviewsWidget" data-jsurl="//cl.avis-verifies.com/fr/cache/8/2/e/82e3f014-3834-3c84-e5c2-57a3c8fd31c1/widget4/widget02-11446_script.js" id="netreviewsWidgetNum11446"/><script src="//cl.avis-verifies.com/fr/widget4/widget02.min.js"></script><script type="text/javascript">
#
#         var psv = 1.7;
#         var hiRecaptchaSiteKey = '6Lc-ItgiAAAAAEmILb2ozb1TIHdQ83-QWWBjyfP9';
#         var hirecaptchaContact = '1';
#         var hirEnableContactPageCaptcha = '';
#         var hirEnableAuthPageCaptcha = '';
# ...
# </li>
# <li class="thumb-container js-thumb-container">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="thumb js-modal-thumb img-fluid" data-image-large-src="https://freeglisse.com/70931-thickbox_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" height="148" src="https://freeglisse.com/70931-home_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" width="523"/>
# </li>
# </ul>
# </div>
# </aside>
# </div>
# </div><!-- /.modal-content -->
# </div><!-- /.modal-dialog -->
# </div><!-- /.modal -->
# <footer class="page-footer">
# <!-- Footer content -->
# </footer>
# <div class="page-loading-overlay main-product-details-loading"></div>
# </section>
# </div>
# </div>
# </div>
# </section>
# <footer class="js-footer" id="footer">
# <div class="footer-container footer-h4 style-2">
# <div class="footer-top">
# <div class="container">
# <div class="footer-blockemail">
# <div class="ps-emailsubscription-block block links accordion_small_screen" id="blockEmailSubscription_displayRbEmail">
# <div class="title-newsletter">
# <h3 class="rb-title">Newsletter</h3>
# <p class="sub-letter">Vous pouvez vous désinscrire à tout moment.
# Vous trouverez pour cela nos informations de contact dans les conditions d'utilisation du site.</p>
# </div>
# <div class="block_content">
# <form action="https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-431280-ski-occasion-rossignol-sender-104-ti-2023-fixations.html#blockEmailSubscription_displayRbEmail" method="post">
# <div class="input-group newsletter-input-group">
# <input aria-labelledby="block-newsletter-label" class="form-control input-subscription" name="email" placeholder="Votre adresse e-mail" required="" type="email" value=""/>
# <button class="btn btn-outline" name="submitNewsletter" type="submit">
# <i aria-hidden="true" class="fa fa-paper-plane"></i>
# <span>S'inscrire</span>
# </button>
# </div>
# <input name="blockHookName" type="hidden" value="displayRbEmail"/>
# <input name="action" type="hidden" value="0"/>
# </form>
# <div class="msg-block">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-top-->
# <div class="footer-center">
# <div class="container">
# <div class="row">
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="box-group">
# <a href="https://freeglisse.com/">
# <img alt="Freeglisse.com" class="logo" src="https://freeglisse.com/img/logo-1668007595.jpg"/>
# </a>
# <br/><br/>
# <div class="block-contact block links">
# <div class="title clearfix">
# <h3 class="h3 rb-title">Contactez-nous</h3>
# </div>
# <ul>
# <li class="address"><i class="rub-map-pin"></i><span>Freeglisse.com<br/>98 B rue des champs plans<br/>74800 Saint-Pierre en Faucigny<br/>France</span></li>
# <li class="phone">
# <i class="icon-telephone"></i>
# <span>Site web : 04 50 07 13 25 / Magasin Freeglisse Shop : 04 85 22 11 04 </span>
# </li>
# <li class="fax">
# <i class="rub-printer"></i>
# <span>RETRAIT DES COMMANDES LE LUNDI 14h-19h ET DU MARDI AU SAMEDI 9h-12h 14h-19h</span>
# </li>
# <li class="email">
# <i class="icon-mail"></i>
# <script type="text/javascript">document.write(unescape('%3c%61%20%68%72%65%66%3d%22%6d%61%69%6c%74%6f%3a%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%22%20%3e%73%65%72%76%69%63%65%63%6c%69%65%6e%74%40%66%72%65%65%67%6c%69%73%73%65%2e%63%6f%6d%3c%2f%61%3e'))</script>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Informations</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/contact" title="Utilisez notre formulaire pour nous contacter">
# 	                                contact
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/4-a-propos" title="Apprenez-en d'avantage sur nous">
# 	                                Qui sommes-nous
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/31-economie-circulaire" title="économie circulaire">
# 	                                Économie circulaire
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/27-choisir-son-materiel" title="Comment bien choisir son matériel ?">
# 	                                Choisir son matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/6-etat-du-materiel" title="Explication de l'état d'usure du matériel en premier, deuxième et troisième choix">
# 	                                État du matériel
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/32-notre-atelier" title="">
# 	                                Notre atelier
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/3-conditions-generales-de-ventes" title="Nos conditions générales de ventes">
# 	                                Conditions générales de ventes
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/5-modes-de-paiement" title="Notre offre de paiement sécurisé">
# 	                                Modes de paiement
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/7-echange-et-retour-produits" title="">
# 	                                Échange et retour produits
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/9-article" title="">
# 	                                Articles
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/content/26-donnees-personnelles" title="">
# 	                                Données personnelles
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Mon compte</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/mon-compte" title="">
# 	                                Mon compte
# 	                            </a>
# </li>
# </ul>
# </div>
# <div class="links block RbBlockLink">
# <p class="h3 title_block">Catégories</p>
# <ul>
# <li>
# <a href="https://freeglisse.com/fr/106-occasion" title="">
# 	                                Occasion
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/787-destockage-neuf" title="">
# 	                                Déstockage-neuf
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/667-packs" title="">
# 	                                Packs
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/666-recherche-avancee" title="">
# 	                                Recherche avancée
# 	                            </a>
# </li>
# <li>
# <a href="https://freeglisse.com/fr/fabricants">
# 	                                Toutes nos Marques
# 	                            </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-12 col-xs-12 col-sp-12 pasflex">
# <div class="rb-social-block block links">
# <h3 class="rb-title hidden-sm-down">Follow us</h3>
# <div id="footer_social_block">
# <a href="https://www.facebook.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-facebook-square"></i>
# <span>Facebook</span>
# </a>
# <a href="https://www.instagram.com/freeglisse/" target="_blank">
# <i aria-hidden="true" class="fa fa-instagram"></i>
# <span>Instagram</span>
# </a>
# </div>
# </div>
# <div class="box-footer-html">N°1 du ski occasion en France depuis 30 ans</div>
# <div class="sale-popup flex box-center" data-text1="Acheté il y a " data-text2="minutes"></div>
# </div>
# </div>
# </div>
# </div><!-- end footer-center -->
# <div class="footer-copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-4 col-xs-12 col-sp-12">
# <div class="text-md-left">
# <img alt="Freeglisse.com" class="img-fluid" src="https://freeglisse.com/themes/rb_davici/assets/img/payment.png"/>
# </div>
# </div>
# <div class="col-md-8 col-xs-12 col-sp-12">
# <div class="text-md-right">
# <a class="_blank" href="https://www.nextase.fr" target="_blank">
#                 © 2024 Freeglisse - Par Nextase
#               </a>
# </div>
# </div>
# </div>
# </div>
# </div><!-- end footer-copyright -->
# <div class="rb-hidden hidden-md-down" id="rb-product-cart">
# <div class="container">
# <div class="rb-product-thumb">
# <div class="product-cover-img">
# <img alt="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A" class="js-qv-product-cover img img-thumb" itemprop="image" src="https://freeglisse.com/70892-small_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg" title="Ski occasion Rossignol Sender 104 Ti 2023  + Fixations Qualité A"/>
# </div>
# <div class="rb-description-sticky">
# <h1 class="h1 product-detail-name" itemprop="name">
#             Ski occasion Rossignol Sender 104 Ti 2023  + Fixations
#           </h1>
# <div class="product-prices js-product-prices">
# <div class="product-discount">
# <span class="regular-price">419,00 €</span>
# </div>
# <div class="product-price h5 has-discount">
# <div class="current-price">
# <span class="current-price-value" content="335.2">
#                                       335,20 €
#                       </span>
# <span class="discount discount-percentage">Économisez 20%</span>
# </div>
# </div>
# <div class="tax-shipping-delivery-label">
#               TTC
#
#
#                                           </div>
# </div>
# </div>
# </div>
# <div class="product-actions">
# <div class="product-variants js-product-variants">
# <div class="clearfix product-variants-item">
# <span class="control-label">Etat du matériel :
#                                                                         <span>Qualité A</span>
# </span>
# <ul id="group_3">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="3" name="group[3]" title="Qualité A" type="radio" value="3"/>
# <span class="radio-label">Qualité A</span>
# </label>
# </li>
# </ul>
# </div>
# <div class="clearfix product-variants-item">
# <span class="control-label">Longueur des Skis :
#                                                                         <span>164 cm</span>
# </span>
# <ul id="group_14">
# <li class="input-container float-xs-left instock">
# <label>
# <input checked="checked" class="input-radio" data-product-attribute="14" name="group[14]" title="164 cm" type="radio" value="906"/>
# <span class="radio-label">164 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="172 cm" type="radio" value="914"/>
# <span class="radio-label">172 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="178 cm" type="radio" value="920"/>
# <span class="radio-label">178 cm</span>
# </label>
# </li>
# <li class="input-container float-xs-left instock">
# <label>
# <input class="input-radio" data-product-attribute="14" name="group[14]" title="186 cm" type="radio" value="928"/>
# <span class="radio-label">186 cm</span>
# </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="rb-product-add-to-cart">
# <span class="control-label">Quantity</span>
# <div class="rb-product-quantity clearfix">
# <div class="qty">
# <div class="input-group bootstrap-touchspin">
# <input aria-label="Quantity" class="input-group form-control" id="quantity_wanted" min="1" name="qty" type="number" value="1"/>
# <span class="input-group-btn-vertical">
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-up" type="button">
# <i class="material-icons touchspin-up"></i>
# </button>
# <button class="btn btn-touchspin js-touchspin bootstrap-touchspin-down" type="button">
# <i class="material-icons touchspin-down"></i>
# </button>
# </span>
# </div>
# </div>
# <div class="add">
# <a class="btn btn-primary add-to-cart">
# <i class="material-icons shopping-cart"></i>
#                   Add to cart
#                 </a>
# </div>
# </div>
# </div>
# <section class="product-discounts js-product-discounts">
# </section>
# </div>
# </div>
# </div>
# </div>
# <div class="progress-wrap" id="rb-back-top">
# <a href="#">
# <svg class="progress-circle svg-content" height="100%" viewbox="-1 -1 102 102" width="100%">
# <path d="M50,1 a49,49 0 0,1 0,98 a49,49 0 0,1 0,-98"></path>
# </svg>
# </a>
# </div>
# </footer>
# </main>
# <script src="https://freeglisse.com/themes/rb_davici/assets/cache/bottom-73e215898.js" type="text/javascript"></script>
# <div aria-hidden="true" class="modal rbsizeguide-modal fade" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-header">
# <div class="modal-body">
# <div class="row">
# <div class="col-md-6">
# <img src="https://freeglisse.com/modules/rbsizeguide/views/img/img.jpg" style="max-width:100%;height:auto;"/>
# </div>
# <div class="col-md-6">
# <ul class="nav nav-tabs">
# <li class="nav-item">
# <a class="nav-link active" data-toggle="tab" href="#rb_sizeguide" title="Size Guide">
# <h5>Size Guide</h5>
# </a>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane rte fade active in" id="rb_sizeguide">
# <table class="table table-sizegudie" style="height:36px;" width="1215"><tbody><tr><td style="text-align:left;">CLOTHES</td></tr></tbody></table><p></p><table class="table table-sizegudie" style="height:157px;" width="1217"><thead><tr><th>MEASURE</th><th>XS/34</th><th>S/36</th><th>M/38-40</th><th>L/40-42</th></tr></thead><tbody><tr class="background-odd"><td>UK</td><td>6</td><td>8</td><td>10</td><td>12</td></tr><tr><td>USA</td><td>4</td><td>6</td><td>8</td><td>10</td></tr><tr class="background-odd"><td>FRA</td><td>36</td><td>38</td><td>40</td><td>42</td></tr><tr><td>Waist (cm)</td><td>64</td><td>68</td><td>72</td><td>76</td></tr><tr class="background-odd"><td>Chest (cm)</td><td>81</td><td>85</td><td>89</td><td>93</td></tr><tr><td>Seat (cm)</td><td>89</td><td>93</td><td>97</td><td>101</td></tr><tr class="background-odd"><td>Inseam (cm)</td><td>81</td><td>82</td><td>83</td><td>84</td></tr></tbody></table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><script>
# function ap5_setPackContentData(retryCount) {
# 	if (typeof(retryCount) == 'undefined') {
# 		var retryCount = 0;
# 	}
# 	if (typeof(ap5_cartPackProducts) == 'object') {
# 		let ap5_packContentDataUpdated = false;
# 		for (ap5_uniquePackAttribute in ap5_cartPackProducts) {
# 			$('.product-line-info span:contains("' + ap5_uniquePackAttribute + '"), .product-line-grid span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 			$('#blockcart-modal .modal-body span:contains("' + ap5_uniquePackAttribute + '")').each(function (idx, elem) {
# 				var changed = $(elem).html().replace(ap5_uniquePackAttribute, ap5_cartPackProducts[ap5_uniquePackAttribute].cart);
# 				$(elem).html(changed);
# 				ap5_packContentDataUpdated = true;
# 			});
# 		}
# 		if (!ap5_packContentDataUpdated) {
# 			if (retryCount <= 5) {
# 				retryCount++;
# 				setTimeout(ap5_setPackContentData, 100, retryCount);
# 			}
# 		}
# 	}
# }
#
# document.addEventListener('DOMContentLoaded', function () {
# 	ap5_setPackContentData();
# 	$(document).ajaxSuccess(function() {
# 		ap5_setPackContentData();
# 	});
# 	$(document).on('ap5-After-AddPackToCart', function() {
# 		ap5_setPackContentData();
# 	});
# });
# </script>
# </body>
# </html>

# %%
filter_maker = maker_soup.find('img',{'class':"img img-thumbnail manufacturer-logo"})
filter_maker
# Out:
# <img alt="Rossignol" class="img img-thumbnail manufacturer-logo" loading="lazy" src="https://freeglisse.com/img/m/135-small_default.jpg"/>

# %%
filter_maker.get('alt')
# Out:
# 'Rossignol'

# %% [markdown]
# ## Mise en place du DataFrame de qualiter A

# %%
from unidecode import unidecode
def table_qualite_a():
    base_url = "https://freeglisse.com/fr/12-ski-occasion/s-1/etat_du_materiel-qualite_a?page={}"
    current_page = 1
    df_global_a = pd.DataFrame(columns=['nom', 'prix', 'lien'])
    while True:
        url = base_url.format(current_page)
        response = requests.get(url)
        if response.status_code != 200:
            print("Erreur lors de la requête HTTP")
            break
        soup = BeautifulSoup(response.text, 'html.parser')
        balises_h2 = soup.find_all("h2", {"class": "h3 product-title"})
        noms_produits = [balise_h2.a.text.strip() for balise_h2 in balises_h2]
        prices = [unidecode(span.get_text().strip()) for span in soup.find_all("span", {"class": "price"})]
        product_links = [h2_tag.a.get("href") for h2_tag in balises_h2]
        data = {'nom': noms_produits, 'prix': prices, 'lien': product_links}
        df_current = pd.DataFrame(data)
        df_global_a = pd.concat([df_global_a, df_current], ignore_index=True)
        next_page_link = soup.find("a", {"rel": "next", "class": "next js-search-link"})
        if not next_page_link:
            break
        current_page += 1
    return df_global_a
df_a = table_qualite_a()
df_a['Qualité'] = 'Qualité A'
df_a
# Out:
#                                                   nom        prix  \
# 0   Ski junior Rossignol Star Wars occasion + fixa...   69,00 EUR
# 1   Ski occasion Rossignol Sender 94 Ti 2023  + Fi...  287,20 EUR
# 2   Ski occasion Rossignol Sender 104 Ti 2023  + F...  335,20 EUR
# 3   Ski occasion junior Dynastar Team speed  + Fix...   59,00 EUR
# 4   Ski occasion Dynastar SPEED ZONE 4x4 78 + fixa...  199,00 EUR
# 5   Ski occasion Dynastar SPEED ZONE 4x4 82 + fixa...  249,00 EUR
# 6            Ski occasion Atomic Cloud Q9 + fixations  299,00 EUR
# 7   Ski occasion  junior Tecnopro Team Pulse + fix...   55,00 EUR
# 8              Ski occasion Volkl RTM 7.4 + fixations  109,00 EUR
# 9   Ski occasion Rossignol Nova 8 CA 2022  + Fixat...  209,00 EUR
# 10   Ski occasion Dynastar intense 4x4 78 + fixations  199,00 EUR
# 11  Ski occasion Rossignol React 6 Compact + fixat...  169,00 EUR
# 12   Ski occasion Rossignol Experience 74 + fixations  149,00 EUR
# 13  Ski occasion Rossignol React 6 Compact + fixat...  169,00 EUR
# 14     Ski occasion Nordica Transfire RTX + fixations  149,00 EUR
# 15  Ski occasion Rossignol Nova 8 CA 2023  + Fixat...  207,20 EUR
# 16              Ski occasion Elan GSX Pro + fixations  259,00 EUR
# 17          Ski occasion Dynastar Cham 87 + fixations  129,00 EUR
# 18  Ski occasion junior Nordica Ace of Spades + fi...   65,00 EUR
# 19    Ski de fond occasion Fischer Cruiser Crown +...   75,00 EUR
# 20  Ski de fond occasion junior Salomon Skin Race ...   59,00 EUR
# 21           Ski occasion Kastle RX 12 SL + fixations  229,00 EUR
# 22      Ski occasion Dynastar Legend w 88 + fixations  249,00 EUR
# 23           Ski occasion Fischer My Curv + fixations  229,00 EUR
# 24       Ski occasion Fischer RC4 My Curv + fixations  189,00 EUR
# 25           Ski occasion Kastle RX 12 SL + fixations  229,00 EUR
# 26           Ski occasion Fischer My Curv + fixations  229,00 EUR
# 27  Ski occasion junior Tecnopro Flyte JR + fixations   45,00 EUR
# 28       Ski occasion junior Volkl RTM JR + fixations   59,00 EUR
# 29  Ski occasion Rossignol Blackops Sender 2022 + ...  299,00 EUR
# 30  Ski occasion Rossignol Experience 86 Basalt 20...  255,20 EUR
# 31        Ski occasion Dynastar M-Freeski + fixations  169,00 EUR
# 32            Ski occasion Movement Jam ER + fixation  149,00 EUR
# 33  Ski occasion Rossignol Strato Edition 2023 + f...  327,20 EUR
# 34  Ski de fond occasion junior Fischer RCR Skatec...   65,00 EUR
# 35              Ski occasion Head peak 74 + fixations   89,00 EUR
# 36  Ski occasion Rossignol Temptation Style + fixa...  139,00 EUR
# 37         Ski occasion Salomon X Max X10 + fixations  249,00 EUR
# 38        Ski occasion Rossignol Famous 6 + Fixations  139,00 EUR
# 39  Ski occasion junior Tecnopro Team Pulse + fixa...   55,00 EUR
# 40        Ski occasion Salomon AIRA 76 CF + Fixations  109,00 EUR
# 41                  Ski Test Kastle FX 95 + fixations  443,40 EUR
# 42        Ski occasion Lacroix LX Gravity + fixations  339,00 EUR
# 43  Ski occasion Fischer Brilliant My Turn + fixat...  249,00 EUR
# 44                      Ski Test Zag H 96 + fixations  426,30 EUR
# 45                     Ski Test Zag H 105 + fixations  384,30 EUR
# 46           Ski occasion Movement Go Fast + fixation  289,00 EUR
# 47      Ski occasion Rossignol Sky 7 HD W + Fixations  229,00 EUR
# 48           Ski occasion Salomon Rocker  + fixations  289,00 EUR
# 49      Ski occasion Fischer RC4 the Curv + fixations  229,00 EUR
# 50            Ski occasion Kastle DX 73 W + fixations  239,00 EUR
# 51   Ski occasion Fischer RC4 Worldcup SC + fixations  289,00 EUR
# 52  Ski occasion Dynastar SPEED ZONE 10 Ti + fixat...  209,00 EUR
# 53        Ski occasion Dynastar Menace 90 + fixations  179,00 EUR
# 54                Ski occasion Scott Luna + fixations   89,00 EUR
# 55              Ski occasion Lacroix Pure + fixations  229,00 EUR
# 56          Ski occasion Exonde XO 97 v31 + fixations  349,00 EUR
# 57  Ski occasion junior Tecnopro Team Pulse + fixa...   49,00 EUR
#
#                                                  lien    Qualité
# 0   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 1   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 2   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 3   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 4   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 5   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 6   https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 7   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 8   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 9   https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité A
# 10  https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 11  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 12  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 13  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 14  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 15  https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité A
# 16  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 17  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 18  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 19  https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité A
# 20  https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité A
# 21  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 22  https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 23  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 24  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 25  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 26  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 27  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 28  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 29  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 30  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 31  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 32  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 33  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 34  https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité A
# 35  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 36  https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 37  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 38  https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité A
# 39  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 40  https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 41  https://freeglisse.com/fr/ski-test-all-mountai...  Qualité A
# 42  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 43  https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité A
# 44  https://freeglisse.com/fr/ski-test-all-mountai...  Qualité A
# 45  https://freeglisse.com/fr/ski-test-all-mountai...  Qualité A
# 46  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 47  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 48  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 49  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 50  https://freeglisse.com/fr/ski-occasion-femme-l...  Qualité A
# 51  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 52  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 53  https://freeglisse.com/fr/ski-occasion-freesty...  Qualité A
# 54  https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité A
# 55  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 56  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité A
# 57  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A

# %% [markdown]
# ## Mise en place du DataFrame de qualiter B

# %%
from unidecode import unidecode
def table_qualite_b():
    base_url = "https://freeglisse.com/fr/12-ski-occasion/s-1/etat_du_materiel-qualite_b?page={}"
    current_page = 1
    df_global_b = pd.DataFrame(columns=['nom', 'prix', 'lien'])
    while True:
        url = base_url.format(current_page)
        response = requests.get(url)
        if response.status_code != 200:
            print("Erreur lors de la requête HTTP")
            break
        soup = BeautifulSoup(response.text, 'html.parser')
        balises_h2 = soup.find_all("h2", {"class": "h3 product-title"})
        noms_produits = [balise_h2.a.text.strip() for balise_h2 in balises_h2]
        prices = [unidecode(span.get_text().strip()) for span in soup.find_all("span", {"class": "price"})]
        product_links = [h2_tag.a.get("href") for h2_tag in balises_h2]
        data = {'nom': noms_produits, 'prix': prices, 'lien': product_links}
        df_current = pd.DataFrame(data)
        df_global_b = pd.concat([df_global_b, df_current], ignore_index=True)
        next_page_link = soup.find("a", {"rel": "next", "class": "next js-search-link"})
        if not next_page_link:
            break
        current_page += 1
    return df_global_b
df_b = table_qualite_b()
df_b['Qualité'] = 'Qualité B'
df_b
# Out:
#                                                   nom        prix  \
# 0           Ski occasion Rossignol Nova 6 + fixations  139,00 EUR
# 1   Ski occasion junior toutes marques à 19 € + Fi...   19,00 EUR
# 2           Ski occasion K2 Thrilluvit 85 + fixations  119,00 EUR
# 3              Ski occasion Armada ARV 84 + fixations  189,00 EUR
# 4   Ski occasion Dynastar SPEED ZONE 4x4 78 + fixa...  159,00 EUR
# ..                                                ...         ...
# 57             Ski occasion K2 Pinnacle 95 + fixation  149,00 EUR
# 58        Ski occasion Volant Pulse White + fixations  119,00 EUR
# 59  Ski occasion Dynastar SPEED ZONE 10 Ti + fixat...  169,00 EUR
# 60  Ski occasion junior Fischer RC4 worldcup GS + ...   55,00 EUR
# 61        Ski occasion Dynastar Legend 94 + fixations   89,00 EUR
#
#                                                  lien    Qualité
# 0   https://freeglisse.com/fr/ski-occasion-femme-l...  Qualité B
# 1   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité B
# 2   https://freeglisse.com/fr/ski-occasion-femme-a...  Qualité B
# 3   https://freeglisse.com/fr/ski-occasion-freesty...  Qualité B
# 4   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité B
# ..                                                ...        ...
# 57  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité B
# 58  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité B
# 59  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité B
# 60  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité B
# 61  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité B
#
# [62 rows x 4 columns]

# %% [markdown]
# ## Mise en place du DataFrame de qualiter C

# %%
from unidecode import unidecode
def table_qualite_c():
    base_url = "https://freeglisse.com/fr/12-ski-occasion/s-1/etat_du_materiel-qualite_c?page={}"
    current_page = 1
    df_global_c = pd.DataFrame(columns=['nom', 'prix', 'lien'])
    while True:
        url = base_url.format(current_page)
        response = requests.get(url)
        if response.status_code != 200:
            print("Erreur lors de la requête HTTP")
            break
        soup = BeautifulSoup(response.text, 'html.parser')
        balises_h2 = soup.find_all("h2", {"class": "h3 product-title"})
        noms_produits = [balise_h2.a.text.strip() for balise_h2 in balises_h2]
        prices = [unidecode(span.get_text().strip()) for span in soup.find_all("span", {"class": "price"})]
        product_links = [h2_tag.a.get("href") for h2_tag in balises_h2]
        data = {'nom': noms_produits, 'prix': prices, 'lien': product_links}
        df_current = pd.DataFrame(data)
        df_global_c = pd.concat([df_global_c, df_current], ignore_index=True)
        next_page_link = soup.find("a", {"rel": "next", "class": "next js-search-link"})
        if not next_page_link:
            break
        current_page += 1
    return df_global_c
df_c = table_qualite_c()
df_c['Qualité'] = 'Qualité C'
df_c
# Out:
#                                                   nom        prix  \
# 0   Ski de fond occasion Toutes marques  + fixatio...    9,00 EUR
# 1           Ski occasion Rossignol Nova 6 + fixations   59,00 EUR
# 2   Ski de fond occasion Rossignol LTS Junior + fi...   19,00 EUR
# 3   Ski de fond occasion Toutes marques + fixation...   15,00 EUR
# 4   Ski de fond occasion Rossignol Progress + fixa...   19,00 EUR
# 5   Ski occasion junior Salomon S Race Jr + fixations   39,00 EUR
# 6   Ski de fond occasion Toutes marques + fixation...   19,00 EUR
# 7     Ski occasion junior Head Supershape + fixations   45,00 EUR
# 8            Ski occasion Elan Sling Shot + fixations   39,00 EUR
# 9             Ski occasion Volkl Revolt 95 + fixation   69,00 EUR
# 10  Ski occasion Rossignol tous modèle à 29€ + fix...   29,00 EUR
# 11             Ski occasion Head Shape TX + fixations   59,00 EUR
# 12  Ski occasion adulte K2 tous modèles à 29€ + Fi...   29,00 EUR
# 13            Ski occasion Dynastar CR 74 + fixations   55,00 EUR
# 14     Ski occasion Fischer Pro MTN 80 Ti + fixations   45,00 EUR
# 15  Ski occasion Head Supershape i.Magnum + fixations   69,00 EUR
# 16              Ski occasion Volkl RTM 7.4 + fixation   59,00 EUR
# 17    Ski occasion Head Super Joy Slr Pro + fixations   79,00 EUR
# 18               Ski occasion Head Rev 78 + fixations   59,00 EUR
# 19           Ski occasion Volkl Revolt 95 + fixations   99,00 EUR
# 20         Ski occasion Atomic Redster G9 + fixations  109,00 EUR
# 21         Ski occasion Head i.Shape Rush + fixations   59,00 EUR
# 22  Ski occasion Nordica Dobermann Spitfire CRX + ...   59,00 EUR
# 23              Ski occasion Kastle MX 84 + fixations   69,00 EUR
# 24              Ski occasion Kastle MX 84 + fixations   69,00 EUR
# 25         Ski occasion Head i.Shape Rush + fixations   59,00 EUR
# 26  Ski occasion Nordica Dobermann Spitfire CRX + ...   59,00 EUR
# 27         Ski occasion Atomic Redster G9 + fixations  109,00 EUR
# 28         Ski occasion Atomic Redster S9 + fixations  149,00 EUR
# 29  Ski occasion junior Dynastar Team Course WC + ...   43,00 EUR
# 30   Ski occasion junior Fischer RC4 Race + fixations   35,00 EUR
# 31  Ski occasion junior Dynastar Team Course WC + ...   45,00 EUR
# 32  Ski occasion Rossignol Pursuit 600 CAM + fixat...   59,00 EUR
# 33  Ski occasion Femme toutes marques tous modèles...   29,00 EUR
# 34  Ski occasion Atomic tous modèle à 29€ + fixations   29,00 EUR
# 35    Ski occasion Head tous modèle à 29€ + fixations   29,00 EUR
# 36   Ski occasion Volkl tous modèle à 29€ + fixations   29,00 EUR
# 37   Ski occasion Scott tous modèle à 29€ + fixations   29,00 EUR
# 38  Ski occasion Dynastar tous modèle à 29€ + fixa...   29,00 EUR
# 39  Ski occasion Salomon Tous Modèles à 29€ + fixa...   29,00 EUR
# 40  Ski occasion junior Head Team Supershape Era 2...   45,00 EUR
# 41  Ski occasion Nordica Dobermann spitfire CRX + ...   59,00 EUR
# 42  Ski occasion Nordica Dobermann Spitfire pro + ...   69,00 EUR
# 43         Ski occasion Atomic Redster G9 + fixations  109,00 EUR
# 44    Ski occasion junior Fischer Stunner + fixations   49,00 EUR
# 45          Ski occasion Salomon X Wing 6 + fixations   39,00 EUR
# 46  Ski occasion Nordica Navigator 85 Ca R + fixat...   59,00 EUR
# 47  Ski occasion junior Blizzard Racing GS + fixat...   29,00 EUR
# 48  Ski occasion junior Volkl Racetiger GS + fixat...   29,00 EUR
# 49          Ski occasion Salomon X Wing 8 + fixations   59,00 EUR
# 50            Ski occasion Volkl Kendo 88 + fixations   89,00 EUR
#
#                                                  lien    Qualité
# 0   https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité C
# 1   https://freeglisse.com/fr/ski-occasion-femme-l...  Qualité C
# 2   https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité C
# 3   https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité C
# 4   https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité C
# 5   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 6   https://freeglisse.com/fr/ski-de-fond-occasion...  Qualité C
# 7   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 8   https://freeglisse.com/fr/ski-occasion-freesty...  Qualité C
# 9   https://freeglisse.com/fr/ski-occasion-freesty...  Qualité C
# 10  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 11  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 12  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 13  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 14  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 15  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 16  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 17  https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité C
# 18  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 19  https://freeglisse.com/fr/ski-occasion-freesty...  Qualité C
# 20  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 21  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 22  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 23  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 24  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 25  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 26  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 27  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 28  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 29  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 30  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 31  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 32  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 33  https://freeglisse.com/fr/ski-occasion-femme-p...  Qualité C
# 34  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 35  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 36  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 37  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 38  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 39  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 40  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 41  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 42  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 43  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 44  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 45  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 46  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 47  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 48  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 49  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 50  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité C

# %% [markdown]
# ## Merge des 3 DataFrame de qualiter

# %%
df_all_quality = pd.concat([df_a, df_b, df_c])
df_all_quality
# Out:
#                                                   nom        prix  \
# 0   Ski junior Rossignol Star Wars occasion + fixa...   69,00 EUR
# 1   Ski occasion Rossignol Sender 94 Ti 2023  + Fi...  287,20 EUR
# 2   Ski occasion Rossignol Sender 104 Ti 2023  + F...  335,20 EUR
# 3   Ski occasion junior Dynastar Team speed  + Fix...   59,00 EUR
# 4   Ski occasion Dynastar SPEED ZONE 4x4 78 + fixa...  199,00 EUR
# ..                                                ...         ...
# 46  Ski occasion Nordica Navigator 85 Ca R + fixat...   59,00 EUR
# 47  Ski occasion junior Blizzard Racing GS + fixat...   29,00 EUR
# 48  Ski occasion junior Volkl Racetiger GS + fixat...   29,00 EUR
# 49          Ski occasion Salomon X Wing 8 + fixations   59,00 EUR
# 50            Ski occasion Volkl Kendo 88 + fixations   89,00 EUR
#
#                                                  lien    Qualité
# 0   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 1   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 2   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 3   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 4   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# ..                                                ...        ...
# 46  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 47  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 48  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 49  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 50  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité C
#
# [171 rows x 4 columns]

# %% [markdown]
# ## Mise en place du DataFrame

# %%
def detail_produit():
    type_list = []
    price_list = []
    maker_list = []
    utilisateur_list = []
    niveau_list = []
    coloris_list = []
    utilisateur_config_list = []
    economie_co2_list = []
    type_produit_list = []
    for url in df_all_quality['lien']:
        s = requests.Session()
        r = s.get(url)
        product = BeautifulSoup(r.content)
        soup_price = BeautifulSoup(r.content)
        maker_soup = BeautifulSoup(r.content)
        product_info = product.find('section', {"class":"product-features"})
        filter_price = soup_price.find('span', {"class":"current-price-value"})
        filter_maker = maker_soup.find('img',{'class':"img img-thumbnail manufacturer-logo"})
        try :
            type_list.append(str(product_info).split('Type')[1].split('>')[2].split('<')[0])
        except :
            type_list.append(np.nan)
        try :
            price_list.append(str(filter_price).split('content')[1].split('\"')[1])
        except :
            price_list.append(np.nan)
        try :
            maker_list.append(filter_maker.get('alt'))
        except :
            maker_list.append(np.nan)
        try :
            utilisateur_list.append(str(product_info).split('Utilisateur')[1].split('>')[2].split('<')[0])
        except :
            utilisateur_list.append(np.nan)
        try :
            niveau_list.append(str(product_info).split('Niveau')[1].split('>')[2].split('<')[0])
        except :
            niveau_list.append(np.nan)
        try :
            coloris_list.append(str(product_info).split('Coloris')[1].split('>')[2].split('<')[0])
        except :
            coloris_list.append(np.nan)
        try :
            utilisateur_config_list.append(str(product_info).split('Utilisateur - Configurateur')[1].split('>')[2].split('<')[0])
        except :
            utilisateur_config_list.append(np.nan)
        try :
            economie_co2_list.append(str(product_info).split('Economie de CO2 pour la planète (en kg)')[1].split('>')[2].split('<')[0])
        except :
            economie_co2_list.append(np.nan)
        try :
            type_produit_list.append(str(product_info).split('Type de produit')[1].split('>')[2].split('<')[0])
        except :
            type_produit_list.append(np.nan)
    #return pd.DataFrame({
        #'url' : url_list, 
        #'price' : price_list,
        #'maker' : maker_list,
        #'type' : type_list,
        #'utilisateur' : utilisateur_list,
        #'niveau' : niveau_list,
        #'coloris' : coloris_list,
        #'utilisateur config' : utilisateur_config_list,
        #'economie co2' : economie_co2_list,
        #'type produit' : type_produit_list
    #})
    df_all_quality['marque_produit'] = maker_list
    df_all_quality['type_pratique'] = utilisateur_config_list
    df_all_quality['utilisateur'] = utilisateur_list
    df_all_quality['niveau'] = niveau_list
    df_all_quality['colori'] = coloris_list
    df_all_quality['economie co2'] = economie_co2_list
    df_all_quality['type'] = type_list
    df_all_quality['type produit'] = type_produit_list

# %% [markdown]
# affichage du DataFrame

# %%
detail_produit()

# %%
df_all_quality
# Out:
#                                                   nom        prix  \
# 0   Ski junior Rossignol Star Wars occasion + fixa...   69,00 EUR
# 1   Ski occasion Rossignol Sender 94 Ti 2023  + Fi...  287,20 EUR
# 2   Ski occasion Rossignol Sender 104 Ti 2023  + F...  335,20 EUR
# 3   Ski occasion junior Dynastar Team speed  + Fix...   59,00 EUR
# 4   Ski occasion Dynastar SPEED ZONE 4x4 78 + fixa...  199,00 EUR
# ..                                                ...         ...
# 46  Ski occasion Nordica Navigator 85 Ca R + fixat...   59,00 EUR
# 47  Ski occasion junior Blizzard Racing GS + fixat...   29,00 EUR
# 48  Ski occasion junior Volkl Racetiger GS + fixat...   29,00 EUR
# 49          Ski occasion Salomon X Wing 8 + fixations   59,00 EUR
# 50            Ski occasion Volkl Kendo 88 + fixations   89,00 EUR
#
#                                                  lien    Qualité  \
# 0   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 1   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 2   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# 3   https://freeglisse.com/fr/ski-occasion-junior-...  Qualité A
# 4   https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité A
# ..                                                ...        ...
# 46  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 47  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 48  https://freeglisse.com/fr/ski-occasion-junior-...  Qualité C
# 49  https://freeglisse.com/fr/ski-occasion-adulte-...  Qualité C
# 50  https://freeglisse.com/fr/ski-occasion-freerid...  Qualité C
#
#    marque_produit      type_pratique utilisateur        niveau  colori  \
# 0       Rossignol          un junior      Junior      Débutant    Bleu
# 1       Rossignol  Freerideur adulte       Mixte    Performant    Noir
# 2       Rossignol  Freerideur adulte       Mixte    Performant    Gris
# 3        Dynastar          un junior      Junior  Loisir sport   Blanc
# 4        Dynastar                NaN       Mixte      Débutant    Gris
# ..            ...                ...         ...           ...     ...
# 46        Nordica                NaN       Mixte        Loisir  Orange
# 47       Blizzard                NaN      Junior   Compétition  Orange
# 48          Volkl                NaN      Junior    Performant   Rouge
# 49        Salomon                NaN       Mixte  Loisir sport   Rouge
# 50          Volkl                NaN       Mixte    Performant    Noir
#
#    economie co2          type                      type produit
# 0           3.6         Piste        Ski occasion junior loisir
# 1           3.6      Freeride             Ski occasion freeride
# 2           3.6      Freeride             Ski occasion freeride
# 3           3.6         Piste        Ski occasion junior loisir
# 4           3.6  All mountain  Ski occasion adulte all mountain
# ..          ...           ...                               ...
# 46          3.6  All mountain  Ski occasion adulte all mountain
# 47          3.6        Racing   Ski occasion junior performance
# 48          3.6         Piste   Ski occasion junior performance
# 49          3.6  All mountain  Ski occasion adulte all mountain
# 50          3.6      Freeride             Ski occasion freeride
#
# [171 rows x 12 columns]

# %% [markdown]
# changement des valeurs text en valeurs numerique

# %%
df_all_quality['economie co2'].nunique()
# Out:
# 1

# %% [markdown]
# affichage des valeurs manquantes

# %% [markdown]
# ## Bonus: compilation des données Freeglisse

# %% [markdown]
# Quelques mois plus tard, Olist vous rappelle. Un partenariat a été noué avec FreeGlisse, et les produits d'occasion du site seront désormais vendus sur la plateforme Olist!
#
# En revanche, les équipes d'Olist n'ont pas le temps de gérer à la main le transfert des annonces d'un site à l'autre. Ils ont besoin de vous pour **rassembler toutes les informations sur les skis d’occasion dans un fichier unique (excel ou csv)**, et pour **enregistrer l’ensemble des photos**, afin de pouvoir rapidement créer des fiches produit sur Olist. Ils comptent sur vous pour leur présenter un dossier bien organisé, afin que le transfert vers leur plateforme soit le plus simple possible.
#
# Si vous avez le temps de vous lancer dans ce projet, vous pouvez inclure une courte partie là-dessus (slide ou section de notebook) dans votre **présentation finale**, afin **d'expliquer aux équipes d'Olist comment l'information est organisée**.
